# %%
import ee
import pandas as pd
from pathlib import Path
from datetime import datetime, timezone
import os
import re

from google.auth.transport.requests import AuthorizedSession

ee.Authenticate()  #  or !earthengine authenticate --auth_mode=gcloud
session = AuthorizedSession(ee.data.get_persistent_credentials())

session

# %% [markdown]
# ## Create empty image collections as target
# Create empty image collection with earthengine CLI
# Purge contents if delete or clean repopulation needed
# List COGs in GCS folder
#
# ```
# cd /data/gis/raster_base/Alaska/AKVegMap/foliar_cover
#
# conda activate ee
#
# earthengine create folder projects/akveg-map/assets/foliar_cover
# earthengine create collection projects/akveg-map/assets/foliar_cover/akveg_foliar_cover_v2p0
#
# for i in `earthengine ls projects/akveg-map/assets/foliar_cover/akveg_foliar_cover_v2p0`; do earthengine rm $i; done
#
# ```

# %%
import json
# from urllib.parse import urlparse
import os
from pprint import pprint

# %%
# TODO Fix date extraction from filename to work for different filename formats
# Parts are zero-based
def load_gcs_cogs_to_collection(cogs, project_folder, collection, pft_part):
    # Request body as a dictionary.
    for cog in cogs['tif']:
      fileOnly = os.path.split(cog)[1]
      # print(fileOnly)

      cogName = fileOnly[:-4]
      print(cogName)
      
      # Split on both underscore and period
      parts = re.split(r'[_\.]', fileOnly)
      print(parts)
      
      pft = f"{parts[pft_part]}"
      print(pft)
        
      # start_dt = datetime(year, 1, 1)
      # start_dt = f"{start_dt:%Y-%m-%dT%H:%M:%SZ}"  # Format string for ISO 8601 + Z
      # end_dt = datetime(year + 1, 1, 1)
      # end_dt = f"{end_dt:%Y-%m-%dT%H:%M:%SZ}"  # Format string for ISO 8601 + Z
      # print(start_dt, end_dt)
        
      request = {
        'type': 'IMAGE',
        'gcs_location': {
          'uris': cog
        },
        'properties': {
            'pft': pft,
            'version': 2.0,
            #   'source': 'https://code.earthengine.google.com/067b10ee56537817756a3177a9138aee',
            # 'yyyymmdd_hhmmss': yyyymmdd_hhmmss
        },
        # 'startTime': start_dt,#'2023-01-01T00:00:00.000000000Z',
        # 'endTime': end_dt,#'2024-01-01T00:00:00.000000000Z',
      }

      # pprint(json.dumps(request))

      # A folder (or ImageCollection) name and the new asset name.
      asset_id = collection+'/'+cogName
      print(project_folder)
      print(asset_id)
        
      url = 'https://earthengine.googleapis.com/v1alpha/projects/{}/assets?assetId={}'
      print(url)

      response = session.post(
        url = url.format(project_folder, asset_id),
        data = json.dumps(request)
      )

      pprint(json.loads(response.content))
    print('done')

# %% [markdown]
# ## Run it

# %%
# gsutil ls gs://akveg-data/rasters_cog/round_20241124_v20250502/*.tif > akveg_foliar_cover_v2p0_on_gcs.txt
project_folder = 'akveg-map'
collection = 'foliar_cover/akveg_foliar_cover_v2p0'
tif_txt = '/data/gis/raster_base/Alaska/AKVegMap/foliar_cover/akveg_foliar_cover_v2p0_on_gcs.txt'
cogs = pd.read_csv(tif_txt, header=None,names=['tif'])

load_gcs_cogs_to_collection(cogs, project_folder, collection, 0)
# Out:
# alnus_10m_3338
# ['alnus', '10m', '3338', 'tif']
# alnus
# akveg-map
# foliar_cover/akveg_foliar_cover_v2p0/alnus_10m_3338
# https://earthengine.googleapis.com/v1alpha/projects/{}/assets?assetId={}
# {'bands': [{'dataType': {'precision': 'INT', 'range': {'max': 255}},
#             'grid': {'affineTransform': {'scaleX': 10,
#                                          'scaleY': -10,
#                                          'translateX': -2180085,
#                                          'translateY': 2388175},
#                      'crsCode': 'EPSG:3338',
#                      'dimensions': {'height': 198834, 'width': 307943}},
#             'id': 'B0',
#             'missingData': {'values': [255]},
#             'pyramidingPolicy': 'MEAN'}],
#  'cloudStorageLocation': {'uris': ['gs://akveg-data/rasters_cog/round_20241124_v20250502/alnus_10m_3338.tif']},
#  'geometry': {'coordinates': [[172.20012497418128, 52.982186886504465],
#                               [175.4747218234518, 48.999058895172126],
#                               [180.29620784020125, 50.43544349923501],
#                               [190.8100687957891, 52.55125133460313],
#                               [202.15248711856034, 53.5459341065996],
#                               [213.7218499895904, 53.342957188845844],
#                               [219.37740376964612, 52.79370144982859],
#                               [224.89754188155013, 64.35938664450953],
#                               [227.4227194789508, 67.65074281613498],
#                               [229.6737588501225, 70.01170172602443],
#                               [219.93296818306223, 70.99819311518736],
#                               [199.00395193479872, 71.3717783236605],
#                               [179.34486240270817, 69.58821415327849],
#                               [170.90995247629414, 68.02056726077777],
#                               [157.23664885636, 63.91136146920561],
#                               [168.2234685793636, 56.81734521686287],
#                               [172.20012497418128, 52.982186886504465]],
#               'type': 'LineString'},
#  'id': 'projects/akveg-map/assets/foliar_cover/akveg_foliar_cover_v2p0/alnus_10m_3338',
#  'name': 'projects/akveg-map/assets/foliar_cover/akveg_foliar_cover_v2p0/alnus_10m_3338',
#  'properties': {'pft': 'alnus', 'version': 2},
#  'tilesets': [{'id': '0',
#                'sources': [{'uris': ['gs://akveg-data/rasters_cog/round_20241124_v20250502/alnus_10m_3338.tif']}]}],
#  'type': 'IMAGE',
#  'updateTime': '2025-05-03T17:45:10.013689Z'}
# betshr_10m_3338
# ['betshr', '10m', '3338', 'tif']
# betshr
# akveg-map
# foliar_cover/akveg_foliar_cover_v2p0/betshr_10m_3338
# https://earthengine.googleapis.com/v1alpha/projects/{}/assets?assetId={}
# {'bands': [{'dataType': {'precision': 'INT', 'range': {'max': 255}},
#             'grid': {'affineTransform': {'scaleX': 10,
#                                          'scaleY': -10,
#                                          'translateX': -2180085,
#                                          'translateY': 2388175},
#                      'crsCode': 'EPSG:3338',
#                      'dimensions': {'height': 198834, 'width': 307943}},
#             'id': 'B0',
#             'missingData': {'values': [255]},
#             'pyramidingPolicy': 'MEAN'}],
#  'cloudStorageLocation': {'uris': ['gs://akveg-data/rasters_cog/round_20241124_v20250502/betshr_10m_3338.tif']},
#  'geometry': {'coordinates': [[172.20012497418128, 52.982186886504465],
#                               [175.4747218234518, 48.999058895172126],
#                               [180.29620784020125, 50.43544349923501],
#                               [190.8100687957891, 52.55125133460313],
#                               [202.15248711856034, 53.5459341065996],
#                               [213.7218499895904, 53.342957188845844],
#                               [219.37740376964612, 52.79370144982859],
#                               [224.89754188155013, 64.35938664450953],
#                               [227.4227194789508, 67.65074281613498],
#                               [229.6737588501225, 70.01170172602443],
#                               [219.93296818306223, 70.99819311518736],
#                               [199.00395193479872, 71.3717783236605],
#                               [179.34486240270817, 69.58821415327849],
#                               [170.90995247629414, 68.02056726077777],
#                               [157.23664885636, 63.91136146920561],
#                               [168.2234685793636, 56.81734521686287],
#                               [172.20012497418128, 52.982186886504465]],
#               'type': 'LineString'},
#  'id': 'projects/akveg-map/assets/foliar_cover/akveg_foliar_cover_v2p0/betshr_10m_3338',
#  'name': 'projects/akveg-map/assets/foliar_cover/akveg_foliar_cover_v2p0/betshr_10m_3338',
#  'properties': {'pft': 'betshr', 'version': 2},
#  'tilesets': [{'id': '0',
#                'sources': [{'uris': ['gs://akveg-data/rasters_cog/round_20241124_v20250502/betshr_10m_3338.tif']}]}],
#  'type': 'IMAGE',
#  'updateTime': '2025-05-03T17:45:11.708455Z'}
# bettre_10m_3338
# ['bettre', '10m', '3338', 'tif']
# bettre
# akveg-map
# foliar_cover/akveg_foliar_cover_v2p0/bettre_10m_3338
# https://earthengine.googleapis.com/v1alpha/projects/{}/assets?assetId={}
# {'bands': [{'dataType': {'precision': 'INT', 'range': {'max': 255}},
#             'grid': {'affineTransform': {'scaleX': 10,
#                                          'scaleY': -10,
#                                          'translateX': -2180085,
#                                          'translateY': 2388175},
#                      'crsCode': 'EPSG:3338',
#                      'dimensions': {'height': 198834, 'width': 307943}},
#             'id': 'B0',
#             'missingData': {'values': [255]},
#             'pyramidingPolicy': 'MEAN'}],
#  'cloudStorageLocation': {'uris': ['gs://akveg-data/rasters_cog/round_20241124_v20250502/bettre_10m_3338.tif']},
#  'geometry': {'coordinates': [[172.20012497418128, 52.982186886504465],
#                               [175.4747218234518, 48.999058895172126],
#                               [180.29620784020125, 50.43544349923501],
#                               [190.8100687957891, 52.55125133460313],
#                               [202.15248711856034, 53.5459341065996],
#                               [213.7218499895904, 53.342957188845844],
#                               [219.37740376964612, 52.79370144982859],
#                               [224.89754188155013, 64.35938664450953],
#                               [227.4227194789508, 67.65074281613498],
#                               [229.6737588501225, 70.01170172602443],
#                               [219.93296818306223, 70.99819311518736],
#                               [199.00395193479872, 71.3717783236605],
#                               [179.34486240270817, 69.58821415327849],
#                               [170.90995247629414, 68.02056726077777],
#                               [157.23664885636, 63.91136146920561],
#                               [168.2234685793636, 56.81734521686287],
#                               [172.20012497418128, 52.982186886504465]],
#               'type': 'LineString'},
#  'id': 'projects/akveg-map/assets/foliar_cover/akveg_foliar_cover_v2p0/bettre_10m_3338',
#  'name': 'projects/akveg-map/assets/foliar_cover/akveg_foliar_cover_v2p0/bettre_10m_3338',
#  'properties': {'pft': 'bettre', 'version': 2},
#  'tilesets': [{'id': '0',
#                'sources': [{'uris': ['gs://akveg-data/rasters_cog/round_20241124_v20250502/bettre_10m_3338.tif']}]}],
#  'type': 'IMAGE',
#  'updateTime': '2025-05-03T17:45:13.127142Z'}
# brotre_10m_3338
# ['brotre', '10m', '3338', 'tif']
# brotre
# akveg-map
# foliar_cover/akveg_foliar_cover_v2p0/brotre_10m_3338
# https://earthengine.googleapis.com/v1alpha/projects/{}/assets?assetId={}
# {'bands': [{'dataType': {'precision': 'INT', 'range': {'max': 255}},
#             'grid': {'affineTransform': {'scaleX': 10,
#                                          'scaleY': -10,
#                                          'translateX': -2180085,
#                                          'translateY': 2388175},
#                      'crsCode': 'EPSG:3338',
#                      'dimensions': {'height': 198834, 'width': 307943}},
#             'id': 'B0',
#             'missingData': {'values': [255]},
#             'pyramidingPolicy': 'MEAN'}],
#  'cloudStorageLocation': {'uris': ['gs://akveg-data/rasters_cog/round_20241124_v20250502/brotre_10m_3338.tif']},
#  'geometry': {'coordinates': [[172.20012497418128, 52.982186886504465],
#                               [175.4747218234518, 48.999058895172126],
#                               [180.29620784020125, 50.43544349923501],
#                               [190.8100687957891, 52.55125133460313],
#                               [202.15248711856034, 53.5459341065996],
#                               [213.7218499895904, 53.342957188845844],
#                               [219.37740376964612, 52.79370144982859],
#                               [224.89754188155013, 64.35938664450953],
#                               [227.4227194789508, 67.65074281613498],
#                               [229.6737588501225, 70.01170172602443],
#                               [219.93296818306223, 70.99819311518736],
#                               [199.00395193479872, 71.3717783236605],
#                               [179.34486240270817, 69.58821415327849],
#                               [170.90995247629414, 68.02056726077777],
#                               [157.23664885636, 63.91136146920561],
#                               [168.2234685793636, 56.81734521686287],
#                               [172.20012497418128, 52.982186886504465]],
#               'type': 'LineString'},
#  'id': 'projects/akveg-map/assets/foliar_cover/akveg_foliar_cover_v2p0/brotre_10m_3338',
#  'name': 'projects/akveg-map/assets/foliar_cover/akveg_foliar_cover_v2p0/brotre_10m_3338',
#  'properties': {'pft': 'brotre', 'version': 2},
#  'tilesets': [{'id': '0',
#                'sources': [{'uris': ['gs://akveg-data/rasters_cog/round_20241124_v20250502/brotre_10m_3338.tif']}]}],
#  'type': 'IMAGE',
#  'updateTime': '2025-05-03T17:45:14.634418Z'}
# dryas_10m_3338
# ['dryas', '10m', '3338', 'tif']
# dryas
# akveg-map
# foliar_cover/akveg_foliar_cover_v2p0/dryas_10m_3338
# https://earthengine.googleapis.com/v1alpha/projects/{}/assets?assetId={}
# {'bands': [{'dataType': {'precision': 'INT', 'range': {'max': 255}},
#             'grid': {'affineTransform': {'scaleX': 10,
#                                          'scaleY': -10,
#                                          'translateX': -2180085,
#                                          'translateY': 2388175},
#                      'crsCode': 'EPSG:3338',
#                      'dimensions': {'height': 198834, 'width': 307943}},
#             'id': 'B0',
#             'missingData': {'values': [255]},
#             'pyramidingPolicy': 'MEAN'}],
#  'cloudStorageLocation': {'uris': ['gs://akveg-data/rasters_cog/round_20241124_v20250502/dryas_10m_3338.tif']},
#  'geometry': {'coordinates': [[172.20012497418128, 52.982186886504465],
#                               [175.4747218234518, 48.999058895172126],
#                               [180.29620784020125, 50.43544349923501],
#                               [190.8100687957891, 52.55125133460313],
#                               [202.15248711856034, 53.5459341065996],
#                               [213.7218499895904, 53.342957188845844],
#                               [219.37740376964612, 52.79370144982859],
#                               [224.89754188155013, 64.35938664450953],
#                               [227.4227194789508, 67.65074281613498],
#                               [229.6737588501225, 70.01170172602443],
#                               [219.93296818306223, 70.99819311518736],
#                               [199.00395193479872, 71.3717783236605],
#                               [179.34486240270817, 69.58821415327849],
#                               [170.90995247629414, 68.02056726077777],
#                               [157.23664885636, 63.91136146920561],
#                               [168.2234685793636, 56.81734521686287],
#                               [172.20012497418128, 52.982186886504465]],
#               'type': 'LineString'},
#  'id': 'projects/akveg-map/assets/foliar_cover/akveg_foliar_cover_v2p0/dryas_10m_3338',
#  'name': 'projects/akveg-map/assets/foliar_cover/akveg_foliar_cover_v2p0/dryas_10m_3338',
#  'properties': {'pft': 'dryas', 'version': 2},
#  'tilesets': [{'id': '0',
#                'sources': [{'uris': ['gs://akveg-data/rasters_cog/round_20241124_v20250502/dryas_10m_3338.tif']}]}],
#  'type': 'IMAGE',
#  'updateTime': '2025-05-03T17:45:16.061256Z'}
# dsalix_10m_3338
# ['dsalix', '10m', '3338', 'tif']
# dsalix
# akveg-map
# foliar_cover/akveg_foliar_cover_v2p0/dsalix_10m_3338
# https://earthengine.googleapis.com/v1alpha/projects/{}/assets?assetId={}
# {'bands': [{'dataType': {'precision': 'INT', 'range': {'max': 255}},
#             'grid': {'affineTransform': {'scaleX': 10,
#                                          'scaleY': -10,
#                                          'translateX': -2180085,
#                                          'translateY': 2388175},
#                      'crsCode': 'EPSG:3338',
#                      'dimensions': {'height': 198834, 'width': 307943}},
#             'id': 'B0',
#             'missingData': {'values': [255]},
#             'pyramidingPolicy': 'MEAN'}],
#  'cloudStorageLocation': {'uris': ['gs://akveg-data/rasters_cog/round_20241124_v20250502/dsalix_10m_3338.tif']},
#  'geometry': {'coordinates': [[172.20012497418128, 52.982186886504465],
#                               [175.4747218234518, 48.999058895172126],
#                               [180.29620784020125, 50.43544349923501],
#                               [190.8100687957891, 52.55125133460313],
#                               [202.15248711856034, 53.5459341065996],
#                               [213.7218499895904, 53.342957188845844],
#                               [219.37740376964612, 52.79370144982859],
#                               [224.89754188155013, 64.35938664450953],
#                               [227.4227194789508, 67.65074281613498],
#                               [229.6737588501225, 70.01170172602443],
#                               [219.93296818306223, 70.99819311518736],
#                               [199.00395193479872, 71.3717783236605],
#                               [179.34486240270817, 69.58821415327849],
#                               [170.90995247629414, 68.02056726077777],
#                               [157.23664885636, 63.91136146920561],
#                               [168.2234685793636, 56.81734521686287],
#                               [172.20012497418128, 52.982186886504465]],
#               'type': 'LineString'},
#  'id': 'projects/akveg-map/assets/foliar_cover/akveg_foliar_cover_v2p0/dsalix_10m_3338',
#  'name': 'projects/akveg-map/assets/foliar_cover/akveg_foliar_cover_v2p0/dsalix_10m_3338',
#  'properties': {'pft': 'dsalix', 'version': 2},
#  'tilesets': [{'id': '0',
#                'sources': [{'uris': ['gs://akveg-data/rasters_cog/round_20241124_v20250502/dsalix_10m_3338.tif']}]}],
#  'type': 'IMAGE',
#  'updateTime': '2025-05-03T17:45:17.542325Z'}
# empnig_10m_3338
# ['empnig', '10m', '3338', 'tif']
# empnig
# akveg-map
# foliar_cover/akveg_foliar_cover_v2p0/empnig_10m_3338
# https://earthengine.googleapis.com/v1alpha/projects/{}/assets?assetId={}
# {'bands': [{'dataType': {'precision': 'INT', 'range': {'max': 255}},
#             'grid': {'affineTransform': {'scaleX': 10,
#                                          'scaleY': -10,
#                                          'translateX': -2180085,
#                                          'translateY': 2388175},
#                      'crsCode': 'EPSG:3338',
#                      'dimensions': {'height': 198834, 'width': 307943}},
#             'id': 'B0',
#             'missingData': {'values': [255]},
#             'pyramidingPolicy': 'MEAN'}],
#  'cloudStorageLocation': {'uris': ['gs://akveg-data/rasters_cog/round_20241124_v20250502/empnig_10m_3338.tif']},
#  'geometry': {'coordinates': [[172.20012497418128, 52.982186886504465],
#                               [175.4747218234518, 48.999058895172126],
#                               [180.29620784020125, 50.43544349923501],
#                               [190.8100687957891, 52.55125133460313],
#                               [202.15248711856034, 53.5459341065996],
#                               [213.7218499895904, 53.342957188845844],
#                               [219.37740376964612, 52.79370144982859],
#                               [224.89754188155013, 64.35938664450953],
#                               [227.4227194789508, 67.65074281613498],
#                               [229.6737588501225, 70.01170172602443],
#                               [219.93296818306223, 70.99819311518736],
#                               [199.00395193479872, 71.3717783236605],
#                               [179.34486240270817, 69.58821415327849],
#                               [170.90995247629414, 68.02056726077777],
#                               [157.23664885636, 63.91136146920561],
#                               [168.2234685793636, 56.81734521686287],
#                               [172.20012497418128, 52.982186886504465]],
#               'type': 'LineString'},
#  'id': 'projects/akveg-map/assets/foliar_cover/akveg_foliar_cover_v2p0/empnig_10m_3338',
#  'name': 'projects/akveg-map/assets/foliar_cover/akveg_foliar_cover_v2p0/empnig_10m_3338',
#  'properties': {'pft': 'empnig', 'version': 2},
#  'tilesets': [{'id': '0',
#                'sources': [{'uris': ['gs://akveg-data/rasters_cog/round_20241124_v20250502/empnig_10m_3338.tif']}]}],
#  'type': 'IMAGE',
#  'updateTime': '2025-05-03T17:45:18.943427Z'}
# erivag_10m_3338
# ['erivag', '10m', '3338', 'tif']
# erivag
# akveg-map
# foliar_cover/akveg_foliar_cover_v2p0/erivag_10m_3338
# https://earthengine.googleapis.com/v1alpha/projects/{}/assets?assetId={}
# {'bands': [{'dataType': {'precision': 'INT', 'range': {'max': 255}},
#             'grid': {'affineTransform': {'scaleX': 10,
#                                          'scaleY': -10,
#                                          'translateX': -2180085,
#                                          'translateY': 2388175},
#                      'crsCode': 'EPSG:3338',
#                      'dimensions': {'height': 198834, 'width': 307943}},
#             'id': 'B0',
#             'missingData': {'values': [255]},
#             'pyramidingPolicy': 'MEAN'}],
#  'cloudStorageLocation': {'uris': ['gs://akveg-data/rasters_cog/round_20241124_v20250502/erivag_10m_3338.tif']},
#  'geometry': {'coordinates': [[172.20012497418128, 52.982186886504465],
#                               [175.4747218234518, 48.999058895172126],
#                               [180.29620784020125, 50.43544349923501],
#                               [190.8100687957891, 52.55125133460313],
#                               [202.15248711856034, 53.5459341065996],
#                               [213.7218499895904, 53.342957188845844],
#                               [219.37740376964612, 52.79370144982859],
#                               [224.89754188155013, 64.35938664450953],
#                               [227.4227194789508, 67.65074281613498],
#                               [229.6737588501225, 70.01170172602443],
#                               [219.93296818306223, 70.99819311518736],
#                               [199.00395193479872, 71.3717783236605],
#                               [179.34486240270817, 69.58821415327849],
#                               [170.90995247629414, 68.02056726077777],
#                               [157.23664885636, 63.91136146920561],
#                               [168.2234685793636, 56.81734521686287],
#                               [172.20012497418128, 52.982186886504465]],
#               'type': 'LineString'},
#  'id': 'projects/akveg-map/assets/foliar_cover/akveg_foliar_cover_v2p0/erivag_10m_3338',
#  'name': 'projects/akveg-map/assets/foliar_cover/akveg_foliar_cover_v2p0/erivag_10m_3338',
#  'properties': {'pft': 'erivag', 'version': 2},
#  'tilesets': [{'id': '0',
#                'sources': [{'uris': ['gs://akveg-data/rasters_cog/round_20241124_v20250502/erivag_10m_3338.tif']}]}],
#  'type': 'IMAGE',
#  'updateTime': '2025-05-03T17:45:20.319304Z'}
# mwcalama_10m_3338
# ['mwcalama', '10m', '3338', 'tif']
# mwcalama
# akveg-map
# foliar_cover/akveg_foliar_cover_v2p0/mwcalama_10m_3338
# https://earthengine.googleapis.com/v1alpha/projects/{}/assets?assetId={}
# {'bands': [{'dataType': {'precision': 'INT', 'range': {'max': 255}},
#             'grid': {'affineTransform': {'scaleX': 10,
#                                          'scaleY': -10,
#                                          'translateX': -2180085,
#                                          'translateY': 2388175},
#                      'crsCode': 'EPSG:3338',
#                      'dimensions': {'height': 198834, 'width': 307943}},
#             'id': 'B0',
#             'missingData': {'values': [255]},
#             'pyramidingPolicy': 'MEAN'}],
#  'cloudStorageLocation': {'uris': ['gs://akveg-data/rasters_cog/round_20241124_v20250502/mwcalama_10m_3338.tif']},
#  'geometry': {'coordinates': [[172.20012497418128, 52.982186886504465],
#                               [175.4747218234518, 48.999058895172126],
#                               [180.29620784020125, 50.43544349923501],
#                               [190.8100687957891, 52.55125133460313],
#                               [202.15248711856034, 53.5459341065996],
#                               [213.7218499895904, 53.342957188845844],
#                               [219.37740376964612, 52.79370144982859],
#                               [224.89754188155013, 64.35938664450953],
#                               [227.4227194789508, 67.65074281613498],
#                               [229.6737588501225, 70.01170172602443],
#                               [219.93296818306223, 70.99819311518736],
#                               [199.00395193479872, 71.3717783236605],
#                               [179.34486240270817, 69.58821415327849],
#                               [170.90995247629414, 68.02056726077777],
#                               [157.23664885636, 63.91136146920561],
#                               [168.2234685793636, 56.81734521686287],
#                               [172.20012497418128, 52.982186886504465]],
#               'type': 'LineString'},
#  'id': 'projects/akveg-map/assets/foliar_cover/akveg_foliar_cover_v2p0/mwcalama_10m_3338',
#  'name': 'projects/akveg-map/assets/foliar_cover/akveg_foliar_cover_v2p0/mwcalama_10m_3338',
#  'properties': {'pft': 'mwcalama', 'version': 2},
#  'tilesets': [{'id': '0',
#                'sources': [{'uris': ['gs://akveg-data/rasters_cog/round_20241124_v20250502/mwcalama_10m_3338.tif']}]}],
#  'type': 'IMAGE',
#  'updateTime': '2025-05-03T17:45:22.016361Z'}
# ndsalix_10m_3338
# ['ndsalix', '10m', '3338', 'tif']
# ndsalix
# akveg-map
# foliar_cover/akveg_foliar_cover_v2p0/ndsalix_10m_3338
# https://earthengine.googleapis.com/v1alpha/projects/{}/assets?assetId={}
# {'bands': [{'dataType': {'precision': 'INT', 'range': {'max': 255}},
#             'grid': {'affineTransform': {'scaleX': 10,
#                                          'scaleY': -10,
#                                          'translateX': -2180085,
#                                          'translateY': 2388175},
#                      'crsCode': 'EPSG:3338',
#                      'dimensions': {'height': 198834, 'width': 307943}},
#             'id': 'B0',
#             'missingData': {'values': [255]},
#             'pyramidingPolicy': 'MEAN'}],
#  'cloudStorageLocation': {'uris': ['gs://akveg-data/rasters_cog/round_20241124_v20250502/ndsalix_10m_3338.tif']},
#  'geometry': {'coordinates': [[172.20012497418128, 52.982186886504465],
#                               [175.4747218234518, 48.999058895172126],
#                               [180.29620784020125, 50.43544349923501],
#                               [190.8100687957891, 52.55125133460313],
#                               [202.15248711856034, 53.5459341065996],
#                               [213.7218499895904, 53.342957188845844],
#                               [219.37740376964612, 52.79370144982859],
#                               [224.89754188155013, 64.35938664450953],
#                               [227.4227194789508, 67.65074281613498],
#                               [229.6737588501225, 70.01170172602443],
#                               [219.93296818306223, 70.99819311518736],
#                               [199.00395193479872, 71.3717783236605],
#                               [179.34486240270817, 69.58821415327849],
#                               [170.90995247629414, 68.02056726077777],
#                               [157.23664885636, 63.91136146920561],
#                               [168.2234685793636, 56.81734521686287],
#                               [172.20012497418128, 52.982186886504465]],
#               'type': 'LineString'},
#  'id': 'projects/akveg-map/assets/foliar_cover/akveg_foliar_cover_v2p0/ndsalix_10m_3338',
#  'name': 'projects/akveg-map/assets/foliar_cover/akveg_foliar_cover_v2p0/ndsalix_10m_3338',
#  'properties': {'pft': 'ndsalix', 'version': 2},
#  'tilesets': [{'id': '0',
#                'sources': [{'uris': ['gs://akveg-data/rasters_cog/round_20241124_v20250502/ndsalix_10m_3338.tif']}]}],
#  'type': 'IMAGE',
#  'updateTime': '2025-05-03T17:45:23.719058Z'}
# nerishr_10m_3338
# ['nerishr', '10m', '3338', 'tif']
# nerishr
# akveg-map
# foliar_cover/akveg_foliar_cover_v2p0/nerishr_10m_3338
# https://earthengine.googleapis.com/v1alpha/projects/{}/assets?assetId={}
# {'bands': [{'dataType': {'precision': 'INT', 'range': {'max': 255}},
#             'grid': {'affineTransform': {'scaleX': 10,
#                                          'scaleY': -10,
#                                          'translateX': -2180085,
#                                          'translateY': 2388175},
#                      'crsCode': 'EPSG:3338',
#                      'dimensions': {'height': 198834, 'width': 307943}},
#             'id': 'B0',
#             'missingData': {'values': [255]},
#             'pyramidingPolicy': 'MEAN'}],
#  'cloudStorageLocation': {'uris': ['gs://akveg-data/rasters_cog/round_20241124_v20250502/nerishr_10m_3338.tif']},
#  'geometry': {'coordinates': [[172.20012497418128, 52.982186886504465],
#                               [175.4747218234518, 48.999058895172126],
#                               [180.29620784020125, 50.43544349923501],
#                               [190.8100687957891, 52.55125133460313],
#                               [202.15248711856034, 53.5459341065996],
#                               [213.7218499895904, 53.342957188845844],
#                               [219.37740376964612, 52.79370144982859],
#                               [224.89754188155013, 64.35938664450953],
#                               [227.4227194789508, 67.65074281613498],
#                               [229.6737588501225, 70.01170172602443],
#                               [219.93296818306223, 70.99819311518736],
#                               [199.00395193479872, 71.3717783236605],
#                               [179.34486240270817, 69.58821415327849],
#                               [170.90995247629414, 68.02056726077777],
#                               [157.23664885636, 63.91136146920561],
#                               [168.2234685793636, 56.81734521686287],
#                               [172.20012497418128, 52.982186886504465]],
#               'type': 'LineString'},
#  'id': 'projects/akveg-map/assets/foliar_cover/akveg_foliar_cover_v2p0/nerishr_10m_3338',
#  'name': 'projects/akveg-map/assets/foliar_cover/akveg_foliar_cover_v2p0/nerishr_10m_3338',
#  'properties': {'pft': 'nerishr', 'version': 2},
#  'tilesets': [{'id': '0',
#                'sources': [{'uris': ['gs://akveg-data/rasters_cog/round_20241124_v20250502/nerishr_10m_3338.tif']}]}],
#  'type': 'IMAGE',
#  'updateTime': '2025-05-03T17:45:25.108740Z'}
# picgla_10m_3338
# ['picgla', '10m', '3338', 'tif']
# picgla
# akveg-map
# foliar_cover/akveg_foliar_cover_v2p0/picgla_10m_3338
# https://earthengine.googleapis.com/v1alpha/projects/{}/assets?assetId={}
# {'bands': [{'dataType': {'precision': 'INT', 'range': {'max': 255}},
#             'grid': {'affineTransform': {'scaleX': 10,
#                                          'scaleY': -10,
#                                          'translateX': -2180085,
#                                          'translateY': 2388175},
#                      'crsCode': 'EPSG:3338',
#                      'dimensions': {'height': 198834, 'width': 307943}},
#             'id': 'B0',
#             'missingData': {'values': [255]},
#             'pyramidingPolicy': 'MEAN'}],
#  'cloudStorageLocation': {'uris': ['gs://akveg-data/rasters_cog/round_20241124_v20250502/picgla_10m_3338.tif']},
#  'geometry': {'coordinates': [[172.20012497418128, 52.982186886504465],
#                               [175.4747218234518, 48.999058895172126],
#                               [180.29620784020125, 50.43544349923501],
#                               [190.8100687957891, 52.55125133460313],
#                               [202.15248711856034, 53.5459341065996],
#                               [213.7218499895904, 53.342957188845844],
#                               [219.37740376964612, 52.79370144982859],
#                               [224.89754188155013, 64.35938664450953],
#                               [227.4227194789508, 67.65074281613498],
#                               [229.6737588501225, 70.01170172602443],
#                               [219.93296818306223, 70.99819311518736],
#                               [199.00395193479872, 71.3717783236605],
#                               [179.34486240270817, 69.58821415327849],
#                               [170.90995247629414, 68.02056726077777],
#                               [157.23664885636, 63.91136146920561],
#                               [168.2234685793636, 56.81734521686287],
#                               [172.20012497418128, 52.982186886504465]],
#               'type': 'LineString'},
#  'id': 'projects/akveg-map/assets/foliar_cover/akveg_foliar_cover_v2p0/picgla_10m_3338',
#  'name': 'projects/akveg-map/assets/foliar_cover/akveg_foliar_cover_v2p0/picgla_10m_3338',
#  'properties': {'pft': 'picgla', 'version': 2},
#  'tilesets': [{'id': '0',
#                'sources': [{'uris': ['gs://akveg-data/rasters_cog/round_20241124_v20250502/picgla_10m_3338.tif']}]}],
#  'type': 'IMAGE',
#  'updateTime': '2025-05-03T17:45:26.745928Z'}
# picmar_10m_3338
# ['picmar', '10m', '3338', 'tif']
# picmar
# akveg-map
# foliar_cover/akveg_foliar_cover_v2p0/picmar_10m_3338
# https://earthengine.googleapis.com/v1alpha/projects/{}/assets?assetId={}
# {'bands': [{'dataType': {'precision': 'INT', 'range': {'max': 255}},
#             'grid': {'affineTransform': {'scaleX': 10,
#                                          'scaleY': -10,
#                                          'translateX': -2180085,
#                                          'translateY': 2388175},
#                      'crsCode': 'EPSG:3338',
#                      'dimensions': {'height': 198834, 'width': 307943}},
#             'id': 'B0',
#             'missingData': {'values': [255]},
#             'pyramidingPolicy': 'MEAN'}],
#  'cloudStorageLocation': {'uris': ['gs://akveg-data/rasters_cog/round_20241124_v20250502/picmar_10m_3338.tif']},
#  'geometry': {'coordinates': [[172.20012497418128, 52.982186886504465],
#                               [175.4747218234518, 48.999058895172126],
#                               [180.29620784020125, 50.43544349923501],
#                               [190.8100687957891, 52.55125133460313],
#                               [202.15248711856034, 53.5459341065996],
#                               [213.7218499895904, 53.342957188845844],
#                               [219.37740376964612, 52.79370144982859],
#                               [224.89754188155013, 64.35938664450953],
#                               [227.4227194789508, 67.65074281613498],
#                               [229.6737588501225, 70.01170172602443],
#                               [219.93296818306223, 70.99819311518736],
#                               [199.00395193479872, 71.3717783236605],
#                               [179.34486240270817, 69.58821415327849],
#                               [170.90995247629414, 68.02056726077777],
#                               [157.23664885636, 63.91136146920561],
#                               [168.2234685793636, 56.81734521686287],
#                               [172.20012497418128, 52.982186886504465]],
#               'type': 'LineString'},
#  'id': 'projects/akveg-map/assets/foliar_cover/akveg_foliar_cover_v2p0/picmar_10m_3338',
#  'name': 'projects/akveg-map/assets/foliar_cover/akveg_foliar_cover_v2p0/picmar_10m_3338',
#  'properties': {'pft': 'picmar', 'version': 2},
#  'tilesets': [{'id': '0',
#                'sources': [{'uris': ['gs://akveg-data/rasters_cog/round_20241124_v20250502/picmar_10m_3338.tif']}]}],
#  'type': 'IMAGE',
#  'updateTime': '2025-05-03T17:45:28.067351Z'}
# picsit_10m_3338
# ['picsit', '10m', '3338', 'tif']
# picsit
# akveg-map
# foliar_cover/akveg_foliar_cover_v2p0/picsit_10m_3338
# https://earthengine.googleapis.com/v1alpha/projects/{}/assets?assetId={}
# {'bands': [{'dataType': {'precision': 'INT', 'range': {'max': 255}},
#             'grid': {'affineTransform': {'scaleX': 10,
#                                          'scaleY': -10,
#                                          'translateX': -2180085,
#                                          'translateY': 2388175},
#                      'crsCode': 'EPSG:3338',
#                      'dimensions': {'height': 198834, 'width': 307943}},
#             'id': 'B0',
#             'missingData': {'values': [255]},
#             'pyramidingPolicy': 'MEAN'}],
#  'cloudStorageLocation': {'uris': ['gs://akveg-data/rasters_cog/round_20241124_v20250502/picsit_10m_3338.tif']},
#  'geometry': {'coordinates': [[172.20012497418128, 52.982186886504465],
#                               [175.4747218234518, 48.999058895172126],
#                               [180.29620784020125, 50.43544349923501],
#                               [190.8100687957891, 52.55125133460313],
#                               [202.15248711856034, 53.5459341065996],
#                               [213.7218499895904, 53.342957188845844],
#                               [219.37740376964612, 52.79370144982859],
#                               [224.89754188155013, 64.35938664450953],
#                               [227.4227194789508, 67.65074281613498],
#                               [229.6737588501225, 70.01170172602443],
#                               [219.93296818306223, 70.99819311518736],
#                               [199.00395193479872, 71.3717783236605],
#                               [179.34486240270817, 69.58821415327849],
#                               [170.90995247629414, 68.02056726077777],
#                               [157.23664885636, 63.91136146920561],
#                               [168.2234685793636, 56.81734521686287],
#                               [172.20012497418128, 52.982186886504465]],
#               'type': 'LineString'},
#  'id': 'projects/akveg-map/assets/foliar_cover/akveg_foliar_cover_v2p0/picsit_10m_3338',
#  'name': 'projects/akveg-map/assets/foliar_cover/akveg_foliar_cover_v2p0/picsit_10m_3338',
#  'properties': {'pft': 'picsit', 'version': 2},
#  'tilesets': [{'id': '0',
#                'sources': [{'uris': ['gs://akveg-data/rasters_cog/round_20241124_v20250502/picsit_10m_3338.tif']}]}],
#  'type': 'IMAGE',
#  'updateTime': '2025-05-03T17:45:29.651232Z'}
# poptre_10m_3338
# ['poptre', '10m', '3338', 'tif']
# poptre
# akveg-map
# foliar_cover/akveg_foliar_cover_v2p0/poptre_10m_3338
# https://earthengine.googleapis.com/v1alpha/projects/{}/assets?assetId={}
# {'bands': [{'dataType': {'precision': 'INT', 'range': {'max': 255}},
#             'grid': {'affineTransform': {'scaleX': 10,
#                                          'scaleY': -10,
#                                          'translateX': -2180085,
#                                          'translateY': 2388175},
#                      'crsCode': 'EPSG:3338',
#                      'dimensions': {'height': 198834, 'width': 307943}},
#             'id': 'B0',
#             'missingData': {'values': [255]},
#             'pyramidingPolicy': 'MEAN'}],
#  'cloudStorageLocation': {'uris': ['gs://akveg-data/rasters_cog/round_20241124_v20250502/poptre_10m_3338.tif']},
#  'geometry': {'coordinates': [[172.20012497418128, 52.982186886504465],
#                               [175.4747218234518, 48.999058895172126],
#                               [180.29620784020125, 50.43544349923501],
#                               [190.8100687957891, 52.55125133460313],
#                               [202.15248711856034, 53.5459341065996],
#                               [213.7218499895904, 53.342957188845844],
#                               [219.37740376964612, 52.79370144982859],
#                               [224.89754188155013, 64.35938664450953],
#                               [227.4227194789508, 67.65074281613498],
#                               [229.6737588501225, 70.01170172602443],
#                               [219.93296818306223, 70.99819311518736],
#                               [199.00395193479872, 71.3717783236605],
#                               [179.34486240270817, 69.58821415327849],
#                               [170.90995247629414, 68.02056726077777],
#                               [157.23664885636, 63.91136146920561],
#                               [168.2234685793636, 56.81734521686287],
#                               [172.20012497418128, 52.982186886504465]],
#               'type': 'LineString'},
#  'id': 'projects/akveg-map/assets/foliar_cover/akveg_foliar_cover_v2p0/poptre_10m_3338',
#  'name': 'projects/akveg-map/assets/foliar_cover/akveg_foliar_cover_v2p0/poptre_10m_3338',
#  'properties': {'pft': 'poptre', 'version': 2},
#  'tilesets': [{'id': '0',
#                'sources': [{'uris': ['gs://akveg-data/rasters_cog/round_20241124_v20250502/poptre_10m_3338.tif']}]}],
#  'type': 'IMAGE',
#  'updateTime': '2025-05-03T17:45:31.148455Z'}
# populbt_10m_3338
# ['populbt', '10m', '3338', 'tif']
# populbt
# akveg-map
# foliar_cover/akveg_foliar_cover_v2p0/populbt_10m_3338
# https://earthengine.googleapis.com/v1alpha/projects/{}/assets?assetId={}
# {'bands': [{'dataType': {'precision': 'INT', 'range': {'max': 255}},
#             'grid': {'affineTransform': {'scaleX': 10,
#                                          'scaleY': -10,
#                                          'translateX': -2180085,
#                                          'translateY': 2388175},
#                      'crsCode': 'EPSG:3338',
#                      'dimensions': {'height': 198834, 'width': 307943}},
#             'id': 'B0',
#             'missingData': {'values': [255]},
#             'pyramidingPolicy': 'MEAN'}],
#  'cloudStorageLocation': {'uris': ['gs://akveg-data/rasters_cog/round_20241124_v20250502/populbt_10m_3338.tif']},
#  'geometry': {'coordinates': [[172.20012497418128, 52.982186886504465],
#                               [175.4747218234518, 48.999058895172126],
#                               [180.29620784020125, 50.43544349923501],
#                               [190.8100687957891, 52.55125133460313],
#                               [202.15248711856034, 53.5459341065996],
#                               [213.7218499895904, 53.342957188845844],
#                               [219.37740376964612, 52.79370144982859],
#                               [224.89754188155013, 64.35938664450953],
#                               [227.4227194789508, 67.65074281613498],
#                               [229.6737588501225, 70.01170172602443],
#                               [219.93296818306223, 70.99819311518736],
#                               [199.00395193479872, 71.3717783236605],
#                               [179.34486240270817, 69.58821415327849],
#                               [170.90995247629414, 68.02056726077777],
#                               [157.23664885636, 63.91136146920561],
#                               [168.2234685793636, 56.81734521686287],
#                               [172.20012497418128, 52.982186886504465]],
#               'type': 'LineString'},
#  'id': 'projects/akveg-map/assets/foliar_cover/akveg_foliar_cover_v2p0/populbt_10m_3338',
#  'name': 'projects/akveg-map/assets/foliar_cover/akveg_foliar_cover_v2p0/populbt_10m_3338',
#  'properties': {'pft': 'populbt', 'version': 2},
#  'tilesets': [{'id': '0',
#                'sources': [{'uris': ['gs://akveg-data/rasters_cog/round_20241124_v20250502/populbt_10m_3338.tif']}]}],
#  'type': 'IMAGE',
#  'updateTime': '2025-05-03T17:45:32.676086Z'}
# rhoshr_10m_3338
# ['rhoshr', '10m', '3338', 'tif']
# rhoshr
# akveg-map
# foliar_cover/akveg_foliar_cover_v2p0/rhoshr_10m_3338
# https://earthengine.googleapis.com/v1alpha/projects/{}/assets?assetId={}
# {'bands': [{'dataType': {'precision': 'INT', 'range': {'max': 255}},
#             'grid': {'affineTransform': {'scaleX': 10,
#                                          'scaleY': -10,
#                                          'translateX': -2180085,
#                                          'translateY': 2388175},
#                      'crsCode': 'EPSG:3338',
#                      'dimensions': {'height': 198834, 'width': 307943}},
#             'id': 'B0',
#             'missingData': {'values': [255]},
#             'pyramidingPolicy': 'MEAN'}],
#  'cloudStorageLocation': {'uris': ['gs://akveg-data/rasters_cog/round_20241124_v20250502/rhoshr_10m_3338.tif']},
#  'geometry': {'coordinates': [[172.20012497418128, 52.982186886504465],
#                               [175.4747218234518, 48.999058895172126],
#                               [180.29620784020125, 50.43544349923501],
#                               [190.8100687957891, 52.55125133460313],
#                               [202.15248711856034, 53.5459341065996],
#                               [213.7218499895904, 53.342957188845844],
#                               [219.37740376964612, 52.79370144982859],
#                               [224.89754188155013, 64.35938664450953],
#                               [227.4227194789508, 67.65074281613498],
#                               [229.6737588501225, 70.01170172602443],
#                               [219.93296818306223, 70.99819311518736],
#                               [199.00395193479872, 71.3717783236605],
#                               [179.34486240270817, 69.58821415327849],
#                               [170.90995247629414, 68.02056726077777],
#                               [157.23664885636, 63.91136146920561],
#                               [168.2234685793636, 56.81734521686287],
#                               [172.20012497418128, 52.982186886504465]],
#               'type': 'LineString'},
#  'id': 'projects/akveg-map/assets/foliar_cover/akveg_foliar_cover_v2p0/rhoshr_10m_3338',
#  'name': 'projects/akveg-map/assets/foliar_cover/akveg_foliar_cover_v2p0/rhoshr_10m_3338',
#  'properties': {'pft': 'rhoshr', 'version': 2},
#  'tilesets': [{'id': '0',
#                'sources': [{'uris': ['gs://akveg-data/rasters_cog/round_20241124_v20250502/rhoshr_10m_3338.tif']}]}],
#  'type': 'IMAGE',
#  'updateTime': '2025-05-03T17:45:34.027930Z'}
# rubspe_10m_3338
# ['rubspe', '10m', '3338', 'tif']
# rubspe
# akveg-map
# foliar_cover/akveg_foliar_cover_v2p0/rubspe_10m_3338
# https://earthengine.googleapis.com/v1alpha/projects/{}/assets?assetId={}
# {'bands': [{'dataType': {'precision': 'INT', 'range': {'max': 255}},
#             'grid': {'affineTransform': {'scaleX': 10,
#                                          'scaleY': -10,
#                                          'translateX': -2180085,
#                                          'translateY': 2388175},
#                      'crsCode': 'EPSG:3338',
#                      'dimensions': {'height': 198834, 'width': 307943}},
#             'id': 'B0',
#             'missingData': {'values': [255]},
#             'pyramidingPolicy': 'MEAN'}],
#  'cloudStorageLocation': {'uris': ['gs://akveg-data/rasters_cog/round_20241124_v20250502/rubspe_10m_3338.tif']},
#  'geometry': {'coordinates': [[172.20012497418128, 52.982186886504465],
#                               [175.4747218234518, 48.999058895172126],
#                               [180.29620784020125, 50.43544349923501],
#                               [190.8100687957891, 52.55125133460313],
#                               [202.15248711856034, 53.5459341065996],
#                               [213.7218499895904, 53.342957188845844],
#                               [219.37740376964612, 52.79370144982859],
#                               [224.89754188155013, 64.35938664450953],
#                               [227.4227194789508, 67.65074281613498],
#                               [229.6737588501225, 70.01170172602443],
#                               [219.93296818306223, 70.99819311518736],
#                               [199.00395193479872, 71.3717783236605],
#                               [179.34486240270817, 69.58821415327849],
#                               [170.90995247629414, 68.02056726077777],
#                               [157.23664885636, 63.91136146920561],
#                               [168.2234685793636, 56.81734521686287],
#                               [172.20012497418128, 52.982186886504465]],
#               'type': 'LineString'},
#  'id': 'projects/akveg-map/assets/foliar_cover/akveg_foliar_cover_v2p0/rubspe_10m_3338',
#  'name': 'projects/akveg-map/assets/foliar_cover/akveg_foliar_cover_v2p0/rubspe_10m_3338',
#  'properties': {'pft': 'rubspe', 'version': 2},
#  'tilesets': [{'id': '0',
#                'sources': [{'uris': ['gs://akveg-data/rasters_cog/round_20241124_v20250502/rubspe_10m_3338.tif']}]}],
#  'type': 'IMAGE',
#  'updateTime': '2025-05-03T17:45:35.365687Z'}
# sphagn_10m_3338
# ['sphagn', '10m', '3338', 'tif']
# sphagn
# akveg-map
# foliar_cover/akveg_foliar_cover_v2p0/sphagn_10m_3338
# https://earthengine.googleapis.com/v1alpha/projects/{}/assets?assetId={}
# {'bands': [{'dataType': {'precision': 'INT', 'range': {'max': 255}},
#             'grid': {'affineTransform': {'scaleX': 10,
#                                          'scaleY': -10,
#                                          'translateX': -2180085,
#                                          'translateY': 2388175},
#                      'crsCode': 'EPSG:3338',
#                      'dimensions': {'height': 198834, 'width': 307943}},
#             'id': 'B0',
#             'missingData': {'values': [255]},
#             'pyramidingPolicy': 'MEAN'}],
#  'cloudStorageLocation': {'uris': ['gs://akveg-data/rasters_cog/round_20241124_v20250502/sphagn_10m_3338.tif']},
#  'geometry': {'coordinates': [[172.20012497418128, 52.982186886504465],
#                               [175.4747218234518, 48.999058895172126],
#                               [180.29620784020125, 50.43544349923501],
#                               [190.8100687957891, 52.55125133460313],
#                               [202.15248711856034, 53.5459341065996],
#                               [213.7218499895904, 53.342957188845844],
#                               [219.37740376964612, 52.79370144982859],
#                               [224.89754188155013, 64.35938664450953],
#                               [227.4227194789508, 67.65074281613498],
#                               [229.6737588501225, 70.01170172602443],
#                               [219.93296818306223, 70.99819311518736],
#                               [199.00395193479872, 71.3717783236605],
#                               [179.34486240270817, 69.58821415327849],
#                               [170.90995247629414, 68.02056726077777],
#                               [157.23664885636, 63.91136146920561],
#                               [168.2234685793636, 56.81734521686287],
#                               [172.20012497418128, 52.982186886504465]],
#               'type': 'LineString'},
#  'id': 'projects/akveg-map/assets/foliar_cover/akveg_foliar_cover_v2p0/sphagn_10m_3338',
#  'name': 'projects/akveg-map/assets/foliar_cover/akveg_foliar_cover_v2p0/sphagn_10m_3338',
#  'properties': {'pft': 'sphagn', 'version': 2},
#  'tilesets': [{'id': '0',
#                'sources': [{'uris': ['gs://akveg-data/rasters_cog/round_20241124_v20250502/sphagn_10m_3338.tif']}]}],
#  'type': 'IMAGE',
#  'updateTime': '2025-05-03T17:45:36.654683Z'}
# tsumer_10m_3338
# ['tsumer', '10m', '3338', 'tif']
# tsumer
# akveg-map
# foliar_cover/akveg_foliar_cover_v2p0/tsumer_10m_3338
# https://earthengine.googleapis.com/v1alpha/projects/{}/assets?assetId={}
# {'bands': [{'dataType': {'precision': 'INT', 'range': {'max': 255}},
#             'grid': {'affineTransform': {'scaleX': 10,
#                                          'scaleY': -10,
#                                          'translateX': -2180085,
#                                          'translateY': 2388175},
#                      'crsCode': 'EPSG:3338',
#                      'dimensions': {'height': 198834, 'width': 307943}},
#             'id': 'B0',
#             'missingData': {'values': [255]},
#             'pyramidingPolicy': 'MEAN'}],
#  'cloudStorageLocation': {'uris': ['gs://akveg-data/rasters_cog/round_20241124_v20250502/tsumer_10m_3338.tif']},
#  'geometry': {'coordinates': [[172.20012497418128, 52.982186886504465],
#                               [175.4747218234518, 48.999058895172126],
#                               [180.29620784020125, 50.43544349923501],
#                               [190.8100687957891, 52.55125133460313],
#                               [202.15248711856034, 53.5459341065996],
#                               [213.7218499895904, 53.342957188845844],
#                               [219.37740376964612, 52.79370144982859],
#                               [224.89754188155013, 64.35938664450953],
#                               [227.4227194789508, 67.65074281613498],
#                               [229.6737588501225, 70.01170172602443],
#                               [219.93296818306223, 70.99819311518736],
#                               [199.00395193479872, 71.3717783236605],
#                               [179.34486240270817, 69.58821415327849],
#                               [170.90995247629414, 68.02056726077777],
#                               [157.23664885636, 63.91136146920561],
#                               [168.2234685793636, 56.81734521686287],
#                               [172.20012497418128, 52.982186886504465]],
#               'type': 'LineString'},
#  'id': 'projects/akveg-map/assets/foliar_cover/akveg_foliar_cover_v2p0/tsumer_10m_3338',
#  'name': 'projects/akveg-map/assets/foliar_cover/akveg_foliar_cover_v2p0/tsumer_10m_3338',
#  'properties': {'pft': 'tsumer', 'version': 2},
#  'tilesets': [{'id': '0',
#                'sources': [{'uris': ['gs://akveg-data/rasters_cog/round_20241124_v20250502/tsumer_10m_3338.tif']}]}],
#  'type': 'IMAGE',
#  'updateTime': '2025-05-03T17:45:38.369493Z'}
# vaculi_10m_3338
# ['vaculi', '10m', '3338', 'tif']
# vaculi
# akveg-map
# foliar_cover/akveg_foliar_cover_v2p0/vaculi_10m_3338
# https://earthengine.googleapis.com/v1alpha/projects/{}/assets?assetId={}
# {'bands': [{'dataType': {'precision': 'INT', 'range': {'max': 255}},
#             'grid': {'affineTransform': {'scaleX': 10,
#                                          'scaleY': -10,
#                                          'translateX': -2180085,
#                                          'translateY': 2388175},
#                      'crsCode': 'EPSG:3338',
#                      'dimensions': {'height': 198834, 'width': 307943}},
#             'id': 'B0',
#             'missingData': {'values': [255]},
#             'pyramidingPolicy': 'MEAN'}],
#  'cloudStorageLocation': {'uris': ['gs://akveg-data/rasters_cog/round_20241124_v20250502/vaculi_10m_3338.tif']},
#  'geometry': {'coordinates': [[172.20012497418128, 52.982186886504465],
#                               [175.4747218234518, 48.999058895172126],
#                               [180.29620784020125, 50.43544349923501],
#                               [190.8100687957891, 52.55125133460313],
#                               [202.15248711856034, 53.5459341065996],
#                               [213.7218499895904, 53.342957188845844],
#                               [219.37740376964612, 52.79370144982859],
#                               [224.89754188155013, 64.35938664450953],
#                               [227.4227194789508, 67.65074281613498],
#                               [229.6737588501225, 70.01170172602443],
#                               [219.93296818306223, 70.99819311518736],
#                               [199.00395193479872, 71.3717783236605],
#                               [179.34486240270817, 69.58821415327849],
#                               [170.90995247629414, 68.02056726077777],
#                               [157.23664885636, 63.91136146920561],
#                               [168.2234685793636, 56.81734521686287],
#                               [172.20012497418128, 52.982186886504465]],
#               'type': 'LineString'},
#  'id': 'projects/akveg-map/assets/foliar_cover/akveg_foliar_cover_v2p0/vaculi_10m_3338',
#  'name': 'projects/akveg-map/assets/foliar_cover/akveg_foliar_cover_v2p0/vaculi_10m_3338',
#  'properties': {'pft': 'vaculi', 'version': 2},
#  'tilesets': [{'id': '0',
#                'sources': [{'uris': ['gs://akveg-data/rasters_cog/round_20241124_v20250502/vaculi_10m_3338.tif']}]}],
#  'type': 'IMAGE',
#  'updateTime': '2025-05-03T17:45:39.719990Z'}
# vacvit_10m_3338
# ['vacvit', '10m', '3338', 'tif']
# vacvit
# akveg-map
# foliar_cover/akveg_foliar_cover_v2p0/vacvit_10m_3338
# https://earthengine.googleapis.com/v1alpha/projects/{}/assets?assetId={}
# {'bands': [{'dataType': {'precision': 'INT', 'range': {'max': 255}},
#             'grid': {'affineTransform': {'scaleX': 10,
#                                          'scaleY': -10,
#                                          'translateX': -2180085,
#                                          'translateY': 2388175},
#                      'crsCode': 'EPSG:3338',
#                      'dimensions': {'height': 198834, 'width': 307943}},
#             'id': 'B0',
#             'missingData': {'values': [255]},
#             'pyramidingPolicy': 'MEAN'}],
#  'cloudStorageLocation': {'uris': ['gs://akveg-data/rasters_cog/round_20241124_v20250502/vacvit_10m_3338.tif']},
#  'geometry': {'coordinates': [[172.20012497418128, 52.982186886504465],
#                               [175.4747218234518, 48.999058895172126],
#                               [180.29620784020125, 50.43544349923501],
#                               [190.8100687957891, 52.55125133460313],
#                               [202.15248711856034, 53.5459341065996],
#                               [213.7218499895904, 53.342957188845844],
#                               [219.37740376964612, 52.79370144982859],
#                               [224.89754188155013, 64.35938664450953],
#                               [227.4227194789508, 67.65074281613498],
#                               [229.6737588501225, 70.01170172602443],
#                               [219.93296818306223, 70.99819311518736],
#                               [199.00395193479872, 71.3717783236605],
#                               [179.34486240270817, 69.58821415327849],
#                               [170.90995247629414, 68.02056726077777],
#                               [157.23664885636, 63.91136146920561],
#                               [168.2234685793636, 56.81734521686287],
#                               [172.20012497418128, 52.982186886504465]],
#               'type': 'LineString'},
#  'id': 'projects/akveg-map/assets/foliar_cover/akveg_foliar_cover_v2p0/vacvit_10m_3338',
#  'name': 'projects/akveg-map/assets/foliar_cover/akveg_foliar_cover_v2p0/vacvit_10m_3338',
#  'properties': {'pft': 'vacvit', 'version': 2},
#  'tilesets': [{'id': '0',
#                'sources': [{'uris': ['gs://akveg-data/rasters_cog/round_20241124_v20250502/vacvit_10m_3338.tif']}]}],
#  'type': 'IMAGE',
#  'updateTime': '2025-05-03T17:45:40.945370Z'}
# wetsed_10m_3338
# ['wetsed', '10m', '3338', 'tif']
# wetsed
# akveg-map
# foliar_cover/akveg_foliar_cover_v2p0/wetsed_10m_3338
# https://earthengine.googleapis.com/v1alpha/projects/{}/assets?assetId={}
# {'bands': [{'dataType': {'precision': 'INT', 'range': {'max': 255}},
#             'grid': {'affineTransform': {'scaleX': 10,
#                                          'scaleY': -10,
#                                          'translateX': -2180085,
#                                          'translateY': 2388175},
#                      'crsCode': 'EPSG:3338',
#                      'dimensions': {'height': 198834, 'width': 307943}},
#             'id': 'B0',
#             'missingData': {'values': [255]},
#             'pyramidingPolicy': 'MEAN'}],
#  'cloudStorageLocation': {'uris': ['gs://akveg-data/rasters_cog/round_20241124_v20250502/wetsed_10m_3338.tif']},
#  'geometry': {'coordinates': [[172.20012497418128, 52.982186886504465],
#                               [175.4747218234518, 48.999058895172126],
#                               [180.29620784020125, 50.43544349923501],
#                               [190.8100687957891, 52.55125133460313],
#                               [202.15248711856034, 53.5459341065996],
#                               [213.7218499895904, 53.342957188845844],
#                               [219.37740376964612, 52.79370144982859],
#                               [224.89754188155013, 64.35938664450953],
#                               [227.4227194789508, 67.65074281613498],
#                               [229.6737588501225, 70.01170172602443],
#                               [219.93296818306223, 70.99819311518736],
#                               [199.00395193479872, 71.3717783236605],
#                               [179.34486240270817, 69.58821415327849],
#                               [170.90995247629414, 68.02056726077777],
#                               [157.23664885636, 63.91136146920561],
#                               [168.2234685793636, 56.81734521686287],
#                               [172.20012497418128, 52.982186886504465]],
#               'type': 'LineString'},
#  'id': 'projects/akveg-map/assets/foliar_cover/akveg_foliar_cover_v2p0/wetsed_10m_3338',
#  'name': 'projects/akveg-map/assets/foliar_cover/akveg_foliar_cover_v2p0/wetsed_10m_3338',
#  'properties': {'pft': 'wetsed', 'version': 2},
#  'tilesets': [{'id': '0',
#                'sources': [{'uris': ['gs://akveg-data/rasters_cog/round_20241124_v20250502/wetsed_10m_3338.tif']}]}],
#  'type': 'IMAGE',
#  'updateTime': '2025-05-03T17:45:42.370678Z'}
# done
