# %% [markdown]
# # Cloud COGs to Image Collection

# %% [markdown]
# ## Setup

# %%
import ee
ee_project = 'akveg-map'

ee.Authenticate(auth_mode='notebook')  #  or !earthengine authenticate --auth_mode=gcloud

ee.Initialize(project=ee_project)
# ee.Authenticate()  #  or !earthengine authenticate --auth_mode=gcloud
# session = AuthorizedSession(ee.data.get_persistent_credentials())

# %%
import pandas as pd
from pathlib import Path
from datetime import datetime, timezone
import os
import re

from google.auth.transport.requests import AuthorizedSession

session = AuthorizedSession(
    ee.data.get_persistent_credentials().with_quota_project(ee_project)
)

# %% [markdown]
# ## Dynamic World Counts, raw by MGRS tile

# %% [markdown]
# ### Cleanup existing imageCollection, if needed
#
# imageCollections cannot be deleted until all images inside them are deleted. For a cloud-backed image collection with hundreds or thousands of tiles, this can take a while
#
# bash earthengine CLI
# ```
# for i in `earthengine ls projects/akveg-map/assets/dynamic_world_metrics/s2_dw_monthly_counts_mgrs_v20250414b`; do earthengine rm $i; done
#
# # earthengine rm projects/akveg-map/assets/s2_2019_2023_gMedian_v20240311
# ```

# %% [markdown]
# ### Create empty image collections as target
# TODO Automate creation of empty image collection.
#
# For now, manually create empty image collection with earthengine CLI

# %% [markdown]
# ```
# earthengine set_project akveg-map
# earthengine create collection projects/akveg-map/assets/dynamic_world_metrics/s2_dw_monthly_counts_mgrs_v20250414b
# ```

# %% [markdown]
# ### Create list of cloud geotiffs in bucket and image collection
#
# Create list of cogs in a bucket folder to load into an imageCollection.
#
# Create list of cogs that have already been loaded into the imageCollection.
#
# Run in bash in a conda env with gsutil and earthengine command line installed and authenticated.
#
# TODO: Configure it to run directly in python

# %% [markdown]
# ```
# cd /data/gis/raster_base/Alaska/AKVegMap/dynamic_world
#
# gsutil ls gs://akveg-data/s2_dw_v1_metrics/s2_dw_monthly_counts_mgrs_v20250414b/*.tif > dw_monthly_cogs.txt
# earthengine ls projects/akveg-map/assets/dynamic_world_metrics/s2_dw_monthly_counts_mgrs_v20250414b > dw_monthly_cogs_inColl.txt
#
# ```

# %%
# Function to read a text file and return a list of paths
def read_paths_from_file(filepath):
    with open(filepath, 'r') as file:
        paths = file.read().splitlines()
    return paths

# Function to extract the last part of the path and remove the extension
def get_filename_without_extension(path):
    return os.path.splitext(os.path.basename(path))[0]


# Function to save a list of paths to a text file
def save_paths_to_file(paths, filepath):
    with open(filepath, 'w') as file:
        for path in paths:
            file.write(f"{path}\n")

def in_list_1_not_list_2(csv1_path, csv2_path):
    cogList = read_paths_from_file(csv1_path)
    cogListIC = read_paths_from_file(csv2_path)
    
    filenames1 = [get_filename_without_extension(path) for path in cogList]
    filenames2 = [get_filename_without_extension(path) for path in cogListIC]
    
    # Convert lists to pd Series
    filenames_series1 = pd.Series(filenames1, index=cogList)
    filenames_series2 = pd.Series(filenames2, index=cogListIC)
    
    # Find filenames in list1 that are not in list2
    unique_to_list1 = filenames_series1[~filenames_series1.isin(filenames2)]
    
    print("\nPaths in list1 that are not in list2 based on filenames:")
    print(unique_to_list1.index.tolist()[:5])
    print(len(unique_to_list1.index.tolist()))
    
    return unique_to_list1

# %%
# Apply the functions to for full list and already loaded list of vhr_toa_cogs
unique_to_list1 = in_list_1_not_list_2('/data/gis/raster_base/Alaska/AKVegMap/dynamic_world/dw_monthly_cogs.txt',
                                       '/data/gis/raster_base/Alaska/AKVegMap/dynamic_world/dw_monthly_cogs_inColl.txt')

save_paths_to_file(unique_to_list1.index.tolist(), '/data/gis/raster_base/Alaska/AKVegMap/dynamic_world/dw_monthly_cogs_not_inColl.txt')
# Out:
# Paths in list1 that are not in list2 based on filenames:
# ['gs://akveg-data/s2_dw_v1_metrics/s2_dw_monthly_counts_mgrs_v20250414b/s2_dw_counts_mgrs_month05_03UUV_v20250414.tif', 'gs://akveg-data/s2_dw_v1_metrics/s2_dw_monthly_counts_mgrs_v20250414b/s2_dw_counts_mgrs_month06_01UCS_v20250414.tif']
# 2

# %% [markdown]
# ### Open list of geotiffs to ingest

# %%
dw_cogs = pd.read_csv('/data/gis/raster_base/Alaska/AKVegMap/dynamic_world/dw_monthly_cogs_not_inColl.txt', header=None,names=['tif'])
print(dw_cogs[0:2])
print(len(dw_cogs.index))
# Out:
#                                                  tif
# 0  gs://akveg-data/s2_dw_v1_metrics/s2_dw_monthly...
# 1  gs://akveg-data/s2_dw_v1_metrics/s2_dw_monthly...
# 2

# %% [markdown]
# ### Setup parameters

# %%
import json
# from urllib.parse import urlparse
import os
from pprint import pprint

# Earth Engine enabled Cloud Project.
project_folder = 'akveg-map'
# collection = 'reflectance_vhr/ortho_toa_images'

# %% [markdown]
# ### View list of cogs to ingest
# Optional, can skip when list is long.

# %%
for cog in dw_cogs['tif']:
    print(cog)
# Out:
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_monthly_counts_mgrs_v20250414b/s2_dw_counts_mgrs_month05_03UUV_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_monthly_counts_mgrs_v20250414b/s2_dw_counts_mgrs_month06_01UCS_v20250414.tif

# %% [markdown]
# ### Function to load list of gcs cogs to GEE imageCollection
# comment out pprint and most print except when troubleshooting

# %%
#TODO Fix date extraction from filename to work for different filename formats
def load_gcs_cogs_to_collection(cogs, project_folder, collection, month_part, tile_part):
    # Request body as a dictionary.
    for cog in cogs['tif']:
      fileOnly = os.path.split(cog)[1]
      # print(fileOnly)

      cogName = fileOnly[:-4]
      print(cogName)
      
      # parts = fileOnly.split('_')
      # Split on both underscore and period
      parts = re.split(r'[_\.]', fileOnly)
      print(parts)
      
      monthxx = f"{parts[month_part]}"[-2:]
      month = int(monthxx)
      print(month)

      tile = f"{parts[tile_part]}"
      print(tile)

      # dt = datetime.strptime(yyyymmdd_hhmmss, "%Y%m%d_%H%M%S").replace(tzinfo=timezone.utc)
      # dt = f"{dt:%Y-%m-%dT%H:%M:%SZ}"  # Format string for ISO 8601 + Z
      # print(dt)
        
      request = {
        'type': 'IMAGE',
        'gcs_location': {
          'uris': cog
        },
        'properties': {
        #   'source': 'https://code.earthengine.google.com/067b10ee56537817756a3177a9138aee',
            # 'yyyymmdd_hhmmss': yyyymmdd_hhmmss,
            'month': monthxx,
            'tile': tile,
        },
        # 'startTime': dt,#'2023-01-01T00:00:00.000000000Z',
        # 'endTime': dt,#'2024-01-01T00:00:00.000000000Z',
      }

      pprint(json.dumps(request))

      # A folder (or ImageCollection) name and the new asset name.
      asset_id = collection+'/'+cogName
      # print(project_folder)
      # print(asset_id)
        
      url = 'https://earthengine.googleapis.com/v1alpha/projects/{}/assets?assetId={}'
      print(url)
      print(url.format(project_folder, asset_id))

      response = session.post(
        url = url.format(project_folder, asset_id),
        data = json.dumps(request)
      )

      # pprint(json.loads(response.content))
    print('done')

# %% [markdown]
# ### Run it

# %%
load_gcs_cogs_to_collection(dw_cogs, project_folder, 'dynamic_world_metrics/s2_dw_monthly_counts_mgrs_v20250414b', 4, 5)
# Out:
# s2_dw_counts_mgrs_month05_03UUV_v20250414
# ['s2', 'dw', 'counts', 'mgrs', 'month05', '03UUV', 'v20250414', 'tif']
# 5
# 03UUV
# ('{"type": "IMAGE", "gcs_location": {"uris": '
#  '"gs://akveg-data/s2_dw_v1_metrics/s2_dw_monthly_counts_mgrs_v20250414b/s2_dw_counts_mgrs_month05_03UUV_v20250414.tif"}, '
#  '"properties": {"month": "05", "tile": "03UUV"}}')
# https://earthengine.googleapis.com/v1alpha/projects/{}/assets?assetId={}
# https://earthengine.googleapis.com/v1alpha/projects/akveg-map/assets?assetId=dynamic_world_metrics/s2_dw_monthly_counts_mgrs_v20250414b/s2_dw_counts_mgrs_month05_03UUV_v20250414
# s2_dw_counts_mgrs_month06_01UCS_v20250414
# ['s2', 'dw', 'counts', 'mgrs', 'month06', '01UCS', 'v20250414', 'tif']
# 6
# 01UCS
# ('{"type": "IMAGE", "gcs_location": {"uris": '
#  '"gs://akveg-data/s2_dw_v1_metrics/s2_dw_monthly_counts_mgrs_v20250414b/s2_dw_counts_mgrs_month06_01UCS_v20250414.tif"}, '
#  '"properties": {"month": "06", "tile": "01UCS"}}')
# https://earthengine.googleapis.com/v1alpha/projects/{}/assets?assetId={}
# https://earthengine.googleapis.com/v1alpha/projects/akveg-map/assets?assetId=dynamic_world_metrics/s2_dw_monthly_counts_mgrs_v20250414b/s2_dw_counts_mgrs_month06_01UCS_v20250414
# done

# %% [raw]
# Get summary of compute effort (EECUs)
# Note this includes all tasks in queue and some filtering may be required to narrow down to a particular script
#
# To get size and count of exports:
# (ee) mmacander@mason:/data/gis/raster_base/Alaska/AKVegMap/dynamic_world$ gsutil du -sh gs://akveg-data/s2_dw_v1_metrics/s2_dw_monthly_counts_mgrs_v20250414b
# 259.31 GiB   gs://akveg-data/s2_dw_v1_metrics/s2_dw_monthly_counts_mgrs_v20250414b
# (ee) mmacander@mason:/data/gis/raster_base/Alaska/AKVegMap/dynamic_world$ gsutil ls gs://akveg-data/s2_dw_v1_metrics/s2_dw_monthly_counts_mgrs_v20250414b/*.tif | wc -l
# 7
# 53

# %%
import ee
ee.Initialize()

operations = ee.data.listOperations()

# Filter for failed or cancelled tasks
failed_ops = [
    op for op in operations
    if op.get('metadata', {}).get('state') in ['FAILED', 'CANCELLED']
]

# Print summary
for op in failed_ops:
    meta = op['metadata']
    print(f"Task ID: {op['name'].split('/')[-1]}")
    print(f"Description: {meta.get('description', 'N/A')}")
    print(f"State: {meta.get('state')}")
    print(f"Error: {meta.get('errorMessage', 'None')}")
    print('-' * 40)

# Need to redo two (maybe no granules for that month?)
# s2_dw_counts_month05_03UUV_v20250414
# s2_dw_counts_month06_01UCS_v20250414
# Out:
# Task ID: GXLT5QBVB64VCFROC5U47ZMV
# Description: s2_dw_counts_month05_03UUV_v20250414
# State: FAILED
# Error: None
# ----------------------------------------
# Task ID: 273PJSOXO4FQ7GXVGDPDSR52
# Description: s2_dw_counts_month06_01UCS_v20250414
# State: FAILED
# Error: None
# ----------------------------------------
# Task ID: 32BQ2LQ46S6JIDHWVN7Q7NYS
# Description: s2_dw_counts_month07_06VUQ_v20250414
# State: FAILED
# Error: None
# ----------------------------------------
# Task ID: 4GSBFOYQF6U34VUT7EZU4EOY
# Description: s2_dw_counts_month07_06VUQ_v20250414
# State: FAILED
# Error: None
# ----------------------------------------
# Task ID: 6FIFZTCXEMGQGGHGDOLJUWAI
# Description: s2_dw_counts_month07_06VUQ_v20250414
# State: CANCELLED
# Error: None
# ----------------------------------------
# Task ID: UNSCUHRMP243PK23WQ3D2BWX
# Description: s2_dw_counts_month07_06VUQ_v20250414
# State: FAILED
# Error: None
# ----------------------------------------

# %% [markdown]
# ## Dynamic World Percentages (May-Sept) by AKALB 50km tile

# %% [markdown]
# ### Cleanup existing imageCollection, if needed
#
# imageCollections cannot be deleted until all images inside them are deleted. For a cloud-backed image collection with hundreds or thousands of tiles, this can take a while
#
# bash earthengine CLI
# ```
# for i in `earthengine ls projects/akveg-map/assets/dynamic_world_metrics/s2_dw_monthly_counts_mgrs_v20250414b`; do earthengine rm $i; done
#
# # earthengine rm projects/akveg-map/assets/s2_2019_2023_gMedian_v20240311
# ```

# %% [markdown]
# ### Create empty image collections as target
# TODO Automate creation of empty image collection.
#
# For now, manually create empty image collection with earthengine CLI

# %% [markdown]
# ```
# earthengine set_project akveg-map
# earthengine create collection projects/akveg-map/assets/dynamic_world_metrics/s2_dw_percentages_56789_v20250414b
# ```

# %% [markdown]
# ### Create list of cloud geotiffs in bucket and image collection
#
# Create list of cogs in a bucket folder to load into an imageCollection.
#
# Create list of cogs that have already been loaded into the imageCollection.
#
# Run in bash in a conda env with gsutil and earthengine command line installed and authenticated.
#
# TODO: Configure it to run directly in python

# %% [markdown]
# ```
# cd /data/gis/raster_base/Alaska/AKVegMap/dynamic_world
#
# gsutil ls gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/*.tif > dw_percentage_cogs.txt
# earthengine ls projects/akveg-map/assets/dynamic_world_metrics/s2_dw_percentages_56789_v20250414b > dw_percentage_cogs_inColl.txt
#
# ```

# %%
# Function to read a text file and return a list of paths
def read_paths_from_file(filepath):
    with open(filepath, 'r') as file:
        paths = file.read().splitlines()
    return paths

# Function to extract the last part of the path and remove the extension
def get_filename_without_extension(path):
    return os.path.splitext(os.path.basename(path))[0]


# Function to save a list of paths to a text file
def save_paths_to_file(paths, filepath):
    with open(filepath, 'w') as file:
        for path in paths:
            file.write(f"{path}\n")

def in_list_1_not_list_2(csv1_path, csv2_path):
    cogList = read_paths_from_file(csv1_path)
    cogListIC = read_paths_from_file(csv2_path)
    
    filenames1 = [get_filename_without_extension(path) for path in cogList]
    filenames2 = [get_filename_without_extension(path) for path in cogListIC]
    
    # Convert lists to pd Series
    filenames_series1 = pd.Series(filenames1, index=cogList)
    filenames_series2 = pd.Series(filenames2, index=cogListIC)
    
    # Find filenames in list1 that are not in list2
    unique_to_list1 = filenames_series1[~filenames_series1.isin(filenames2)]
    
    print("\nPaths in list1 that are not in list2 based on filenames:")
    print(unique_to_list1.index.tolist()[:5])
    print(len(unique_to_list1.index.tolist()))
    
    return unique_to_list1

# %%
# Apply the functions to for full list and already loaded list of vhr_toa_cogs
unique_to_list1 = in_list_1_not_list_2('/data/gis/raster_base/Alaska/AKVegMap/dynamic_world/dw_percentage_cogs.txt',
                                       '/data/gis/raster_base/Alaska/AKVegMap/dynamic_world/dw_percentage_cogs_inColl.txt')

save_paths_to_file(unique_to_list1.index.tolist(), '/data/gis/raster_base/Alaska/AKVegMap/dynamic_world/dw_percentage_cogs_not_inColl.txt')
# Out:
# Paths in list1 that are not in list2 based on filenames:
# ['gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H45V02_v20250414.tif', 'gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H45V03_v20250414.tif', 'gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H45V04_v20250414.tif', 'gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H45V05_v20250414.tif', 'gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H45V06_v20250414.tif']
# 149

# %% [markdown]
# ### Open list of geotiffs to ingest

# %%
dw_cogs = pd.read_csv('/data/gis/raster_base/Alaska/AKVegMap/dynamic_world/dw_percentage_cogs_not_inColl.txt', header=None,names=['tif'])
print(dw_cogs[0:2])
print(len(dw_cogs.index))
# Out:
#                                                  tif
# 0  gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_aka...
# 1  gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_aka...
# 149

# %% [markdown]
# ### Setup parameters

# %%
import json
# from urllib.parse import urlparse
import os
from pprint import pprint

# Earth Engine enabled Cloud Project.
project_folder = 'akveg-map'
# collection = 'reflectance_vhr/ortho_toa_images'

# %% [markdown]
# ### View list of cogs to ingest
# Optional, can skip when list is long.

# %%
for cog in dw_cogs['tif']:
    print(cog)
# Out:
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H45V02_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H45V03_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H45V04_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H45V05_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H45V06_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H45V07_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H45V08_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H45V09_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H45V10_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H45V11_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H45V12_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H45V13_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H45V14_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H45V15_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H45V16_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H45V17_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H45V18_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H45V19_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H45V20_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H45V21_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H45V22_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H45V23_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H45V24_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H45V25_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H45V26_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H45V27_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H45V28_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H45V29_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H45V30_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H45V31_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H45V32_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H45V33_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H45V34_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H46V02_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H46V03_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H46V04_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H46V05_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H46V06_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H46V07_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H46V08_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H46V09_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H46V10_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H46V11_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H46V12_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H46V13_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H46V14_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H46V15_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H46V16_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H46V17_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H46V18_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H46V19_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H46V20_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H46V21_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H46V22_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H46V23_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H46V24_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H46V25_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H46V26_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H46V27_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H46V28_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H46V29_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H46V30_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H46V31_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H46V32_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H46V33_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H47V02_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H47V03_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H47V04_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H47V05_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H47V06_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H47V07_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H47V08_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H47V09_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H47V10_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H47V11_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H47V12_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H47V13_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H47V14_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H47V15_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H47V16_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H47V17_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H47V18_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H47V19_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H47V20_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H47V21_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H47V22_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H47V23_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H47V24_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H47V25_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H47V26_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H47V27_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H47V28_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H47V29_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H47V30_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H47V31_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H47V32_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H48V02_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H48V03_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H48V04_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H48V05_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H48V06_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H48V07_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H48V08_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H48V09_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H48V10_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H48V11_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H48V12_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H48V13_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H48V14_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H48V15_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H48V16_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H48V17_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H48V18_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H48V19_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H48V20_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H48V21_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H48V22_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H48V23_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H48V24_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H48V25_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H48V26_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H48V27_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H48V28_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H49V03_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H49V04_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H49V05_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H49V06_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H49V07_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H49V08_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H49V09_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H49V10_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H49V11_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H49V12_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H49V13_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H49V14_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H49V15_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H49V16_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H49V17_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H49V18_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H49V19_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H49V20_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H49V21_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H49V22_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H49V23_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H49V24_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H49V25_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H49V26_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H49V27_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H49V28_v20250414.tif

# %% [markdown]
# ### Function to load list of gcs cogs to GEE imageCollection
# comment out pprint and most print except when troubleshooting

# %%
#TODO Fix date extraction from filename to work for different filename formats
def load_gcs_cogs_to_collection(cogs, project_folder, collection, month_part, tile_part, version_counts_part):
    # Request body as a dictionary.
    for cog in cogs['tif']:
      fileOnly = os.path.split(cog)[1]
      # print(fileOnly)

      cogName = fileOnly[:-4]
      print(cogName)
      
      # parts = fileOnly.split('_')
      # Split on both underscore and period
      parts = re.split(r'[_\.]', fileOnly)
      print(parts)
      
      months = parts[month_part]
      # month = int(monthxx)
      print(months)

      tile = f"{parts[tile_part]}"
      print(tile)

      version_counts = f"{parts[version_counts_part]}"
      print(version_counts)

      # dt = datetime.strptime(yyyymmdd_hhmmss, "%Y%m%d_%H%M%S").replace(tzinfo=timezone.utc)
      # dt = f"{dt:%Y-%m-%dT%H:%M:%SZ}"  # Format string for ISO 8601 + Z
      # print(dt)
        
      request = {
        'type': 'IMAGE',
        'gcs_location': {
          'uris': cog
        },
        'properties': {
        #   'source': 'https://code.earthengine.google.com/067b10ee56537817756a3177a9138aee',
            # 'yyyymmdd_hhmmss': yyyymmdd_hhmmss,
            'months': months,
            'tile': tile,
            'version_counts': version_counts
        },
        # 'startTime': dt,#'2023-01-01T00:00:00.000000000Z',
        # 'endTime': dt,#'2024-01-01T00:00:00.000000000Z',
      }

      pprint(json.dumps(request))

      # A folder (or ImageCollection) name and the new asset name.
      asset_id = collection+'/'+cogName
      # print(project_folder)
      # print(asset_id)
        
      url = 'https://earthengine.googleapis.com/v1alpha/projects/{}/assets?assetId={}'
      print(url)
      print(url.format(project_folder, asset_id))

      response = session.post(
        url = url.format(project_folder, asset_id),
        data = json.dumps(request)
      )

      # pprint(json.loads(response.content))
    print('done')

# %% [markdown]
# ### Run it

# %%
load_gcs_cogs_to_collection(dw_cogs, project_folder, 'dynamic_world_metrics/s2_dw_percentages_56789_v20250414', 3, 4, 5)
# Out:
# s2_dw_pct_56789_AK050H45V02_v20250414
# ['s2', 'dw', 'pct', '56789', 'AK050H45V02', 'v20250414', 'tif']
# 56789
# AK050H45V02
# v20250414
# ('{"type": "IMAGE", "gcs_location": {"uris": '
#  '"gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H45V02_v20250414.tif"}, '
#  '"properties": {"months": "56789", "tile": "AK050H45V02", "version_counts": '
#  '"v20250414"}}')
# https://earthengine.googleapis.com/v1alpha/projects/{}/assets?assetId={}
# https://earthengine.googleapis.com/v1alpha/projects/akveg-map/assets?assetId=dynamic_world_metrics/s2_dw_percentages_56789_v20250414/s2_dw_pct_56789_AK050H45V02_v20250414
# s2_dw_pct_56789_AK050H45V03_v20250414
# ['s2', 'dw', 'pct', '56789', 'AK050H45V03', 'v20250414', 'tif']
# 56789
# AK050H45V03
# v20250414
# ('{"type": "IMAGE", "gcs_location": {"uris": '
#  '"gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H45V03_v20250414.tif"}, '
#  '"properties": {"months": "56789", "tile": "AK050H45V03", "version_counts": '
#  '"v20250414"}}')
# https://earthengine.googleapis.com/v1alpha/projects/{}/assets?assetId={}
# https://earthengine.googleapis.com/v1alpha/projects/akveg-map/assets?assetId=dynamic_world_metrics/s2_dw_percentages_56789_v20250414/s2_dw_pct_56789_AK050H45V03_v20250414
# s2_dw_pct_56789_AK050H45V04_v20250414
# ['s2', 'dw', 'pct', '56789', 'AK050H45V04', 'v20250414', 'tif']
# 56789
# AK050H45V04
# v20250414
# ('{"type": "IMAGE", "gcs_location": {"uris": '
#  '"gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H45V04_v20250414.tif"}, '
#  '"properties": {"months": "56789", "tile": "AK050H45V04", "version_counts": '
#  '"v20250414"}}')
# https://earthengine.googleapis.com/v1alpha/projects/{}/assets?assetId={}
# https://earthengine.googleapis.com/v1alpha/projects/akveg-map/assets?assetId=dynamic_world_metrics/s2_dw_percentages_56789_v20250414/s2_dw_pct_56789_AK050H45V04_v20250414
# s2_dw_pct_56789_AK050H45V05_v20250414
# ['s2', 'dw', 'pct', '56789', 'AK050H45V05', 'v20250414', 'tif']
# 56789
# AK050H45V05
# v20250414
# ('{"type": "IMAGE", "gcs_location": {"uris": '
#  '"gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H45V05_v20250414.tif"}, '
#  '"properties": {"months": "56789", "tile": "AK050H45V05", "version_counts": '
#  '"v20250414"}}')
# https://earthengine.googleapis.com/v1alpha/projects/{}/assets?assetId={}
# https://earthengine.googleapis.com/v1alpha/projects/akveg-map/assets?assetId=dynamic_world_metrics/s2_dw_percentages_56789_v20250414/s2_dw_pct_56789_AK050H45V05_v20250414
# s2_dw_pct_56789_AK050H45V06_v20250414
# ['s2', 'dw', 'pct', '56789', 'AK050H45V06', 'v20250414', 'tif']
# 56789
# AK050H45V06
# v20250414
# ('{"type": "IMAGE", "gcs_location": {"uris": '
#  '"gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H45V06_v20250414.tif"}, '
#  '"properties": {"months": "56789", "tile": "AK050H45V06", "version_counts": '
#  '"v20250414"}}')
# https://earthengine.googleapis.com/v1alpha/projects/{}/assets?assetId={}
# https://earthengine.googleapis.com/v1alpha/projects/akveg-map/assets?assetId=dynamic_world_metrics/s2_dw_percentages_56789_v20250414/s2_dw_pct_56789_AK050H45V06_v20250414
# s2_dw_pct_56789_AK050H45V07_v20250414
# ['s2', 'dw', 'pct', '56789', 'AK050H45V07', 'v20250414', 'tif']
# 56789
# AK050H45V07
# v20250414
# ('{"type": "IMAGE", "gcs_location": {"uris": '
#  '"gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H45V07_v20250414.tif"}, '
#  '"properties": {"months": "56789", "tile": "AK050H45V07", "version_counts": '
#  '"v20250414"}}')
# https://earthengine.googleapis.com/v1alpha/projects/{}/assets?assetId={}
# https://earthengine.googleapis.com/v1alpha/projects/akveg-map/assets?assetId=dynamic_world_metrics/s2_dw_percentages_56789_v20250414/s2_dw_pct_56789_AK050H45V07_v20250414
# s2_dw_pct_56789_AK050H45V08_v20250414
# ['s2', 'dw', 'pct', '56789', 'AK050H45V08', 'v20250414', 'tif']
# 56789
# AK050H45V08
# v20250414
# ('{"type": "IMAGE", "gcs_location": {"uris": '
#  '"gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H45V08_v20250414.tif"}, '
#  '"properties": {"months": "56789", "tile": "AK050H45V08", "version_counts": '
#  '"v20250414"}}')
# https://earthengine.googleapis.com/v1alpha/projects/{}/assets?assetId={}
# https://earthengine.googleapis.com/v1alpha/projects/akveg-map/assets?assetId=dynamic_world_metrics/s2_dw_percentages_56789_v20250414/s2_dw_pct_56789_AK050H45V08_v20250414
# s2_dw_pct_56789_AK050H45V09_v20250414
# ['s2', 'dw', 'pct', '56789', 'AK050H45V09', 'v20250414', 'tif']
# 56789
# AK050H45V09
# v20250414
# ('{"type": "IMAGE", "gcs_location": {"uris": '
#  '"gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H45V09_v20250414.tif"}, '
#  '"properties": {"months": "56789", "tile": "AK050H45V09", "version_counts": '
#  '"v20250414"}}')
# https://earthengine.googleapis.com/v1alpha/projects/{}/assets?assetId={}
# https://earthengine.googleapis.com/v1alpha/projects/akveg-map/assets?assetId=dynamic_world_metrics/s2_dw_percentages_56789_v20250414/s2_dw_pct_56789_AK050H45V09_v20250414
# s2_dw_pct_56789_AK050H45V10_v20250414
# ['s2', 'dw', 'pct', '56789', 'AK050H45V10', 'v20250414', 'tif']
# 56789
# AK050H45V10
# v20250414
# ('{"type": "IMAGE", "gcs_location": {"uris": '
#  '"gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H45V10_v20250414.tif"}, '
#  '"properties": {"months": "56789", "tile": "AK050H45V10", "version_counts": '
#  '"v20250414"}}')
# https://earthengine.googleapis.com/v1alpha/projects/{}/assets?assetId={}
# https://earthengine.googleapis.com/v1alpha/projects/akveg-map/assets?assetId=dynamic_world_metrics/s2_dw_percentages_56789_v20250414/s2_dw_pct_56789_AK050H45V10_v20250414
# s2_dw_pct_56789_AK050H45V11_v20250414
# ['s2', 'dw', 'pct', '56789', 'AK050H45V11', 'v20250414', 'tif']
# 56789
# AK050H45V11
# v20250414
# ('{"type": "IMAGE", "gcs_location": {"uris": '
#  '"gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H45V11_v20250414.tif"}, '
#  '"properties": {"months": "56789", "tile": "AK050H45V11", "version_counts": '
#  '"v20250414"}}')
# https://earthengine.googleapis.com/v1alpha/projects/{}/assets?assetId={}
# https://earthengine.googleapis.com/v1alpha/projects/akveg-map/assets?assetId=dynamic_world_metrics/s2_dw_percentages_56789_v20250414/s2_dw_pct_56789_AK050H45V11_v20250414
# s2_dw_pct_56789_AK050H45V12_v20250414
# ['s2', 'dw', 'pct', '56789', 'AK050H45V12', 'v20250414', 'tif']
# 56789
# AK050H45V12
# v20250414
# ('{"type": "IMAGE", "gcs_location": {"uris": '
#  '"gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H45V12_v20250414.tif"}, '
#  '"properties": {"months": "56789", "tile": "AK050H45V12", "version_counts": '
#  '"v20250414"}}')
# https://earthengine.googleapis.com/v1alpha/projects/{}/assets?assetId={}
# https://earthengine.googleapis.com/v1alpha/projects/akveg-map/assets?assetId=dynamic_world_metrics/s2_dw_percentages_56789_v20250414/s2_dw_pct_56789_AK050H45V12_v20250414
# s2_dw_pct_56789_AK050H45V13_v20250414
# ['s2', 'dw', 'pct', '56789', 'AK050H45V13', 'v20250414', 'tif']
# 56789
# AK050H45V13
# v20250414
# ('{"type": "IMAGE", "gcs_location": {"uris": '
#  '"gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H45V13_v20250414.tif"}, '
#  '"properties": {"months": "56789", "tile": "AK050H45V13", "version_counts": '
#  '"v20250414"}}')
# https://earthengine.googleapis.com/v1alpha/projects/{}/assets?assetId={}
# https://earthengine.googleapis.com/v1alpha/projects/akveg-map/assets?assetId=dynamic_world_metrics/s2_dw_percentages_56789_v20250414/s2_dw_pct_56789_AK050H45V13_v20250414
# s2_dw_pct_56789_AK050H45V14_v20250414
# ['s2', 'dw', 'pct', '56789', 'AK050H45V14', 'v20250414', 'tif']
# 56789
# AK050H45V14
# v20250414
# ('{"type": "IMAGE", "gcs_location": {"uris": '
#  '"gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H45V14_v20250414.tif"}, '
#  '"properties": {"months": "56789", "tile": "AK050H45V14", "version_counts": '
#  '"v20250414"}}')
# https://earthengine.googleapis.com/v1alpha/projects/{}/assets?assetId={}
# https://earthengine.googleapis.com/v1alpha/projects/akveg-map/assets?assetId=dynamic_world_metrics/s2_dw_percentages_56789_v20250414/s2_dw_pct_56789_AK050H45V14_v20250414
# s2_dw_pct_56789_AK050H45V15_v20250414
# ['s2', 'dw', 'pct', '56789', 'AK050H45V15', 'v20250414', 'tif']
# 56789
# AK050H45V15
# v20250414
# ('{"type": "IMAGE", "gcs_location": {"uris": '
#  '"gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H45V15_v20250414.tif"}, '
#  '"properties": {"months": "56789", "tile": "AK050H45V15", "version_counts": '
#  '"v20250414"}}')
# https://earthengine.googleapis.com/v1alpha/projects/{}/assets?assetId={}
# https://earthengine.googleapis.com/v1alpha/projects/akveg-map/assets?assetId=dynamic_world_metrics/s2_dw_percentages_56789_v20250414/s2_dw_pct_56789_AK050H45V15_v20250414
# s2_dw_pct_56789_AK050H45V16_v20250414
# ['s2', 'dw', 'pct', '56789', 'AK050H45V16', 'v20250414', 'tif']
# 56789
# AK050H45V16
# v20250414
# ('{"type": "IMAGE", "gcs_location": {"uris": '
#  '"gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H45V16_v20250414.tif"}, '
#  '"properties": {"months": "56789", "tile": "AK050H45V16", "version_counts": '
#  '"v20250414"}}')
# https://earthengine.googleapis.com/v1alpha/projects/{}/assets?assetId={}
# https://earthengine.googleapis.com/v1alpha/projects/akveg-map/assets?assetId=dynamic_world_metrics/s2_dw_percentages_56789_v20250414/s2_dw_pct_56789_AK050H45V16_v20250414
# s2_dw_pct_56789_AK050H45V17_v20250414
# ['s2', 'dw', 'pct', '56789', 'AK050H45V17', 'v20250414', 'tif']
# 56789
# AK050H45V17
# v20250414
# ('{"type": "IMAGE", "gcs_location": {"uris": '
#  '"gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H45V17_v20250414.tif"}, '
#  '"properties": {"months": "56789", "tile": "AK050H45V17", "version_counts": '
#  '"v20250414"}}')
# https://earthengine.googleapis.com/v1alpha/projects/{}/assets?assetId={}
# https://earthengine.googleapis.com/v1alpha/projects/akveg-map/assets?assetId=dynamic_world_metrics/s2_dw_percentages_56789_v20250414/s2_dw_pct_56789_AK050H45V17_v20250414
# s2_dw_pct_56789_AK050H45V18_v20250414
# ['s2', 'dw', 'pct', '56789', 'AK050H45V18', 'v20250414', 'tif']
# 56789
# AK050H45V18
# v20250414
# ('{"type": "IMAGE", "gcs_location": {"uris": '
#  '"gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H45V18_v20250414.tif"}, '
#  '"properties": {"months": "56789", "tile": "AK050H45V18", "version_counts": '
#  '"v20250414"}}')
# https://earthengine.googleapis.com/v1alpha/projects/{}/assets?assetId={}
# https://earthengine.googleapis.com/v1alpha/projects/akveg-map/assets?assetId=dynamic_world_metrics/s2_dw_percentages_56789_v20250414/s2_dw_pct_56789_AK050H45V18_v20250414
# s2_dw_pct_56789_AK050H45V19_v20250414
# ['s2', 'dw', 'pct', '56789', 'AK050H45V19', 'v20250414', 'tif']
# 56789
# AK050H45V19
# v20250414
# ('{"type": "IMAGE", "gcs_location": {"uris": '
#  '"gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H45V19_v20250414.tif"}, '
#  '"properties": {"months": "56789", "tile": "AK050H45V19", "version_counts": '
#  '"v20250414"}}')
# https://earthengine.googleapis.com/v1alpha/projects/{}/assets?assetId={}
# https://earthengine.googleapis.com/v1alpha/projects/akveg-map/assets?assetId=dynamic_world_metrics/s2_dw_percentages_56789_v20250414/s2_dw_pct_56789_AK050H45V19_v20250414
# s2_dw_pct_56789_AK050H45V20_v20250414
# ['s2', 'dw', 'pct', '56789', 'AK050H45V20', 'v20250414', 'tif']
# 56789
# AK050H45V20
# v20250414
# ('{"type": "IMAGE", "gcs_location": {"uris": '
#  '"gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H45V20_v20250414.tif"}, '
#  '"properties": {"months": "56789", "tile": "AK050H45V20", "version_counts": '
#  '"v20250414"}}')
# https://earthengine.googleapis.com/v1alpha/projects/{}/assets?assetId={}
# https://earthengine.googleapis.com/v1alpha/projects/akveg-map/assets?assetId=dynamic_world_metrics/s2_dw_percentages_56789_v20250414/s2_dw_pct_56789_AK050H45V20_v20250414
# s2_dw_pct_56789_AK050H45V21_v20250414
# ['s2', 'dw', 'pct', '56789', 'AK050H45V21', 'v20250414', 'tif']
# 56789
# AK050H45V21
# v20250414
# ('{"type": "IMAGE", "gcs_location": {"uris": '
#  '"gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H45V21_v20250414.tif"}, '
#  '"properties": {"months": "56789", "tile": "AK050H45V21", "version_counts": '
#  '"v20250414"}}')
# https://earthengine.googleapis.com/v1alpha/projects/{}/assets?assetId={}
# https://earthengine.googleapis.com/v1alpha/projects/akveg-map/assets?assetId=dynamic_world_metrics/s2_dw_percentages_56789_v20250414/s2_dw_pct_56789_AK050H45V21_v20250414
# s2_dw_pct_56789_AK050H45V22_v20250414
# ['s2', 'dw', 'pct', '56789', 'AK050H45V22', 'v20250414', 'tif']
# 56789
# AK050H45V22
# v20250414
# ('{"type": "IMAGE", "gcs_location": {"uris": '
#  '"gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H45V22_v20250414.tif"}, '
#  '"properties": {"months": "56789", "tile": "AK050H45V22", "version_counts": '
#  '"v20250414"}}')
# https://earthengine.googleapis.com/v1alpha/projects/{}/assets?assetId={}
# https://earthengine.googleapis.com/v1alpha/projects/akveg-map/assets?assetId=dynamic_world_metrics/s2_dw_percentages_56789_v20250414/s2_dw_pct_56789_AK050H45V22_v20250414
# s2_dw_pct_56789_AK050H45V23_v20250414
# ['s2', 'dw', 'pct', '56789', 'AK050H45V23', 'v20250414', 'tif']
# 56789
# AK050H45V23
# v20250414
# ('{"type": "IMAGE", "gcs_location": {"uris": '
#  '"gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H45V23_v20250414.tif"}, '
#  '"properties": {"months": "56789", "tile": "AK050H45V23", "version_counts": '
#  '"v20250414"}}')
# https://earthengine.googleapis.com/v1alpha/projects/{}/assets?assetId={}
# https://earthengine.googleapis.com/v1alpha/projects/akveg-map/assets?assetId=dynamic_world_metrics/s2_dw_percentages_56789_v20250414/s2_dw_pct_56789_AK050H45V23_v20250414
# s2_dw_pct_56789_AK050H45V24_v20250414
# ['s2', 'dw', 'pct', '56789', 'AK050H45V24', 'v20250414', 'tif']
# 56789
# AK050H45V24
# v20250414
# ('{"type": "IMAGE", "gcs_location": {"uris": '
#  '"gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H45V24_v20250414.tif"}, '
#  '"properties": {"months": "56789", "tile": "AK050H45V24", "version_counts": '
#  '"v20250414"}}')
# https://earthengine.googleapis.com/v1alpha/projects/{}/assets?assetId={}
# https://earthengine.googleapis.com/v1alpha/projects/akveg-map/assets?assetId=dynamic_world_metrics/s2_dw_percentages_56789_v20250414/s2_dw_pct_56789_AK050H45V24_v20250414
# s2_dw_pct_56789_AK050H45V25_v20250414
# ['s2', 'dw', 'pct', '56789', 'AK050H45V25', 'v20250414', 'tif']
# 56789
# AK050H45V25
# v20250414
# ('{"type": "IMAGE", "gcs_location": {"uris": '
#  '"gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H45V25_v20250414.tif"}, '
#  '"properties": {"months": "56789", "tile": "AK050H45V25", "version_counts": '
#  '"v20250414"}}')
# https://earthengine.googleapis.com/v1alpha/projects/{}/assets?assetId={}
# https://earthengine.googleapis.com/v1alpha/projects/akveg-map/assets?assetId=dynamic_world_metrics/s2_dw_percentages_56789_v20250414/s2_dw_pct_56789_AK050H45V25_v20250414
# s2_dw_pct_56789_AK050H45V26_v20250414
# ['s2', 'dw', 'pct', '56789', 'AK050H45V26', 'v20250414', 'tif']
# 56789
# AK050H45V26
# v20250414
# ('{"type": "IMAGE", "gcs_location": {"uris": '
#  '"gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H45V26_v20250414.tif"}, '
#  '"properties": {"months": "56789", "tile": "AK050H45V26", "version_counts": '
#  '"v20250414"}}')
# https://earthengine.googleapis.com/v1alpha/projects/{}/assets?assetId={}
# https://earthengine.googleapis.com/v1alpha/projects/akveg-map/assets?assetId=dynamic_world_metrics/s2_dw_percentages_56789_v20250414/s2_dw_pct_56789_AK050H45V26_v20250414
# s2_dw_pct_56789_AK050H45V27_v20250414
# ['s2', 'dw', 'pct', '56789', 'AK050H45V27', 'v20250414', 'tif']
# 56789
# AK050H45V27
# v20250414
# ('{"type": "IMAGE", "gcs_location": {"uris": '
#  '"gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H45V27_v20250414.tif"}, '
#  '"properties": {"months": "56789", "tile": "AK050H45V27", "version_counts": '
#  '"v20250414"}}')
# https://earthengine.googleapis.com/v1alpha/projects/{}/assets?assetId={}
# https://earthengine.googleapis.com/v1alpha/projects/akveg-map/assets?assetId=dynamic_world_metrics/s2_dw_percentages_56789_v20250414/s2_dw_pct_56789_AK050H45V27_v20250414
# s2_dw_pct_56789_AK050H45V28_v20250414
# ['s2', 'dw', 'pct', '56789', 'AK050H45V28', 'v20250414', 'tif']
# 56789
# AK050H45V28
# v20250414
# ('{"type": "IMAGE", "gcs_location": {"uris": '
#  '"gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H45V28_v20250414.tif"}, '
#  '"properties": {"months": "56789", "tile": "AK050H45V28", "version_counts": '
#  '"v20250414"}}')
# https://earthengine.googleapis.com/v1alpha/projects/{}/assets?assetId={}
# https://earthengine.googleapis.com/v1alpha/projects/akveg-map/assets?assetId=dynamic_world_metrics/s2_dw_percentages_56789_v20250414/s2_dw_pct_56789_AK050H45V28_v20250414
# s2_dw_pct_56789_AK050H45V29_v20250414
# ['s2', 'dw', 'pct', '56789', 'AK050H45V29', 'v20250414', 'tif']
# 56789
# AK050H45V29
# v20250414
# ('{"type": "IMAGE", "gcs_location": {"uris": '
#  '"gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H45V29_v20250414.tif"}, '
#  '"properties": {"months": "56789", "tile": "AK050H45V29", "version_counts": '
#  '"v20250414"}}')
# https://earthengine.googleapis.com/v1alpha/projects/{}/assets?assetId={}
# https://earthengine.googleapis.com/v1alpha/projects/akveg-map/assets?assetId=dynamic_world_metrics/s2_dw_percentages_56789_v20250414/s2_dw_pct_56789_AK050H45V29_v20250414
# s2_dw_pct_56789_AK050H45V30_v20250414
# ['s2', 'dw', 'pct', '56789', 'AK050H45V30', 'v20250414', 'tif']
# 56789
# AK050H45V30
# v20250414
# ('{"type": "IMAGE", "gcs_location": {"uris": '
#  '"gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H45V30_v20250414.tif"}, '
#  '"properties": {"months": "56789", "tile": "AK050H45V30", "version_counts": '
#  '"v20250414"}}')
# https://earthengine.googleapis.com/v1alpha/projects/{}/assets?assetId={}
# https://earthengine.googleapis.com/v1alpha/projects/akveg-map/assets?assetId=dynamic_world_metrics/s2_dw_percentages_56789_v20250414/s2_dw_pct_56789_AK050H45V30_v20250414
# s2_dw_pct_56789_AK050H45V31_v20250414
# ['s2', 'dw', 'pct', '56789', 'AK050H45V31', 'v20250414', 'tif']
# 56789
# AK050H45V31
# v20250414
# ('{"type": "IMAGE", "gcs_location": {"uris": '
#  '"gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H45V31_v20250414.tif"}, '
#  '"properties": {"months": "56789", "tile": "AK050H45V31", "version_counts": '
#  '"v20250414"}}')
# https://earthengine.googleapis.com/v1alpha/projects/{}/assets?assetId={}
# https://earthengine.googleapis.com/v1alpha/projects/akveg-map/assets?assetId=dynamic_world_metrics/s2_dw_percentages_56789_v20250414/s2_dw_pct_56789_AK050H45V31_v20250414
# s2_dw_pct_56789_AK050H45V32_v20250414
# ['s2', 'dw', 'pct', '56789', 'AK050H45V32', 'v20250414', 'tif']
# 56789
# AK050H45V32
# v20250414
# ('{"type": "IMAGE", "gcs_location": {"uris": '
#  '"gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H45V32_v20250414.tif"}, '
#  '"properties": {"months": "56789", "tile": "AK050H45V32", "version_counts": '
#  '"v20250414"}}')
# https://earthengine.googleapis.com/v1alpha/projects/{}/assets?assetId={}
# https://earthengine.googleapis.com/v1alpha/projects/akveg-map/assets?assetId=dynamic_world_metrics/s2_dw_percentages_56789_v20250414/s2_dw_pct_56789_AK050H45V32_v20250414
# s2_dw_pct_56789_AK050H45V33_v20250414
# ['s2', 'dw', 'pct', '56789', 'AK050H45V33', 'v20250414', 'tif']
# 56789
# AK050H45V33
# v20250414
# ('{"type": "IMAGE", "gcs_location": {"uris": '
#  '"gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H45V33_v20250414.tif"}, '
#  '"properties": {"months": "56789", "tile": "AK050H45V33", "version_counts": '
#  '"v20250414"}}')
# https://earthengine.googleapis.com/v1alpha/projects/{}/assets?assetId={}
# https://earthengine.googleapis.com/v1alpha/projects/akveg-map/assets?assetId=dynamic_world_metrics/s2_dw_percentages_56789_v20250414/s2_dw_pct_56789_AK050H45V33_v20250414
# s2_dw_pct_56789_AK050H45V34_v20250414
# ['s2', 'dw', 'pct', '56789', 'AK050H45V34', 'v20250414', 'tif']
# 56789
# AK050H45V34
# v20250414
# ('{"type": "IMAGE", "gcs_location": {"uris": '
#  '"gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H45V34_v20250414.tif"}, '
#  '"properties": {"months": "56789", "tile": "AK050H45V34", "version_counts": '
#  '"v20250414"}}')
# https://earthengine.googleapis.com/v1alpha/projects/{}/assets?assetId={}
# https://earthengine.googleapis.com/v1alpha/projects/akveg-map/assets?assetId=dynamic_world_metrics/s2_dw_percentages_56789_v20250414/s2_dw_pct_56789_AK050H45V34_v20250414
# s2_dw_pct_56789_AK050H46V02_v20250414
# ['s2', 'dw', 'pct', '56789', 'AK050H46V02', 'v20250414', 'tif']
# 56789
# AK050H46V02
# v20250414
# ('{"type": "IMAGE", "gcs_location": {"uris": '
#  '"gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H46V02_v20250414.tif"}, '
#  '"properties": {"months": "56789", "tile": "AK050H46V02", "version_counts": '
#  '"v20250414"}}')
# https://earthengine.googleapis.com/v1alpha/projects/{}/assets?assetId={}
# https://earthengine.googleapis.com/v1alpha/projects/akveg-map/assets?assetId=dynamic_world_metrics/s2_dw_percentages_56789_v20250414/s2_dw_pct_56789_AK050H46V02_v20250414
# s2_dw_pct_56789_AK050H46V03_v20250414
# ['s2', 'dw', 'pct', '56789', 'AK050H46V03', 'v20250414', 'tif']
# 56789
# AK050H46V03
# v20250414
# ('{"type": "IMAGE", "gcs_location": {"uris": '
#  '"gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H46V03_v20250414.tif"}, '
#  '"properties": {"months": "56789", "tile": "AK050H46V03", "version_counts": '
#  '"v20250414"}}')
# https://earthengine.googleapis.com/v1alpha/projects/{}/assets?assetId={}
# https://earthengine.googleapis.com/v1alpha/projects/akveg-map/assets?assetId=dynamic_world_metrics/s2_dw_percentages_56789_v20250414/s2_dw_pct_56789_AK050H46V03_v20250414
# s2_dw_pct_56789_AK050H46V04_v20250414
# ['s2', 'dw', 'pct', '56789', 'AK050H46V04', 'v20250414', 'tif']
# 56789
# AK050H46V04
# v20250414
# ('{"type": "IMAGE", "gcs_location": {"uris": '
#  '"gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H46V04_v20250414.tif"}, '
#  '"properties": {"months": "56789", "tile": "AK050H46V04", "version_counts": '
#  '"v20250414"}}')
# https://earthengine.googleapis.com/v1alpha/projects/{}/assets?assetId={}
# https://earthengine.googleapis.com/v1alpha/projects/akveg-map/assets?assetId=dynamic_world_metrics/s2_dw_percentages_56789_v20250414/s2_dw_pct_56789_AK050H46V04_v20250414
# s2_dw_pct_56789_AK050H46V05_v20250414
# ['s2', 'dw', 'pct', '56789', 'AK050H46V05', 'v20250414', 'tif']
# 56789
# AK050H46V05
# v20250414
# ('{"type": "IMAGE", "gcs_location": {"uris": '
#  '"gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H46V05_v20250414.tif"}, '
#  '"properties": {"months": "56789", "tile": "AK050H46V05", "version_counts": '
#  '"v20250414"}}')
# https://earthengine.googleapis.com/v1alpha/projects/{}/assets?assetId={}
# https://earthengine.googleapis.com/v1alpha/projects/akveg-map/assets?assetId=dynamic_world_metrics/s2_dw_percentages_56789_v20250414/s2_dw_pct_56789_AK050H46V05_v20250414
# s2_dw_pct_56789_AK050H46V06_v20250414
# ['s2', 'dw', 'pct', '56789', 'AK050H46V06', 'v20250414', 'tif']
# 56789
# AK050H46V06
# v20250414
# ('{"type": "IMAGE", "gcs_location": {"uris": '
#  '"gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H46V06_v20250414.tif"}, '
#  '"properties": {"months": "56789", "tile": "AK050H46V06", "version_counts": '
#  '"v20250414"}}')
# https://earthengine.googleapis.com/v1alpha/projects/{}/assets?assetId={}
# https://earthengine.googleapis.com/v1alpha/projects/akveg-map/assets?assetId=dynamic_world_metrics/s2_dw_percentages_56789_v20250414/s2_dw_pct_56789_AK050H46V06_v20250414
# s2_dw_pct_56789_AK050H46V07_v20250414
# ['s2', 'dw', 'pct', '56789', 'AK050H46V07', 'v20250414', 'tif']
# 56789
# AK050H46V07
# v20250414
# ('{"type": "IMAGE", "gcs_location": {"uris": '
#  '"gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H46V07_v20250414.tif"}, '
#  '"properties": {"months": "56789", "tile": "AK050H46V07", "version_counts": '
#  '"v20250414"}}')
# https://earthengine.googleapis.com/v1alpha/projects/{}/assets?assetId={}
# https://earthengine.googleapis.com/v1alpha/projects/akveg-map/assets?assetId=dynamic_world_metrics/s2_dw_percentages_56789_v20250414/s2_dw_pct_56789_AK050H46V07_v20250414
# s2_dw_pct_56789_AK050H46V08_v20250414
# ['s2', 'dw', 'pct', '56789', 'AK050H46V08', 'v20250414', 'tif']
# 56789
# AK050H46V08
# v20250414
# ('{"type": "IMAGE", "gcs_location": {"uris": '
#  '"gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H46V08_v20250414.tif"}, '
#  '"properties": {"months": "56789", "tile": "AK050H46V08", "version_counts": '
#  '"v20250414"}}')
# https://earthengine.googleapis.com/v1alpha/projects/{}/assets?assetId={}
# https://earthengine.googleapis.com/v1alpha/projects/akveg-map/assets?assetId=dynamic_world_metrics/s2_dw_percentages_56789_v20250414/s2_dw_pct_56789_AK050H46V08_v20250414
# s2_dw_pct_56789_AK050H46V09_v20250414
# ['s2', 'dw', 'pct', '56789', 'AK050H46V09', 'v20250414', 'tif']
# 56789
# AK050H46V09
# v20250414
# ('{"type": "IMAGE", "gcs_location": {"uris": '
#  '"gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H46V09_v20250414.tif"}, '
#  '"properties": {"months": "56789", "tile": "AK050H46V09", "version_counts": '
#  '"v20250414"}}')
# https://earthengine.googleapis.com/v1alpha/projects/{}/assets?assetId={}
# https://earthengine.googleapis.com/v1alpha/projects/akveg-map/assets?assetId=dynamic_world_metrics/s2_dw_percentages_56789_v20250414/s2_dw_pct_56789_AK050H46V09_v20250414
# s2_dw_pct_56789_AK050H46V10_v20250414
# ['s2', 'dw', 'pct', '56789', 'AK050H46V10', 'v20250414', 'tif']
# 56789
# AK050H46V10
# v20250414
# ('{"type": "IMAGE", "gcs_location": {"uris": '
#  '"gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H46V10_v20250414.tif"}, '
#  '"properties": {"months": "56789", "tile": "AK050H46V10", "version_counts": '
#  '"v20250414"}}')
# https://earthengine.googleapis.com/v1alpha/projects/{}/assets?assetId={}
# https://earthengine.googleapis.com/v1alpha/projects/akveg-map/assets?assetId=dynamic_world_metrics/s2_dw_percentages_56789_v20250414/s2_dw_pct_56789_AK050H46V10_v20250414
# s2_dw_pct_56789_AK050H46V11_v20250414
# ['s2', 'dw', 'pct', '56789', 'AK050H46V11', 'v20250414', 'tif']
# 56789
# AK050H46V11
# v20250414
# ('{"type": "IMAGE", "gcs_location": {"uris": '
#  '"gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H46V11_v20250414.tif"}, '
#  '"properties": {"months": "56789", "tile": "AK050H46V11", "version_counts": '
#  '"v20250414"}}')
# https://earthengine.googleapis.com/v1alpha/projects/{}/assets?assetId={}
# https://earthengine.googleapis.com/v1alpha/projects/akveg-map/assets?assetId=dynamic_world_metrics/s2_dw_percentages_56789_v20250414/s2_dw_pct_56789_AK050H46V11_v20250414
# s2_dw_pct_56789_AK050H46V12_v20250414
# ['s2', 'dw', 'pct', '56789', 'AK050H46V12', 'v20250414', 'tif']
# 56789
# AK050H46V12
# v20250414
# ('{"type": "IMAGE", "gcs_location": {"uris": '
#  '"gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H46V12_v20250414.tif"}, '
#  '"properties": {"months": "56789", "tile": "AK050H46V12", "version_counts": '
#  '"v20250414"}}')
# https://earthengine.googleapis.com/v1alpha/projects/{}/assets?assetId={}
# https://earthengine.googleapis.com/v1alpha/projects/akveg-map/assets?assetId=dynamic_world_metrics/s2_dw_percentages_56789_v20250414/s2_dw_pct_56789_AK050H46V12_v20250414
# s2_dw_pct_56789_AK050H46V13_v20250414
# ['s2', 'dw', 'pct', '56789', 'AK050H46V13', 'v20250414', 'tif']
# 56789
# AK050H46V13
# v20250414
# ('{"type": "IMAGE", "gcs_location": {"uris": '
#  '"gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H46V13_v20250414.tif"}, '
#  '"properties": {"months": "56789", "tile": "AK050H46V13", "version_counts": '
#  '"v20250414"}}')
# https://earthengine.googleapis.com/v1alpha/projects/{}/assets?assetId={}
# https://earthengine.googleapis.com/v1alpha/projects/akveg-map/assets?assetId=dynamic_world_metrics/s2_dw_percentages_56789_v20250414/s2_dw_pct_56789_AK050H46V13_v20250414
# s2_dw_pct_56789_AK050H46V14_v20250414
# ['s2', 'dw', 'pct', '56789', 'AK050H46V14', 'v20250414', 'tif']
# 56789
# AK050H46V14
# v20250414
# ('{"type": "IMAGE", "gcs_location": {"uris": '
#  '"gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H46V14_v20250414.tif"}, '
#  '"properties": {"months": "56789", "tile": "AK050H46V14", "version_counts": '
#  '"v20250414"}}')
# https://earthengine.googleapis.com/v1alpha/projects/{}/assets?assetId={}
# https://earthengine.googleapis.com/v1alpha/projects/akveg-map/assets?assetId=dynamic_world_metrics/s2_dw_percentages_56789_v20250414/s2_dw_pct_56789_AK050H46V14_v20250414
# s2_dw_pct_56789_AK050H46V15_v20250414
# ['s2', 'dw', 'pct', '56789', 'AK050H46V15', 'v20250414', 'tif']
# 56789
# AK050H46V15
# v20250414
# ('{"type": "IMAGE", "gcs_location": {"uris": '
#  '"gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H46V15_v20250414.tif"}, '
#  '"properties": {"months": "56789", "tile": "AK050H46V15", "version_counts": '
#  '"v20250414"}}')
# https://earthengine.googleapis.com/v1alpha/projects/{}/assets?assetId={}
# https://earthengine.googleapis.com/v1alpha/projects/akveg-map/assets?assetId=dynamic_world_metrics/s2_dw_percentages_56789_v20250414/s2_dw_pct_56789_AK050H46V15_v20250414
# s2_dw_pct_56789_AK050H46V16_v20250414
# ['s2', 'dw', 'pct', '56789', 'AK050H46V16', 'v20250414', 'tif']
# 56789
# AK050H46V16
# v20250414
# ('{"type": "IMAGE", "gcs_location": {"uris": '
#  '"gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H46V16_v20250414.tif"}, '
#  '"properties": {"months": "56789", "tile": "AK050H46V16", "version_counts": '
#  '"v20250414"}}')
# https://earthengine.googleapis.com/v1alpha/projects/{}/assets?assetId={}
# https://earthengine.googleapis.com/v1alpha/projects/akveg-map/assets?assetId=dynamic_world_metrics/s2_dw_percentages_56789_v20250414/s2_dw_pct_56789_AK050H46V16_v20250414
# s2_dw_pct_56789_AK050H46V17_v20250414
# ['s2', 'dw', 'pct', '56789', 'AK050H46V17', 'v20250414', 'tif']
# 56789
# AK050H46V17
# v20250414
# ('{"type": "IMAGE", "gcs_location": {"uris": '
#  '"gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H46V17_v20250414.tif"}, '
#  '"properties": {"months": "56789", "tile": "AK050H46V17", "version_counts": '
#  '"v20250414"}}')
# https://earthengine.googleapis.com/v1alpha/projects/{}/assets?assetId={}
# https://earthengine.googleapis.com/v1alpha/projects/akveg-map/assets?assetId=dynamic_world_metrics/s2_dw_percentages_56789_v20250414/s2_dw_pct_56789_AK050H46V17_v20250414
# s2_dw_pct_56789_AK050H46V18_v20250414
# ['s2', 'dw', 'pct', '56789', 'AK050H46V18', 'v20250414', 'tif']
# 56789
# AK050H46V18
# v20250414
# ('{"type": "IMAGE", "gcs_location": {"uris": '
#  '"gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H46V18_v20250414.tif"}, '
#  '"properties": {"months": "56789", "tile": "AK050H46V18", "version_counts": '
#  '"v20250414"}}')
# https://earthengine.googleapis.com/v1alpha/projects/{}/assets?assetId={}
# https://earthengine.googleapis.com/v1alpha/projects/akveg-map/assets?assetId=dynamic_world_metrics/s2_dw_percentages_56789_v20250414/s2_dw_pct_56789_AK050H46V18_v20250414
# s2_dw_pct_56789_AK050H46V19_v20250414
# ['s2', 'dw', 'pct', '56789', 'AK050H46V19', 'v20250414', 'tif']
# 56789
# AK050H46V19
# v20250414
# ('{"type": "IMAGE", "gcs_location": {"uris": '
#  '"gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H46V19_v20250414.tif"}, '
#  '"properties": {"months": "56789", "tile": "AK050H46V19", "version_counts": '
#  '"v20250414"}}')
# https://earthengine.googleapis.com/v1alpha/projects/{}/assets?assetId={}
# https://earthengine.googleapis.com/v1alpha/projects/akveg-map/assets?assetId=dynamic_world_metrics/s2_dw_percentages_56789_v20250414/s2_dw_pct_56789_AK050H46V19_v20250414
# s2_dw_pct_56789_AK050H46V20_v20250414
# ['s2', 'dw', 'pct', '56789', 'AK050H46V20', 'v20250414', 'tif']
# 56789
# AK050H46V20
# v20250414
# ('{"type": "IMAGE", "gcs_location": {"uris": '
#  '"gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H46V20_v20250414.tif"}, '
#  '"properties": {"months": "56789", "tile": "AK050H46V20", "version_counts": '
#  '"v20250414"}}')
# https://earthengine.googleapis.com/v1alpha/projects/{}/assets?assetId={}
# https://earthengine.googleapis.com/v1alpha/projects/akveg-map/assets?assetId=dynamic_world_metrics/s2_dw_percentages_56789_v20250414/s2_dw_pct_56789_AK050H46V20_v20250414
# s2_dw_pct_56789_AK050H46V21_v20250414
# ['s2', 'dw', 'pct', '56789', 'AK050H46V21', 'v20250414', 'tif']
# 56789
# AK050H46V21
# v20250414
# ('{"type": "IMAGE", "gcs_location": {"uris": '
#  '"gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H46V21_v20250414.tif"}, '
#  '"properties": {"months": "56789", "tile": "AK050H46V21", "version_counts": '
#  '"v20250414"}}')
# https://earthengine.googleapis.com/v1alpha/projects/{}/assets?assetId={}
# https://earthengine.googleapis.com/v1alpha/projects/akveg-map/assets?assetId=dynamic_world_metrics/s2_dw_percentages_56789_v20250414/s2_dw_pct_56789_AK050H46V21_v20250414
# s2_dw_pct_56789_AK050H46V22_v20250414
# ['s2', 'dw', 'pct', '56789', 'AK050H46V22', 'v20250414', 'tif']
# 56789
# AK050H46V22
# v20250414
# ('{"type": "IMAGE", "gcs_location": {"uris": '
#  '"gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H46V22_v20250414.tif"}, '
#  '"properties": {"months": "56789", "tile": "AK050H46V22", "version_counts": '
#  '"v20250414"}}')
# https://earthengine.googleapis.com/v1alpha/projects/{}/assets?assetId={}
# https://earthengine.googleapis.com/v1alpha/projects/akveg-map/assets?assetId=dynamic_world_metrics/s2_dw_percentages_56789_v20250414/s2_dw_pct_56789_AK050H46V22_v20250414
# s2_dw_pct_56789_AK050H46V23_v20250414
# ['s2', 'dw', 'pct', '56789', 'AK050H46V23', 'v20250414', 'tif']
# 56789
# AK050H46V23
# v20250414
# ('{"type": "IMAGE", "gcs_location": {"uris": '
#  '"gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H46V23_v20250414.tif"}, '
#  '"properties": {"months": "56789", "tile": "AK050H46V23", "version_counts": '
#  '"v20250414"}}')
# https://earthengine.googleapis.com/v1alpha/projects/{}/assets?assetId={}
# https://earthengine.googleapis.com/v1alpha/projects/akveg-map/assets?assetId=dynamic_world_metrics/s2_dw_percentages_56789_v20250414/s2_dw_pct_56789_AK050H46V23_v20250414
# s2_dw_pct_56789_AK050H46V24_v20250414
# ['s2', 'dw', 'pct', '56789', 'AK050H46V24', 'v20250414', 'tif']
# 56789
# AK050H46V24
# v20250414
# ('{"type": "IMAGE", "gcs_location": {"uris": '
#  '"gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H46V24_v20250414.tif"}, '
#  '"properties": {"months": "56789", "tile": "AK050H46V24", "version_counts": '
#  '"v20250414"}}')
# https://earthengine.googleapis.com/v1alpha/projects/{}/assets?assetId={}
# https://earthengine.googleapis.com/v1alpha/projects/akveg-map/assets?assetId=dynamic_world_metrics/s2_dw_percentages_56789_v20250414/s2_dw_pct_56789_AK050H46V24_v20250414
# s2_dw_pct_56789_AK050H46V25_v20250414
# ['s2', 'dw', 'pct', '56789', 'AK050H46V25', 'v20250414', 'tif']
# 56789
# AK050H46V25
# v20250414
# ('{"type": "IMAGE", "gcs_location": {"uris": '
#  '"gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H46V25_v20250414.tif"}, '
#  '"properties": {"months": "56789", "tile": "AK050H46V25", "version_counts": '
#  '"v20250414"}}')
# https://earthengine.googleapis.com/v1alpha/projects/{}/assets?assetId={}
# https://earthengine.googleapis.com/v1alpha/projects/akveg-map/assets?assetId=dynamic_world_metrics/s2_dw_percentages_56789_v20250414/s2_dw_pct_56789_AK050H46V25_v20250414
# s2_dw_pct_56789_AK050H46V26_v20250414
# ['s2', 'dw', 'pct', '56789', 'AK050H46V26', 'v20250414', 'tif']
# 56789
# AK050H46V26
# v20250414
# ('{"type": "IMAGE", "gcs_location": {"uris": '
#  '"gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H46V26_v20250414.tif"}, '
#  '"properties": {"months": "56789", "tile": "AK050H46V26", "version_counts": '
#  '"v20250414"}}')
# https://earthengine.googleapis.com/v1alpha/projects/{}/assets?assetId={}
# https://earthengine.googleapis.com/v1alpha/projects/akveg-map/assets?assetId=dynamic_world_metrics/s2_dw_percentages_56789_v20250414/s2_dw_pct_56789_AK050H46V26_v20250414
# s2_dw_pct_56789_AK050H46V27_v20250414
# ['s2', 'dw', 'pct', '56789', 'AK050H46V27', 'v20250414', 'tif']
# 56789
# AK050H46V27
# v20250414
# ('{"type": "IMAGE", "gcs_location": {"uris": '
#  '"gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H46V27_v20250414.tif"}, '
#  '"properties": {"months": "56789", "tile": "AK050H46V27", "version_counts": '
#  '"v20250414"}}')
# https://earthengine.googleapis.com/v1alpha/projects/{}/assets?assetId={}
# https://earthengine.googleapis.com/v1alpha/projects/akveg-map/assets?assetId=dynamic_world_metrics/s2_dw_percentages_56789_v20250414/s2_dw_pct_56789_AK050H46V27_v20250414
# s2_dw_pct_56789_AK050H46V28_v20250414
# ['s2', 'dw', 'pct', '56789', 'AK050H46V28', 'v20250414', 'tif']
# 56789
# AK050H46V28
# v20250414
# ('{"type": "IMAGE", "gcs_location": {"uris": '
#  '"gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H46V28_v20250414.tif"}, '
#  '"properties": {"months": "56789", "tile": "AK050H46V28", "version_counts": '
#  '"v20250414"}}')
# https://earthengine.googleapis.com/v1alpha/projects/{}/assets?assetId={}
# https://earthengine.googleapis.com/v1alpha/projects/akveg-map/assets?assetId=dynamic_world_metrics/s2_dw_percentages_56789_v20250414/s2_dw_pct_56789_AK050H46V28_v20250414
# s2_dw_pct_56789_AK050H46V29_v20250414
# ['s2', 'dw', 'pct', '56789', 'AK050H46V29', 'v20250414', 'tif']
# 56789
# AK050H46V29
# v20250414
# ('{"type": "IMAGE", "gcs_location": {"uris": '
#  '"gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H46V29_v20250414.tif"}, '
#  '"properties": {"months": "56789", "tile": "AK050H46V29", "version_counts": '
#  '"v20250414"}}')
# https://earthengine.googleapis.com/v1alpha/projects/{}/assets?assetId={}
# https://earthengine.googleapis.com/v1alpha/projects/akveg-map/assets?assetId=dynamic_world_metrics/s2_dw_percentages_56789_v20250414/s2_dw_pct_56789_AK050H46V29_v20250414
# s2_dw_pct_56789_AK050H46V30_v20250414
# ['s2', 'dw', 'pct', '56789', 'AK050H46V30', 'v20250414', 'tif']
# 56789
# AK050H46V30
# v20250414
# ('{"type": "IMAGE", "gcs_location": {"uris": '
#  '"gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H46V30_v20250414.tif"}, '
#  '"properties": {"months": "56789", "tile": "AK050H46V30", "version_counts": '
#  '"v20250414"}}')
# https://earthengine.googleapis.com/v1alpha/projects/{}/assets?assetId={}
# https://earthengine.googleapis.com/v1alpha/projects/akveg-map/assets?assetId=dynamic_world_metrics/s2_dw_percentages_56789_v20250414/s2_dw_pct_56789_AK050H46V30_v20250414
# s2_dw_pct_56789_AK050H46V31_v20250414
# ['s2', 'dw', 'pct', '56789', 'AK050H46V31', 'v20250414', 'tif']
# 56789
# AK050H46V31
# v20250414
# ('{"type": "IMAGE", "gcs_location": {"uris": '
#  '"gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H46V31_v20250414.tif"}, '
#  '"properties": {"months": "56789", "tile": "AK050H46V31", "version_counts": '
#  '"v20250414"}}')
# https://earthengine.googleapis.com/v1alpha/projects/{}/assets?assetId={}
# https://earthengine.googleapis.com/v1alpha/projects/akveg-map/assets?assetId=dynamic_world_metrics/s2_dw_percentages_56789_v20250414/s2_dw_pct_56789_AK050H46V31_v20250414
# s2_dw_pct_56789_AK050H46V32_v20250414
# ['s2', 'dw', 'pct', '56789', 'AK050H46V32', 'v20250414', 'tif']
# 56789
# AK050H46V32
# v20250414
# ('{"type": "IMAGE", "gcs_location": {"uris": '
#  '"gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H46V32_v20250414.tif"}, '
#  '"properties": {"months": "56789", "tile": "AK050H46V32", "version_counts": '
#  '"v20250414"}}')
# https://earthengine.googleapis.com/v1alpha/projects/{}/assets?assetId={}
# https://earthengine.googleapis.com/v1alpha/projects/akveg-map/assets?assetId=dynamic_world_metrics/s2_dw_percentages_56789_v20250414/s2_dw_pct_56789_AK050H46V32_v20250414
# s2_dw_pct_56789_AK050H46V33_v20250414
# ['s2', 'dw', 'pct', '56789', 'AK050H46V33', 'v20250414', 'tif']
# 56789
# AK050H46V33
# v20250414
# ('{"type": "IMAGE", "gcs_location": {"uris": '
#  '"gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H46V33_v20250414.tif"}, '
#  '"properties": {"months": "56789", "tile": "AK050H46V33", "version_counts": '
#  '"v20250414"}}')
# https://earthengine.googleapis.com/v1alpha/projects/{}/assets?assetId={}
# https://earthengine.googleapis.com/v1alpha/projects/akveg-map/assets?assetId=dynamic_world_metrics/s2_dw_percentages_56789_v20250414/s2_dw_pct_56789_AK050H46V33_v20250414
# s2_dw_pct_56789_AK050H47V02_v20250414
# ['s2', 'dw', 'pct', '56789', 'AK050H47V02', 'v20250414', 'tif']
# 56789
# AK050H47V02
# v20250414
# ('{"type": "IMAGE", "gcs_location": {"uris": '
#  '"gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H47V02_v20250414.tif"}, '
#  '"properties": {"months": "56789", "tile": "AK050H47V02", "version_counts": '
#  '"v20250414"}}')
# https://earthengine.googleapis.com/v1alpha/projects/{}/assets?assetId={}
# https://earthengine.googleapis.com/v1alpha/projects/akveg-map/assets?assetId=dynamic_world_metrics/s2_dw_percentages_56789_v20250414/s2_dw_pct_56789_AK050H47V02_v20250414
# s2_dw_pct_56789_AK050H47V03_v20250414
# ['s2', 'dw', 'pct', '56789', 'AK050H47V03', 'v20250414', 'tif']
# 56789
# AK050H47V03
# v20250414
# ('{"type": "IMAGE", "gcs_location": {"uris": '
#  '"gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H47V03_v20250414.tif"}, '
#  '"properties": {"months": "56789", "tile": "AK050H47V03", "version_counts": '
#  '"v20250414"}}')
# https://earthengine.googleapis.com/v1alpha/projects/{}/assets?assetId={}
# https://earthengine.googleapis.com/v1alpha/projects/akveg-map/assets?assetId=dynamic_world_metrics/s2_dw_percentages_56789_v20250414/s2_dw_pct_56789_AK050H47V03_v20250414
# s2_dw_pct_56789_AK050H47V04_v20250414
# ['s2', 'dw', 'pct', '56789', 'AK050H47V04', 'v20250414', 'tif']
# 56789
# AK050H47V04
# v20250414
# ('{"type": "IMAGE", "gcs_location": {"uris": '
#  '"gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H47V04_v20250414.tif"}, '
#  '"properties": {"months": "56789", "tile": "AK050H47V04", "version_counts": '
#  '"v20250414"}}')
# https://earthengine.googleapis.com/v1alpha/projects/{}/assets?assetId={}
# https://earthengine.googleapis.com/v1alpha/projects/akveg-map/assets?assetId=dynamic_world_metrics/s2_dw_percentages_56789_v20250414/s2_dw_pct_56789_AK050H47V04_v20250414
# s2_dw_pct_56789_AK050H47V05_v20250414
# ['s2', 'dw', 'pct', '56789', 'AK050H47V05', 'v20250414', 'tif']
# 56789
# AK050H47V05
# v20250414
# ('{"type": "IMAGE", "gcs_location": {"uris": '
#  '"gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H47V05_v20250414.tif"}, '
#  '"properties": {"months": "56789", "tile": "AK050H47V05", "version_counts": '
#  '"v20250414"}}')
# https://earthengine.googleapis.com/v1alpha/projects/{}/assets?assetId={}
# https://earthengine.googleapis.com/v1alpha/projects/akveg-map/assets?assetId=dynamic_world_metrics/s2_dw_percentages_56789_v20250414/s2_dw_pct_56789_AK050H47V05_v20250414
# s2_dw_pct_56789_AK050H47V06_v20250414
# ['s2', 'dw', 'pct', '56789', 'AK050H47V06', 'v20250414', 'tif']
# 56789
# AK050H47V06
# v20250414
# ('{"type": "IMAGE", "gcs_location": {"uris": '
#  '"gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H47V06_v20250414.tif"}, '
#  '"properties": {"months": "56789", "tile": "AK050H47V06", "version_counts": '
#  '"v20250414"}}')
# https://earthengine.googleapis.com/v1alpha/projects/{}/assets?assetId={}
# https://earthengine.googleapis.com/v1alpha/projects/akveg-map/assets?assetId=dynamic_world_metrics/s2_dw_percentages_56789_v20250414/s2_dw_pct_56789_AK050H47V06_v20250414
# s2_dw_pct_56789_AK050H47V07_v20250414
# ['s2', 'dw', 'pct', '56789', 'AK050H47V07', 'v20250414', 'tif']
# 56789
# AK050H47V07
# v20250414
# ('{"type": "IMAGE", "gcs_location": {"uris": '
#  '"gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H47V07_v20250414.tif"}, '
#  '"properties": {"months": "56789", "tile": "AK050H47V07", "version_counts": '
#  '"v20250414"}}')
# https://earthengine.googleapis.com/v1alpha/projects/{}/assets?assetId={}
# https://earthengine.googleapis.com/v1alpha/projects/akveg-map/assets?assetId=dynamic_world_metrics/s2_dw_percentages_56789_v20250414/s2_dw_pct_56789_AK050H47V07_v20250414
# s2_dw_pct_56789_AK050H47V08_v20250414
# ['s2', 'dw', 'pct', '56789', 'AK050H47V08', 'v20250414', 'tif']
# 56789
# AK050H47V08
# v20250414
# ('{"type": "IMAGE", "gcs_location": {"uris": '
#  '"gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H47V08_v20250414.tif"}, '
#  '"properties": {"months": "56789", "tile": "AK050H47V08", "version_counts": '
#  '"v20250414"}}')
# https://earthengine.googleapis.com/v1alpha/projects/{}/assets?assetId={}
# https://earthengine.googleapis.com/v1alpha/projects/akveg-map/assets?assetId=dynamic_world_metrics/s2_dw_percentages_56789_v20250414/s2_dw_pct_56789_AK050H47V08_v20250414
# s2_dw_pct_56789_AK050H47V09_v20250414
# ['s2', 'dw', 'pct', '56789', 'AK050H47V09', 'v20250414', 'tif']
# 56789
# AK050H47V09
# v20250414
# ('{"type": "IMAGE", "gcs_location": {"uris": '
#  '"gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H47V09_v20250414.tif"}, '
#  '"properties": {"months": "56789", "tile": "AK050H47V09", "version_counts": '
#  '"v20250414"}}')
# https://earthengine.googleapis.com/v1alpha/projects/{}/assets?assetId={}
# https://earthengine.googleapis.com/v1alpha/projects/akveg-map/assets?assetId=dynamic_world_metrics/s2_dw_percentages_56789_v20250414/s2_dw_pct_56789_AK050H47V09_v20250414
# s2_dw_pct_56789_AK050H47V10_v20250414
# ['s2', 'dw', 'pct', '56789', 'AK050H47V10', 'v20250414', 'tif']
# 56789
# AK050H47V10
# v20250414
# ('{"type": "IMAGE", "gcs_location": {"uris": '
#  '"gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H47V10_v20250414.tif"}, '
#  '"properties": {"months": "56789", "tile": "AK050H47V10", "version_counts": '
#  '"v20250414"}}')
# https://earthengine.googleapis.com/v1alpha/projects/{}/assets?assetId={}
# https://earthengine.googleapis.com/v1alpha/projects/akveg-map/assets?assetId=dynamic_world_metrics/s2_dw_percentages_56789_v20250414/s2_dw_pct_56789_AK050H47V10_v20250414
# s2_dw_pct_56789_AK050H47V11_v20250414
# ['s2', 'dw', 'pct', '56789', 'AK050H47V11', 'v20250414', 'tif']
# 56789
# AK050H47V11
# v20250414
# ('{"type": "IMAGE", "gcs_location": {"uris": '
#  '"gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H47V11_v20250414.tif"}, '
#  '"properties": {"months": "56789", "tile": "AK050H47V11", "version_counts": '
#  '"v20250414"}}')
# https://earthengine.googleapis.com/v1alpha/projects/{}/assets?assetId={}
# https://earthengine.googleapis.com/v1alpha/projects/akveg-map/assets?assetId=dynamic_world_metrics/s2_dw_percentages_56789_v20250414/s2_dw_pct_56789_AK050H47V11_v20250414
# s2_dw_pct_56789_AK050H47V12_v20250414
# ['s2', 'dw', 'pct', '56789', 'AK050H47V12', 'v20250414', 'tif']
# 56789
# AK050H47V12
# v20250414
# ('{"type": "IMAGE", "gcs_location": {"uris": '
#  '"gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H47V12_v20250414.tif"}, '
#  '"properties": {"months": "56789", "tile": "AK050H47V12", "version_counts": '
#  '"v20250414"}}')
# https://earthengine.googleapis.com/v1alpha/projects/{}/assets?assetId={}
# https://earthengine.googleapis.com/v1alpha/projects/akveg-map/assets?assetId=dynamic_world_metrics/s2_dw_percentages_56789_v20250414/s2_dw_pct_56789_AK050H47V12_v20250414
# s2_dw_pct_56789_AK050H47V13_v20250414
# ...
# https://earthengine.googleapis.com/v1alpha/projects/akveg-map/assets?assetId=dynamic_world_metrics/s2_dw_percentages_56789_v20250414/s2_dw_pct_56789_AK050H49V03_v20250414
# s2_dw_pct_56789_AK050H49V04_v20250414
# ['s2', 'dw', 'pct', '56789', 'AK050H49V04', 'v20250414', 'tif']
# 56789
# AK050H49V04
# v20250414
# ('{"type": "IMAGE", "gcs_location": {"uris": '
#  '"gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H49V04_v20250414.tif"}, '
#  '"properties": {"months": "56789", "tile": "AK050H49V04", "version_counts": '
#  '"v20250414"}}')
# https://earthengine.googleapis.com/v1alpha/projects/{}/assets?assetId={}
# https://earthengine.googleapis.com/v1alpha/projects/akveg-map/assets?assetId=dynamic_world_metrics/s2_dw_percentages_56789_v20250414/s2_dw_pct_56789_AK050H49V04_v20250414
# s2_dw_pct_56789_AK050H49V05_v20250414
# ['s2', 'dw', 'pct', '56789', 'AK050H49V05', 'v20250414', 'tif']
# 56789
# AK050H49V05
# v20250414
# ('{"type": "IMAGE", "gcs_location": {"uris": '
#  '"gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H49V05_v20250414.tif"}, '
#  '"properties": {"months": "56789", "tile": "AK050H49V05", "version_counts": '
#  '"v20250414"}}')
# https://earthengine.googleapis.com/v1alpha/projects/{}/assets?assetId={}
# https://earthengine.googleapis.com/v1alpha/projects/akveg-map/assets?assetId=dynamic_world_metrics/s2_dw_percentages_56789_v20250414/s2_dw_pct_56789_AK050H49V05_v20250414
# s2_dw_pct_56789_AK050H49V06_v20250414
# ['s2', 'dw', 'pct', '56789', 'AK050H49V06', 'v20250414', 'tif']
# 56789
# AK050H49V06
# v20250414
# ('{"type": "IMAGE", "gcs_location": {"uris": '
#  '"gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H49V06_v20250414.tif"}, '
#  '"properties": {"months": "56789", "tile": "AK050H49V06", "version_counts": '
#  '"v20250414"}}')
# https://earthengine.googleapis.com/v1alpha/projects/{}/assets?assetId={}
# https://earthengine.googleapis.com/v1alpha/projects/akveg-map/assets?assetId=dynamic_world_metrics/s2_dw_percentages_56789_v20250414/s2_dw_pct_56789_AK050H49V06_v20250414
# s2_dw_pct_56789_AK050H49V07_v20250414
# ['s2', 'dw', 'pct', '56789', 'AK050H49V07', 'v20250414', 'tif']
# 56789
# AK050H49V07
# v20250414
# ('{"type": "IMAGE", "gcs_location": {"uris": '
#  '"gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H49V07_v20250414.tif"}, '
#  '"properties": {"months": "56789", "tile": "AK050H49V07", "version_counts": '
#  '"v20250414"}}')
# https://earthengine.googleapis.com/v1alpha/projects/{}/assets?assetId={}
# https://earthengine.googleapis.com/v1alpha/projects/akveg-map/assets?assetId=dynamic_world_metrics/s2_dw_percentages_56789_v20250414/s2_dw_pct_56789_AK050H49V07_v20250414
# s2_dw_pct_56789_AK050H49V08_v20250414
# ['s2', 'dw', 'pct', '56789', 'AK050H49V08', 'v20250414', 'tif']
# 56789
# AK050H49V08
# v20250414
# ('{"type": "IMAGE", "gcs_location": {"uris": '
#  '"gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H49V08_v20250414.tif"}, '
#  '"properties": {"months": "56789", "tile": "AK050H49V08", "version_counts": '
#  '"v20250414"}}')
# https://earthengine.googleapis.com/v1alpha/projects/{}/assets?assetId={}
# https://earthengine.googleapis.com/v1alpha/projects/akveg-map/assets?assetId=dynamic_world_metrics/s2_dw_percentages_56789_v20250414/s2_dw_pct_56789_AK050H49V08_v20250414
# s2_dw_pct_56789_AK050H49V09_v20250414
# ['s2', 'dw', 'pct', '56789', 'AK050H49V09', 'v20250414', 'tif']
# 56789
# AK050H49V09
# v20250414
# ('{"type": "IMAGE", "gcs_location": {"uris": '
#  '"gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H49V09_v20250414.tif"}, '
#  '"properties": {"months": "56789", "tile": "AK050H49V09", "version_counts": '
#  '"v20250414"}}')
# https://earthengine.googleapis.com/v1alpha/projects/{}/assets?assetId={}
# https://earthengine.googleapis.com/v1alpha/projects/akveg-map/assets?assetId=dynamic_world_metrics/s2_dw_percentages_56789_v20250414/s2_dw_pct_56789_AK050H49V09_v20250414
# s2_dw_pct_56789_AK050H49V10_v20250414
# ['s2', 'dw', 'pct', '56789', 'AK050H49V10', 'v20250414', 'tif']
# 56789
# AK050H49V10
# v20250414
# ('{"type": "IMAGE", "gcs_location": {"uris": '
#  '"gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H49V10_v20250414.tif"}, '
#  '"properties": {"months": "56789", "tile": "AK050H49V10", "version_counts": '
#  '"v20250414"}}')
# https://earthengine.googleapis.com/v1alpha/projects/{}/assets?assetId={}
# https://earthengine.googleapis.com/v1alpha/projects/akveg-map/assets?assetId=dynamic_world_metrics/s2_dw_percentages_56789_v20250414/s2_dw_pct_56789_AK050H49V10_v20250414
# s2_dw_pct_56789_AK050H49V11_v20250414
# ['s2', 'dw', 'pct', '56789', 'AK050H49V11', 'v20250414', 'tif']
# 56789
# AK050H49V11
# v20250414
# ('{"type": "IMAGE", "gcs_location": {"uris": '
#  '"gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H49V11_v20250414.tif"}, '
#  '"properties": {"months": "56789", "tile": "AK050H49V11", "version_counts": '
#  '"v20250414"}}')
# https://earthengine.googleapis.com/v1alpha/projects/{}/assets?assetId={}
# https://earthengine.googleapis.com/v1alpha/projects/akveg-map/assets?assetId=dynamic_world_metrics/s2_dw_percentages_56789_v20250414/s2_dw_pct_56789_AK050H49V11_v20250414
# s2_dw_pct_56789_AK050H49V12_v20250414
# ['s2', 'dw', 'pct', '56789', 'AK050H49V12', 'v20250414', 'tif']
# 56789
# AK050H49V12
# v20250414
# ('{"type": "IMAGE", "gcs_location": {"uris": '
#  '"gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H49V12_v20250414.tif"}, '
#  '"properties": {"months": "56789", "tile": "AK050H49V12", "version_counts": '
#  '"v20250414"}}')
# https://earthengine.googleapis.com/v1alpha/projects/{}/assets?assetId={}
# https://earthengine.googleapis.com/v1alpha/projects/akveg-map/assets?assetId=dynamic_world_metrics/s2_dw_percentages_56789_v20250414/s2_dw_pct_56789_AK050H49V12_v20250414
# s2_dw_pct_56789_AK050H49V13_v20250414
# ['s2', 'dw', 'pct', '56789', 'AK050H49V13', 'v20250414', 'tif']
# 56789
# AK050H49V13
# v20250414
# ('{"type": "IMAGE", "gcs_location": {"uris": '
#  '"gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H49V13_v20250414.tif"}, '
#  '"properties": {"months": "56789", "tile": "AK050H49V13", "version_counts": '
#  '"v20250414"}}')
# https://earthengine.googleapis.com/v1alpha/projects/{}/assets?assetId={}
# https://earthengine.googleapis.com/v1alpha/projects/akveg-map/assets?assetId=dynamic_world_metrics/s2_dw_percentages_56789_v20250414/s2_dw_pct_56789_AK050H49V13_v20250414
# s2_dw_pct_56789_AK050H49V14_v20250414
# ['s2', 'dw', 'pct', '56789', 'AK050H49V14', 'v20250414', 'tif']
# 56789
# AK050H49V14
# v20250414
# ('{"type": "IMAGE", "gcs_location": {"uris": '
#  '"gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H49V14_v20250414.tif"}, '
#  '"properties": {"months": "56789", "tile": "AK050H49V14", "version_counts": '
#  '"v20250414"}}')
# https://earthengine.googleapis.com/v1alpha/projects/{}/assets?assetId={}
# https://earthengine.googleapis.com/v1alpha/projects/akveg-map/assets?assetId=dynamic_world_metrics/s2_dw_percentages_56789_v20250414/s2_dw_pct_56789_AK050H49V14_v20250414
# s2_dw_pct_56789_AK050H49V15_v20250414
# ['s2', 'dw', 'pct', '56789', 'AK050H49V15', 'v20250414', 'tif']
# 56789
# AK050H49V15
# v20250414
# ('{"type": "IMAGE", "gcs_location": {"uris": '
#  '"gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H49V15_v20250414.tif"}, '
#  '"properties": {"months": "56789", "tile": "AK050H49V15", "version_counts": '
#  '"v20250414"}}')
# https://earthengine.googleapis.com/v1alpha/projects/{}/assets?assetId={}
# https://earthengine.googleapis.com/v1alpha/projects/akveg-map/assets?assetId=dynamic_world_metrics/s2_dw_percentages_56789_v20250414/s2_dw_pct_56789_AK050H49V15_v20250414
# s2_dw_pct_56789_AK050H49V16_v20250414
# ['s2', 'dw', 'pct', '56789', 'AK050H49V16', 'v20250414', 'tif']
# 56789
# AK050H49V16
# v20250414
# ('{"type": "IMAGE", "gcs_location": {"uris": '
#  '"gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H49V16_v20250414.tif"}, '
#  '"properties": {"months": "56789", "tile": "AK050H49V16", "version_counts": '
#  '"v20250414"}}')
# https://earthengine.googleapis.com/v1alpha/projects/{}/assets?assetId={}
# https://earthengine.googleapis.com/v1alpha/projects/akveg-map/assets?assetId=dynamic_world_metrics/s2_dw_percentages_56789_v20250414/s2_dw_pct_56789_AK050H49V16_v20250414
# s2_dw_pct_56789_AK050H49V17_v20250414
# ['s2', 'dw', 'pct', '56789', 'AK050H49V17', 'v20250414', 'tif']
# 56789
# AK050H49V17
# v20250414
# ('{"type": "IMAGE", "gcs_location": {"uris": '
#  '"gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H49V17_v20250414.tif"}, '
#  '"properties": {"months": "56789", "tile": "AK050H49V17", "version_counts": '
#  '"v20250414"}}')
# https://earthengine.googleapis.com/v1alpha/projects/{}/assets?assetId={}
# https://earthengine.googleapis.com/v1alpha/projects/akveg-map/assets?assetId=dynamic_world_metrics/s2_dw_percentages_56789_v20250414/s2_dw_pct_56789_AK050H49V17_v20250414
# s2_dw_pct_56789_AK050H49V18_v20250414
# ['s2', 'dw', 'pct', '56789', 'AK050H49V18', 'v20250414', 'tif']
# 56789
# AK050H49V18
# v20250414
# ('{"type": "IMAGE", "gcs_location": {"uris": '
#  '"gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H49V18_v20250414.tif"}, '
#  '"properties": {"months": "56789", "tile": "AK050H49V18", "version_counts": '
#  '"v20250414"}}')
# https://earthengine.googleapis.com/v1alpha/projects/{}/assets?assetId={}
# https://earthengine.googleapis.com/v1alpha/projects/akveg-map/assets?assetId=dynamic_world_metrics/s2_dw_percentages_56789_v20250414/s2_dw_pct_56789_AK050H49V18_v20250414
# s2_dw_pct_56789_AK050H49V19_v20250414
# ['s2', 'dw', 'pct', '56789', 'AK050H49V19', 'v20250414', 'tif']
# 56789
# AK050H49V19
# v20250414
# ('{"type": "IMAGE", "gcs_location": {"uris": '
#  '"gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H49V19_v20250414.tif"}, '
#  '"properties": {"months": "56789", "tile": "AK050H49V19", "version_counts": '
#  '"v20250414"}}')
# https://earthengine.googleapis.com/v1alpha/projects/{}/assets?assetId={}
# https://earthengine.googleapis.com/v1alpha/projects/akveg-map/assets?assetId=dynamic_world_metrics/s2_dw_percentages_56789_v20250414/s2_dw_pct_56789_AK050H49V19_v20250414
# s2_dw_pct_56789_AK050H49V20_v20250414
# ['s2', 'dw', 'pct', '56789', 'AK050H49V20', 'v20250414', 'tif']
# 56789
# AK050H49V20
# v20250414
# ('{"type": "IMAGE", "gcs_location": {"uris": '
#  '"gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H49V20_v20250414.tif"}, '
#  '"properties": {"months": "56789", "tile": "AK050H49V20", "version_counts": '
#  '"v20250414"}}')
# https://earthengine.googleapis.com/v1alpha/projects/{}/assets?assetId={}
# https://earthengine.googleapis.com/v1alpha/projects/akveg-map/assets?assetId=dynamic_world_metrics/s2_dw_percentages_56789_v20250414/s2_dw_pct_56789_AK050H49V20_v20250414
# s2_dw_pct_56789_AK050H49V21_v20250414
# ['s2', 'dw', 'pct', '56789', 'AK050H49V21', 'v20250414', 'tif']
# 56789
# AK050H49V21
# v20250414
# ('{"type": "IMAGE", "gcs_location": {"uris": '
#  '"gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H49V21_v20250414.tif"}, '
#  '"properties": {"months": "56789", "tile": "AK050H49V21", "version_counts": '
#  '"v20250414"}}')
# https://earthengine.googleapis.com/v1alpha/projects/{}/assets?assetId={}
# https://earthengine.googleapis.com/v1alpha/projects/akveg-map/assets?assetId=dynamic_world_metrics/s2_dw_percentages_56789_v20250414/s2_dw_pct_56789_AK050H49V21_v20250414
# s2_dw_pct_56789_AK050H49V22_v20250414
# ['s2', 'dw', 'pct', '56789', 'AK050H49V22', 'v20250414', 'tif']
# 56789
# AK050H49V22
# v20250414
# ('{"type": "IMAGE", "gcs_location": {"uris": '
#  '"gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H49V22_v20250414.tif"}, '
#  '"properties": {"months": "56789", "tile": "AK050H49V22", "version_counts": '
#  '"v20250414"}}')
# https://earthengine.googleapis.com/v1alpha/projects/{}/assets?assetId={}
# https://earthengine.googleapis.com/v1alpha/projects/akveg-map/assets?assetId=dynamic_world_metrics/s2_dw_percentages_56789_v20250414/s2_dw_pct_56789_AK050H49V22_v20250414
# s2_dw_pct_56789_AK050H49V23_v20250414
# ['s2', 'dw', 'pct', '56789', 'AK050H49V23', 'v20250414', 'tif']
# 56789
# AK050H49V23
# v20250414
# ('{"type": "IMAGE", "gcs_location": {"uris": '
#  '"gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H49V23_v20250414.tif"}, '
#  '"properties": {"months": "56789", "tile": "AK050H49V23", "version_counts": '
#  '"v20250414"}}')
# https://earthengine.googleapis.com/v1alpha/projects/{}/assets?assetId={}
# https://earthengine.googleapis.com/v1alpha/projects/akveg-map/assets?assetId=dynamic_world_metrics/s2_dw_percentages_56789_v20250414/s2_dw_pct_56789_AK050H49V23_v20250414
# s2_dw_pct_56789_AK050H49V24_v20250414
# ['s2', 'dw', 'pct', '56789', 'AK050H49V24', 'v20250414', 'tif']
# 56789
# AK050H49V24
# v20250414
# ('{"type": "IMAGE", "gcs_location": {"uris": '
#  '"gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H49V24_v20250414.tif"}, '
#  '"properties": {"months": "56789", "tile": "AK050H49V24", "version_counts": '
#  '"v20250414"}}')
# https://earthengine.googleapis.com/v1alpha/projects/{}/assets?assetId={}
# https://earthengine.googleapis.com/v1alpha/projects/akveg-map/assets?assetId=dynamic_world_metrics/s2_dw_percentages_56789_v20250414/s2_dw_pct_56789_AK050H49V24_v20250414
# s2_dw_pct_56789_AK050H49V25_v20250414
# ['s2', 'dw', 'pct', '56789', 'AK050H49V25', 'v20250414', 'tif']
# 56789
# AK050H49V25
# v20250414
# ('{"type": "IMAGE", "gcs_location": {"uris": '
#  '"gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H49V25_v20250414.tif"}, '
#  '"properties": {"months": "56789", "tile": "AK050H49V25", "version_counts": '
#  '"v20250414"}}')
# https://earthengine.googleapis.com/v1alpha/projects/{}/assets?assetId={}
# https://earthengine.googleapis.com/v1alpha/projects/akveg-map/assets?assetId=dynamic_world_metrics/s2_dw_percentages_56789_v20250414/s2_dw_pct_56789_AK050H49V25_v20250414
# s2_dw_pct_56789_AK050H49V26_v20250414
# ['s2', 'dw', 'pct', '56789', 'AK050H49V26', 'v20250414', 'tif']
# 56789
# AK050H49V26
# v20250414
# ('{"type": "IMAGE", "gcs_location": {"uris": '
#  '"gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H49V26_v20250414.tif"}, '
#  '"properties": {"months": "56789", "tile": "AK050H49V26", "version_counts": '
#  '"v20250414"}}')
# https://earthengine.googleapis.com/v1alpha/projects/{}/assets?assetId={}
# https://earthengine.googleapis.com/v1alpha/projects/akveg-map/assets?assetId=dynamic_world_metrics/s2_dw_percentages_56789_v20250414/s2_dw_pct_56789_AK050H49V26_v20250414
# s2_dw_pct_56789_AK050H49V27_v20250414
# ['s2', 'dw', 'pct', '56789', 'AK050H49V27', 'v20250414', 'tif']
# 56789
# AK050H49V27
# v20250414
# ('{"type": "IMAGE", "gcs_location": {"uris": '
#  '"gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H49V27_v20250414.tif"}, '
#  '"properties": {"months": "56789", "tile": "AK050H49V27", "version_counts": '
#  '"v20250414"}}')
# https://earthengine.googleapis.com/v1alpha/projects/{}/assets?assetId={}
# https://earthengine.googleapis.com/v1alpha/projects/akveg-map/assets?assetId=dynamic_world_metrics/s2_dw_percentages_56789_v20250414/s2_dw_pct_56789_AK050H49V27_v20250414
# s2_dw_pct_56789_AK050H49V28_v20250414
# ['s2', 'dw', 'pct', '56789', 'AK050H49V28', 'v20250414', 'tif']
# 56789
# AK050H49V28
# v20250414
# ('{"type": "IMAGE", "gcs_location": {"uris": '
#  '"gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H49V28_v20250414.tif"}, '
#  '"properties": {"months": "56789", "tile": "AK050H49V28", "version_counts": '
#  '"v20250414"}}')
# https://earthengine.googleapis.com/v1alpha/projects/{}/assets?assetId={}
# https://earthengine.googleapis.com/v1alpha/projects/akveg-map/assets?assetId=dynamic_world_metrics/s2_dw_percentages_56789_v20250414/s2_dw_pct_56789_AK050H49V28_v20250414
# done

# %% [raw]
# Get summary of compute effort (EECUs) and GCS storage
# Note this includes all tasks in queue and some filtering may be required to narrow down to a particular script
#
# To get size and count of exports:
# (ee) mmacander@mason:/data/gis/raster_base/Alaska/AKVegMap/dynamic_world$ gsutil du -sh gs://akveg-data/s2_dw_v1_metrics/s2_dw_monthly_counts_mgrs_v20250414b
# 259.31 GiB   gs://akveg-data/s2_dw_v1_metrics/s2_dw_monthly_counts_mgrs_v20250414b
# (ee) mmacander@mason:/data/gis/raster_base/Alaska/AKVegMap/dynamic_world$ gsutil ls gs://akveg-data/s2_dw_v1_metrics/s2_dw_monthly_counts_mgrs_v20250414b/*.tif | wc -l
# 7
# 53

# %%
import ee
import pandas as pd
from datetime import datetime, timezone

# Initialize Earth Engine
ee.Initialize()

# Parse Alaska time in format: 'YYYY-MM-DD HH:MM:SS -0800'
def parse_alaska_offset(s):
    return datetime.strptime(s, '%Y-%m-%d %H:%M:%S %z').astimezone(timezone.utc)

# Input times (Alaska time with UTC offset)
start_str = '2025-04-23 21:20:00 -0800'
end_str   = '2025-04-24 12:00:00 -0800'

start_dt = parse_alaska_offset(start_str)
end_dt   = parse_alaska_offset(end_str)

# List tasks
ops = ee.data.listOperations()

# Filter and collect metadata
all_keys = set()
filtered_ops = []
for op in ops:
    meta = op.get('metadata', {})
    create_time = meta.get('createTime')
    if create_time:
        create_dt = datetime.fromisoformat(create_time.replace('Z', '+00:00'))
        if start_dt <= create_dt <= end_dt:
            filtered_ops.append(op)
            all_keys.update(meta.keys())

# Build rows
all_keys = sorted(all_keys)
rows = []
for op in filtered_ops:
    meta = op.get('metadata', {})
    row = {key: meta.get(key, None) for key in all_keys}
    row['task_id'] = op.get('name', '').split('/')[-1]
    row['state'] = 'DONE' if op.get('done') else 'RUNNING'
    rows.append(row)

# Save to CSV
df = pd.DataFrame(rows)
df.to_csv('/data/gis/raster_base/Alaska/AKVegMap/dynamic_world/gee_tasks_all_metadata_20250424.csv', index=False)

# %%
df
# Out:
#                                                  @type  attempt
# 0    type.googleapis.com/google.earthengine.v1alpha...        1  \
# 1    type.googleapis.com/google.earthengine.v1alpha...        1
# 2    type.googleapis.com/google.earthengine.v1alpha...        1
# 3    type.googleapis.com/google.earthengine.v1alpha...        1
# 4    type.googleapis.com/google.earthengine.v1alpha...        1
# ..                                                 ...      ...
# 144  type.googleapis.com/google.earthengine.v1alpha...        1
# 145  type.googleapis.com/google.earthengine.v1alpha...        1
# 146  type.googleapis.com/google.earthengine.v1alpha...        1
# 147  type.googleapis.com/google.earthengine.v1alpha...        1
# 148  type.googleapis.com/google.earthengine.v1alpha...        1
#
#      batchEecuUsageSeconds                   createTime
# 0               826.518005  2025-04-24T05:29:15.888897Z  \
# 1               836.197937  2025-04-24T05:29:14.211265Z
# 2               974.192444  2025-04-24T05:29:12.683765Z
# 3              1004.728760  2025-04-24T05:29:11.051134Z
# 4              1071.574829  2025-04-24T05:29:10.611571Z
# ..                     ...                          ...
# 144            1391.524658  2025-04-24T05:26:33.524848Z
# 145            1002.073303  2025-04-24T05:26:32.705022Z
# 146            1027.902100  2025-04-24T05:26:31.967841Z
# 147            1026.831909  2025-04-24T05:26:31.378892Z
# 148             710.842834  2025-04-24T05:26:30.621358Z
#
#                                   description
# 0    s2_dw_counts_56789_AK050H49V28_v20250414  \
# 1    s2_dw_counts_56789_AK050H49V27_v20250414
# 2    s2_dw_counts_56789_AK050H49V26_v20250414
# 3    s2_dw_counts_56789_AK050H49V25_v20250414
# 4    s2_dw_counts_56789_AK050H49V24_v20250414
# ..                                        ...
# 144  s2_dw_counts_56789_AK050H45V06_v20250414
# 145  s2_dw_counts_56789_AK050H45V05_v20250414
# 146  s2_dw_counts_56789_AK050H45V04_v20250414
# 147  s2_dw_counts_56789_AK050H45V03_v20250414
# 148  s2_dw_counts_56789_AK050H45V02_v20250414
#
#                                        destinationUris
# 0    [https://console.developers.google.com/storage...  \
# 1    [https://console.developers.google.com/storage...
# 2    [https://console.developers.google.com/storage...
# 3    [https://console.developers.google.com/storage...
# 4    [https://console.developers.google.com/storage...
# ..                                                 ...
# 144  [https://console.developers.google.com/storage...
# 145  [https://console.developers.google.com/storage...
# 146  [https://console.developers.google.com/storage...
# 147  [https://console.developers.google.com/storage...
# 148  [https://console.developers.google.com/storage...
#
#                          endTime  priority  progress
# 0    2025-04-24T10:34:22.985572Z       100         1  \
# 1    2025-04-24T10:30:01.597381Z       100         1
# 2    2025-04-24T10:30:52.891383Z       100         1
# 3    2025-04-24T10:29:35.989644Z       100         1
# 4    2025-04-24T10:25:27.482684Z       100         1
# ..                           ...       ...       ...
# 144  2025-04-24T05:39:50.762868Z       100         1
# 145  2025-04-24T05:39:00.187884Z       100         1
# 146  2025-04-24T05:31:52.779940Z       100         1
# 147  2025-04-24T05:31:53.740674Z       100         1
# 148  2025-04-24T05:31:00.586398Z       100         1
#
#                                              scriptUri
# 0    https://code.earthengine.google.com/49ddd8d72d...  \
# 1    https://code.earthengine.google.com/49ddd8d72d...
# 2    https://code.earthengine.google.com/49ddd8d72d...
# 3    https://code.earthengine.google.com/49ddd8d72d...
# 4    https://code.earthengine.google.com/49ddd8d72d...
# ..                                                 ...
# 144  https://code.earthengine.google.com/49ddd8d72d...
# 145  https://code.earthengine.google.com/49ddd8d72d...
# 146  https://code.earthengine.google.com/49ddd8d72d...
# 147  https://code.earthengine.google.com/49ddd8d72d...
# 148  https://code.earthengine.google.com/49ddd8d72d...
#
#                                                 stages
# 0    [{'displayName': 'Create Local Files', 'comple...  \
# 1    [{'displayName': 'Create Local Files', 'comple...
# 2    [{'displayName': 'Create Local Files', 'comple...
# 3    [{'displayName': 'Create Local Files', 'comple...
# 4    [{'displayName': 'Create Local Files', 'comple...
# ..                                                 ...
# 144  [{'displayName': 'Create Local Files', 'comple...
# 145  [{'displayName': 'Create Local Files', 'comple...
# 146  [{'displayName': 'Create Local Files', 'comple...
# 147  [{'displayName': 'Create Local Files', 'comple...
# 148  [{'displayName': 'Create Local Files', 'comple...
#
#                        startTime state          type
# 0    2025-04-24T10:29:42.863929Z  DONE  EXPORT_IMAGE  \
# 1    2025-04-24T10:26:37.135802Z  DONE  EXPORT_IMAGE
# 2    2025-04-24T10:25:58.281718Z  DONE  EXPORT_IMAGE
# 3    2025-04-24T10:25:34.665567Z  DONE  EXPORT_IMAGE
# 4    2025-04-24T10:21:03.927804Z  DONE  EXPORT_IMAGE
# ..                           ...   ...           ...
# 144  2025-04-24T05:31:59.327517Z  DONE  EXPORT_IMAGE
# 145  2025-04-24T05:31:06.619897Z  DONE  EXPORT_IMAGE
# 146  2025-04-24T05:26:38.401424Z  DONE  EXPORT_IMAGE
# 147  2025-04-24T05:26:38.419884Z  DONE  EXPORT_IMAGE
# 148  2025-04-24T05:26:38.422093Z  DONE  EXPORT_IMAGE
#
#                       updateTime                   task_id
# 0    2025-04-24T10:34:22.985572Z  QAEYTGADQC77NUSISQB6OF3C
# 1    2025-04-24T10:30:01.597381Z  2A7XCJKAQCCUT5AUUTMNGYCA
# 2    2025-04-24T10:30:52.891383Z  WKCA2QKDXFJAXF2R3E4IULQN
# 3    2025-04-24T10:29:35.989644Z  BRCDHDEIFSCGNZ5SZULWFECY
# 4    2025-04-24T10:25:27.482684Z  NEYXC3VWTRJCGLKNFFLLM3BX
# ..                           ...                       ...
# 144  2025-04-24T05:39:50.762868Z  P5JVDYFMLG45NWSX432IZ4GN
# 145  2025-04-24T05:39:00.187884Z  N7HVKEDDSLZBR3ZQCVEF7DFE
# 146  2025-04-24T05:31:52.779940Z  ESVK6GSLUQGKZTV3BZZJQLIR
# 147  2025-04-24T05:31:53.740674Z  QGOMIWKW6VO5CHISEFUIGE72
# 148  2025-04-24T05:31:00.586398Z  4WCVEL7ILZHUMGGUOXTA4KWI
#
# [149 rows x 16 columns]

# %%
import ee
ee.Initialize()

operations = ee.data.listOperations()

# Filter for failed or cancelled tasks
failed_ops = [
    op for op in operations
    if op.get('metadata', {}).get('state') in ['FAILED', 'CANCELLED']
]

# Print summary
for op in failed_ops:
    meta = op['metadata']
    print(f"Task ID: {op['name'].split('/')[-1]}")
    print(f"Description: {meta.get('description', 'N/A')}")
    print(f"State: {meta.get('state')}")
    print(f"Error: {meta.get('errorMessage', 'None')}")
    print('-' * 40)

# Need to redo two (maybe no granules for that month?)
# s2_dw_counts_month05_03UUV_v20250414
# s2_dw_counts_month06_01UCS_v20250414
# Out:
# Task ID: GXLT5QBVB64VCFROC5U47ZMV
# Description: s2_dw_counts_month05_03UUV_v20250414
# State: FAILED
# Error: None
# ----------------------------------------
# Task ID: 273PJSOXO4FQ7GXVGDPDSR52
# Description: s2_dw_counts_month06_01UCS_v20250414
# State: FAILED
# Error: None
# ----------------------------------------
# Task ID: 32BQ2LQ46S6JIDHWVN7Q7NYS
# Description: s2_dw_counts_month07_06VUQ_v20250414
# State: FAILED
# Error: None
# ----------------------------------------
# Task ID: 4GSBFOYQF6U34VUT7EZU4EOY
# Description: s2_dw_counts_month07_06VUQ_v20250414
# State: FAILED
# Error: None
# ----------------------------------------
# Task ID: 6FIFZTCXEMGQGGHGDOLJUWAI
# Description: s2_dw_counts_month07_06VUQ_v20250414
# State: CANCELLED
# Error: None
# ----------------------------------------
# Task ID: UNSCUHRMP243PK23WQ3D2BWX
# Description: s2_dw_counts_month07_06VUQ_v20250414
# State: FAILED
# Error: None
# ----------------------------------------
