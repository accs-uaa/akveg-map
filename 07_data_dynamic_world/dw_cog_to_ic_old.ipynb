# %% [markdown]
# # Cloud COGs to Image Collection

# %% [markdown]
# ## Setup

# %%
import ee
ee_project = 'akveg-map'

ee.Authenticate(auth_mode='notebook')  #  or !earthengine authenticate --auth_mode=gcloud

ee.Initialize(project=ee_project)
# ee.Authenticate()  #  or !earthengine authenticate --auth_mode=gcloud
# session = AuthorizedSession(ee.data.get_persistent_credentials())

# %%
import pandas as pd
from pathlib import Path
from datetime import datetime, timezone
import os
import re

from google.auth.transport.requests import AuthorizedSession

session = AuthorizedSession(
    ee.data.get_persistent_credentials().with_quota_project(ee_project)
)

# %% [markdown]
# ## Dynamic World Counts, raw by MGRS tile

# %% [markdown]
# ### Cleanup existing imageCollection, if needed
#
# imageCollections cannot be deleted until all images inside them are deleted. For a cloud-backed image collection with hundreds or thousands of tiles, this can take a while
#
# bash earthengine CLI
# ```
# for i in `earthengine ls projects/akveg-map/assets/dynamic_world_metrics/s2_dw_monthly_counts_mgrs_v20250414b`; do earthengine rm $i; done
#
# # earthengine rm projects/akveg-map/assets/s2_2019_2023_gMedian_v20240311
# ```

# %% [markdown]
# ### Create empty image collections as target
# TODO Automate creation of empty image collection.
#
# For now, manually create empty image collection with earthengine CLI

# %% [markdown]
# ```
# earthengine set_project akveg-map
# earthengine create collection projects/akveg-map/assets/dynamic_world_metrics/s2_dw_monthly_counts_mgrs_v20250414b
# ```

# %% [markdown]
# ### Create list of cloud geotiffs in bucket and image collection
#
# Create list of cogs in a bucket folder to load into an imageCollection.
#
# Create list of cogs that have already been loaded into the imageCollection.
#
# Run in bash in a conda env with gsutil and earthengine command line installed and authenticated.
#
# TODO: Configure it to run directly in python

# %% [markdown]
# ```
# cd /data/gis/raster_base/Alaska/AKVegMap/dynamic_world
#
# gsutil ls gs://akveg-data/s2_dw_v1_metrics/s2_dw_monthly_counts_mgrs_v20250414b/*.tif > dw_monthly_cogs.txt
# earthengine ls projects/akveg-map/assets/dynamic_world_metrics/s2_dw_monthly_counts_mgrs_v20250414b > dw_monthly_cogs_inColl.txt
#
# ```

# %%
# Function to read a text file and return a list of paths
def read_paths_from_file(filepath):
    with open(filepath, 'r') as file:
        paths = file.read().splitlines()
    return paths

# Function to extract the last part of the path and remove the extension
def get_filename_without_extension(path):
    return os.path.splitext(os.path.basename(path))[0]


# Function to save a list of paths to a text file
def save_paths_to_file(paths, filepath):
    with open(filepath, 'w') as file:
        for path in paths:
            file.write(f"{path}\n")

def in_list_1_not_list_2(csv1_path, csv2_path):
    cogList = read_paths_from_file(csv1_path)
    cogListIC = read_paths_from_file(csv2_path)
    
    filenames1 = [get_filename_without_extension(path) for path in cogList]
    filenames2 = [get_filename_without_extension(path) for path in cogListIC]
    
    # Convert lists to pd Series
    filenames_series1 = pd.Series(filenames1, index=cogList)
    filenames_series2 = pd.Series(filenames2, index=cogListIC)
    
    # Find filenames in list1 that are not in list2
    unique_to_list1 = filenames_series1[~filenames_series1.isin(filenames2)]
    
    print("\nPaths in list1 that are not in list2 based on filenames:")
    print(unique_to_list1.index.tolist()[:5])
    print(len(unique_to_list1.index.tolist()))
    
    return unique_to_list1

# %%
# Apply the functions to for full list and already loaded list of vhr_toa_cogs
unique_to_list1 = in_list_1_not_list_2('/data/gis/raster_base/Alaska/AKVegMap/dynamic_world/dw_monthly_cogs.txt',
                                       '/data/gis/raster_base/Alaska/AKVegMap/dynamic_world/dw_monthly_cogs_inColl.txt')

save_paths_to_file(unique_to_list1.index.tolist(), '/data/gis/raster_base/Alaska/AKVegMap/dynamic_world/dw_monthly_cogs_not_inColl.txt')
# Out:
# Paths in list1 that are not in list2 based on filenames:
# ['gs://akveg-data/s2_dw_v1_metrics/s2_dw_monthly_counts_mgrs_v20250414b/s2_dw_counts_mgrs_month05_03UUV_v20250414.tif', 'gs://akveg-data/s2_dw_v1_metrics/s2_dw_monthly_counts_mgrs_v20250414b/s2_dw_counts_mgrs_month06_01UCS_v20250414.tif']
# 2

# %% [markdown]
# ### Open list of geotiffs to ingest

# %%
dw_cogs = pd.read_csv('/data/gis/raster_base/Alaska/AKVegMap/dynamic_world/dw_monthly_cogs_not_inColl.txt', header=None,names=['tif'])
print(dw_cogs[0:2])
print(len(dw_cogs.index))
# Out:
#                                                  tif
# 0  gs://akveg-data/s2_dw_v1_metrics/s2_dw_monthly...
# 1  gs://akveg-data/s2_dw_v1_metrics/s2_dw_monthly...
# 2

# %% [markdown]
# ### Setup parameters

# %%
import json
# from urllib.parse import urlparse
import os
from pprint import pprint

# Earth Engine enabled Cloud Project.
project_folder = 'akveg-map'
# collection = 'reflectance_vhr/ortho_toa_images'

# %% [markdown]
# ### View list of cogs to ingest
# Optional, can skip when list is long.

# %%
for cog in dw_cogs['tif']:
    print(cog)
# Out:
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_monthly_counts_mgrs_v20250414b/s2_dw_counts_mgrs_month05_03UUV_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_monthly_counts_mgrs_v20250414b/s2_dw_counts_mgrs_month06_01UCS_v20250414.tif

# %% [markdown]
# ### Function to load list of gcs cogs to GEE imageCollection
# comment out pprint and most print except when troubleshooting

# %%
#TODO Fix date extraction from filename to work for different filename formats
def load_gcs_cogs_to_collection(cogs, project_folder, collection, month_part, tile_part):
    # Request body as a dictionary.
    for cog in cogs['tif']:
      fileOnly = os.path.split(cog)[1]
      # print(fileOnly)

      cogName = fileOnly[:-4]
      print(cogName)
      
      # parts = fileOnly.split('_')
      # Split on both underscore and period
      parts = re.split(r'[_\.]', fileOnly)
      print(parts)
      
      monthxx = f"{parts[month_part]}"[-2:]
      month = int(monthxx)
      print(month)

      tile = f"{parts[tile_part]}"
      print(tile)

      # dt = datetime.strptime(yyyymmdd_hhmmss, "%Y%m%d_%H%M%S").replace(tzinfo=timezone.utc)
      # dt = f"{dt:%Y-%m-%dT%H:%M:%SZ}"  # Format string for ISO 8601 + Z
      # print(dt)
        
      request = {
        'type': 'IMAGE',
        'gcs_location': {
          'uris': cog
        },
        'properties': {
        #   'source': 'https://code.earthengine.google.com/067b10ee56537817756a3177a9138aee',
            # 'yyyymmdd_hhmmss': yyyymmdd_hhmmss,
            'month': monthxx,
            'tile': tile,
        },
        # 'startTime': dt,#'2023-01-01T00:00:00.000000000Z',
        # 'endTime': dt,#'2024-01-01T00:00:00.000000000Z',
      }

      pprint(json.dumps(request))

      # A folder (or ImageCollection) name and the new asset name.
      asset_id = collection+'/'+cogName
      # print(project_folder)
      # print(asset_id)
        
      url = 'https://earthengine.googleapis.com/v1alpha/projects/{}/assets?assetId={}'
      print(url)
      print(url.format(project_folder, asset_id))

      response = session.post(
        url = url.format(project_folder, asset_id),
        data = json.dumps(request)
      )

      # pprint(json.loads(response.content))
    print('done')

# %% [markdown]
# ### Run it

# %%
load_gcs_cogs_to_collection(dw_cogs, project_folder, 'dynamic_world_metrics/s2_dw_monthly_counts_mgrs_v20250414b', 4, 5)
# Out:
# s2_dw_counts_mgrs_month05_03UUV_v20250414
# ['s2', 'dw', 'counts', 'mgrs', 'month05', '03UUV', 'v20250414', 'tif']
# 5
# 03UUV
# ('{"type": "IMAGE", "gcs_location": {"uris": '
#  '"gs://akveg-data/s2_dw_v1_metrics/s2_dw_monthly_counts_mgrs_v20250414b/s2_dw_counts_mgrs_month05_03UUV_v20250414.tif"}, '
#  '"properties": {"month": "05", "tile": "03UUV"}}')
# https://earthengine.googleapis.com/v1alpha/projects/{}/assets?assetId={}
# https://earthengine.googleapis.com/v1alpha/projects/akveg-map/assets?assetId=dynamic_world_metrics/s2_dw_monthly_counts_mgrs_v20250414b/s2_dw_counts_mgrs_month05_03UUV_v20250414
# s2_dw_counts_mgrs_month06_01UCS_v20250414
# ['s2', 'dw', 'counts', 'mgrs', 'month06', '01UCS', 'v20250414', 'tif']
# 6
# 01UCS
# ('{"type": "IMAGE", "gcs_location": {"uris": '
#  '"gs://akveg-data/s2_dw_v1_metrics/s2_dw_monthly_counts_mgrs_v20250414b/s2_dw_counts_mgrs_month06_01UCS_v20250414.tif"}, '
#  '"properties": {"month": "06", "tile": "01UCS"}}')
# https://earthengine.googleapis.com/v1alpha/projects/{}/assets?assetId={}
# https://earthengine.googleapis.com/v1alpha/projects/akveg-map/assets?assetId=dynamic_world_metrics/s2_dw_monthly_counts_mgrs_v20250414b/s2_dw_counts_mgrs_month06_01UCS_v20250414
# done

# %% [raw]
# Get summary of compute effort (EECUs)
# Note this includes all tasks in queue and some filtering may be required to narrow down to a particular script
#
# To get size and count of exports:
# (ee) mmacander@mason:/data/gis/raster_base/Alaska/AKVegMap/dynamic_world$ gsutil du -sh gs://akveg-data/s2_dw_v1_metrics/s2_dw_monthly_counts_mgrs_v20250414b
# 259.31 GiB   gs://akveg-data/s2_dw_v1_metrics/s2_dw_monthly_counts_mgrs_v20250414b
# (ee) mmacander@mason:/data/gis/raster_base/Alaska/AKVegMap/dynamic_world$ gsutil ls gs://akveg-data/s2_dw_v1_metrics/s2_dw_monthly_counts_mgrs_v20250414b/*.tif | wc -l
# 7
# 53

# %%
import ee
ee.Initialize()

operations = ee.data.listOperations()

# Filter for failed or cancelled tasks
failed_ops = [
    op for op in operations
    if op.get('metadata', {}).get('state') in ['FAILED', 'CANCELLED']
]

# Print summary
for op in failed_ops:
    meta = op['metadata']
    print(f"Task ID: {op['name'].split('/')[-1]}")
    print(f"Description: {meta.get('description', 'N/A')}")
    print(f"State: {meta.get('state')}")
    print(f"Error: {meta.get('errorMessage', 'None')}")
    print('-' * 40)

# Need to redo two (maybe no granules for that month?)
# s2_dw_counts_month05_03UUV_v20250414
# s2_dw_counts_month06_01UCS_v20250414
# Out:
# Task ID: GXLT5QBVB64VCFROC5U47ZMV
# Description: s2_dw_counts_month05_03UUV_v20250414
# State: FAILED
# Error: None
# ----------------------------------------
# Task ID: 273PJSOXO4FQ7GXVGDPDSR52
# Description: s2_dw_counts_month06_01UCS_v20250414
# State: FAILED
# Error: None
# ----------------------------------------
# Task ID: 32BQ2LQ46S6JIDHWVN7Q7NYS
# Description: s2_dw_counts_month07_06VUQ_v20250414
# State: FAILED
# Error: None
# ----------------------------------------
# Task ID: 4GSBFOYQF6U34VUT7EZU4EOY
# Description: s2_dw_counts_month07_06VUQ_v20250414
# State: FAILED
# Error: None
# ----------------------------------------
# Task ID: 6FIFZTCXEMGQGGHGDOLJUWAI
# Description: s2_dw_counts_month07_06VUQ_v20250414
# State: CANCELLED
# Error: None
# ----------------------------------------
# Task ID: UNSCUHRMP243PK23WQ3D2BWX
# Description: s2_dw_counts_month07_06VUQ_v20250414
# State: FAILED
# Error: None
# ----------------------------------------

# %% [markdown]
# ## Dynamic World Percentages (May-Sept) by AKALB 50km tile

# %% [markdown]
# ### Cleanup existing imageCollection, if needed
#
# imageCollections cannot be deleted until all images inside them are deleted. For a cloud-backed image collection with hundreds or thousands of tiles, this can take a while
#
# bash earthengine CLI
# ```
# for i in `earthengine ls projects/akveg-map/assets/dynamic_world_metrics/s2_dw_monthly_counts_mgrs_v20250414b`; do earthengine rm $i; done
#
# # earthengine rm projects/akveg-map/assets/s2_2019_2023_gMedian_v20240311
# ```

# %% [markdown]
# ### new code for cleaning existing imageCollection
#
# bash earthengine CLI
# ```
# COLLECTION="projects/akveg-map/assets/dynamic_world_metrics/s2_dw_percentages_56789_v20250414"
# earthengine ls $COLLECTION | xargs -P 20 -I {} earthengine rm {}
# ```

# %% [markdown]
# ### Create empty image collections as target
# TODO Automate creation of empty image collection.
#
# For now, manually create empty image collection with earthengine CLI

# %% [markdown]
# ```
# earthengine set_project akveg-map
# earthengine create collection projects/akveg-map/assets/dynamic_world_metrics/s2_dw_percentages_56789_v20250414b
# ```

# %% [markdown]
# ### Create list of cloud geotiffs in bucket and image collection
#
# Create list of cogs in a bucket folder to load into an imageCollection.
#
# Create list of cogs that have already been loaded into the imageCollection.
#
# Run in bash in a conda env with gsutil and earthengine command line installed and authenticated.
#
# TODO: Configure it to run directly in python

# %% [markdown]
# ```
# cd /data/gis/raster_base/Alaska/AKVegMap/dynamic_world
#
# gsutil ls gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/*.tif > dw_percentage_cogs.txt
# earthengine ls projects/akveg-map/assets/dynamic_world_metrics/s2_dw_percentages_56789_v20250414 > dw_percentage_cogs_inColl.txt
#
# ```

# %%
# Function to read a text file and return a list of paths
def read_paths_from_file(filepath):
    with open(filepath, 'r') as file:
        paths = file.read().splitlines()
    return paths

# Function to extract the last part of the path and remove the extension
def get_filename_without_extension(path):
    return os.path.splitext(os.path.basename(path))[0]


# Function to save a list of paths to a text file
def save_paths_to_file(paths, filepath):
    with open(filepath, 'w') as file:
        for path in paths:
            file.write(f"{path}\n")

def in_list_1_not_list_2(csv1_path, csv2_path):
    cogList = read_paths_from_file(csv1_path)
    cogListIC = read_paths_from_file(csv2_path)
    
    filenames1 = [get_filename_without_extension(path) for path in cogList]
    filenames2 = [get_filename_without_extension(path) for path in cogListIC]
    
    # Convert lists to pd Series
    filenames_series1 = pd.Series(filenames1, index=cogList)
    filenames_series2 = pd.Series(filenames2, index=cogListIC)
    
    # Find filenames in list1 that are not in list2
    unique_to_list1 = filenames_series1[~filenames_series1.isin(filenames2)]
    
    print("\nPaths in list1 that are not in list2 based on filenames:")
    print(unique_to_list1.index.tolist()[:5])
    print(len(unique_to_list1.index.tolist()))
    
    return unique_to_list1

# %%
# Apply the functions to for full list and already loaded list of vhr_toa_cogs
unique_to_list1 = in_list_1_not_list_2('/data/gis/raster_base/Alaska/AKVegMap/dynamic_world/dw_percentage_cogs.txt',
                                       '/data/gis/raster_base/Alaska/AKVegMap/dynamic_world/dw_percentage_cogs_inColl.txt')

save_paths_to_file(unique_to_list1.index.tolist(), '/data/gis/raster_base/Alaska/AKVegMap/dynamic_world/dw_percentage_cogs_not_inColl.txt')
# Out:
# Paths in list1 that are not in list2 based on filenames:
# ['gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H01V31_v20250414.tif', 'gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H01V32_v20250414.tif', 'gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H01V33_v20250414.tif', 'gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H02V31_v20250414.tif', 'gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H02V32_v20250414.tif']
# 279

# %% [markdown]
# ### Open list of geotiffs to ingest

# %%
dw_cogs = pd.read_csv('/data/gis/raster_base/Alaska/AKVegMap/dynamic_world/dw_percentage_cogs_not_inColl.txt', header=None,names=['tif'])
print(dw_cogs[0:2])
print(len(dw_cogs.index))
# Out:
#                                                  tif
# 0  gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_aka...
# 1  gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_aka...
# 279

# %% [markdown]
# ### Setup parameters

# %%
import json
# from urllib.parse import urlparse
import os
from pprint import pprint

# Earth Engine enabled Cloud Project.
project_folder = 'akveg-map'
# collection = 'reflectance_vhr/ortho_toa_images'

# %% [markdown]
# ### View list of cogs to ingest
# Optional, can skip when list is long.

# %%
for cog in dw_cogs['tif']:
    print(cog)
# Out:
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H01V31_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H01V32_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H01V33_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H02V31_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H02V32_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H02V33_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H03V32_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H03V33_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H04V34_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H05V34_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H06V35_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H06V36_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H07V35_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H07V36_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H07V37_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H07V38_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H08V36_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H08V37_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H08V38_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H09V37_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H09V38_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H10V38_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H10V39_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H11V38_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H11V39_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H12V38_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H12V39_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H13V38_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H13V39_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H13V40_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H14V39_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H14V40_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H15V39_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H15V40_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H16V39_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H16V40_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H17V39_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H17V40_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H18V39_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H18V40_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H18V41_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H19V40_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H20V40_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H21V40_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H22V39_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H22V40_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H23V39_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H23V40_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H24V22_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H24V23_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H24V39_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H24V40_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H25V22_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H25V23_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H25V30_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H25V31_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H25V32_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H25V39_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H25V40_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H26V30_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H26V31_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H26V32_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H26V38_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H26V39_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H26V40_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H27V15_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H27V16_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H27V17_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H27V38_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H27V39_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H27V40_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H28V15_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H28V16_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H28V17_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H28V18_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H28V38_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H28V39_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H29V16_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H29V17_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H29V18_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H29V37_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H29V38_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H29V39_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H30V17_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H30V18_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H30V24_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H30V25_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H30V37_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H30V38_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H30V39_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H31V12_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H31V13_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H31V14_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H31V21_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H31V22_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H31V24_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H31V25_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H31V26_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H31V36_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H31V37_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H31V38_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H32V12_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H32V13_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H32V14_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H32V20_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H32V21_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H32V22_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H32V23_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H32V24_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H32V25_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H32V26_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H32V36_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H32V37_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H32V38_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H33V11_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H33V12_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H33V13_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H33V14_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H33V15_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H33V18_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H33V19_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H33V20_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H33V21_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H33V22_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H33V23_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H33V24_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H33V25_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H33V26_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H33V35_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H33V36_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H33V37_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H33V38_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H34V05_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H34V06_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H34V07_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H34V11_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H34V12_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H34V13_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H34V14_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H34V15_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H34V16_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H34V18_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H34V19_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H34V20_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H34V21_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H34V22_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H34V23_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H34V24_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H34V25_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H34V26_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H34V27_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H34V35_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H34V36_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H34V37_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H34V38_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H35V05_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H35V06_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H35V07_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H35V08_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H35V09_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H35V11_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H35V12_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H35V13_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H35V14_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H35V15_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H35V16_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H35V18_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H35V19_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H35V20_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H35V21_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H35V22_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H35V23_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H35V24_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H35V25_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H35V26_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H35V27_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H35V28_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H35V29_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H35V34_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H35V35_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H35V36_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H35V37_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H35V38_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H36V05_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H36V06_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H36V07_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H36V08_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H36V09_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H36V10_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H36V11_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H36V12_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H36V13_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H36V14_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H36V15_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H36V16_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H36V17_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H36V18_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H36V19_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H36V20_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H36V21_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H36V22_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H36V23_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H36V24_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H36V25_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H36V26_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H36V27_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H36V28_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H36V29_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H36V34_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H36V35_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H36V36_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H36V37_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H36V38_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H37V04_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H37V05_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H37V06_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H37V07_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H37V08_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H37V09_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H37V10_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H37V11_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H37V12_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H37V13_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H37V14_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H37V15_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H37V16_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H37V17_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H37V18_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H37V19_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H37V20_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H37V21_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H37V22_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H37V23_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H37V24_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H37V25_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H37V26_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H37V27_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H37V28_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H37V29_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H37V33_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H37V34_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H37V35_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H37V36_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H37V37_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H37V38_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H38V03_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H38V04_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H38V05_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H38V06_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H38V07_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H38V08_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H38V09_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H38V10_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H38V11_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H38V12_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H38V13_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H38V14_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H38V15_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H38V16_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H38V17_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H38V18_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H38V19_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H38V20_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H38V21_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H38V22_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H38V23_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H38V24_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H38V25_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H38V26_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H38V27_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H38V28_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H38V29_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H38V30_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H38V33_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H38V34_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H38V35_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H38V36_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H38V37_v20250414.tif
# gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H38V38_v20250414.tif

# %% [markdown]
# ### Function to load list of gcs cogs to GEE imageCollection
# comment out pprint and most print except when troubleshooting

# %%
#TODO Fix date extraction from filename to work for different filename formats
def load_gcs_cogs_to_collection(cogs, project_folder, collection, month_part, tile_part, version_counts_part):
    # Request body as a dictionary.
    for cog in cogs['tif']:
      fileOnly = os.path.split(cog)[1]
      # print(fileOnly)

      cogName = fileOnly[:-4]
      print(cogName)
      
      # parts = fileOnly.split('_')
      # Split on both underscore and period
      parts = re.split(r'[_\.]', fileOnly)
      print(parts)
      
      months = parts[month_part]
      # month = int(monthxx)
      print(months)

      tile = f"{parts[tile_part]}"
      print(tile)

      version_counts = f"{parts[version_counts_part]}"
      print(version_counts)

      # dt = datetime.strptime(yyyymmdd_hhmmss, "%Y%m%d_%H%M%S").replace(tzinfo=timezone.utc)
      # dt = f"{dt:%Y-%m-%dT%H:%M:%SZ}"  # Format string for ISO 8601 + Z
      # print(dt)
        
      request = {
        'type': 'IMAGE',
        'gcs_location': {
          'uris': cog
        },
        'properties': {
        #   'source': 'https://code.earthengine.google.com/067b10ee56537817756a3177a9138aee',
            # 'yyyymmdd_hhmmss': yyyymmdd_hhmmss,
            'months': months,
            'tile': tile,
            'version_counts': version_counts
        },
        # 'startTime': dt,#'2023-01-01T00:00:00.000000000Z',
        # 'endTime': dt,#'2024-01-01T00:00:00.000000000Z',
      }

      pprint(json.dumps(request))

      # A folder (or ImageCollection) name and the new asset name.
      asset_id = collection+'/'+cogName
      # print(project_folder)
      # print(asset_id)
        
      url = 'https://earthengine.googleapis.com/v1alpha/projects/{}/assets?assetId={}'
      print(url)
      print(url.format(project_folder, asset_id))

      response = session.post(
        url = url.format(project_folder, asset_id),
        data = json.dumps(request)
      )

      # pprint(json.loads(response.content))
    print('done')

# %% [markdown]
# ### Run it

# %%
load_gcs_cogs_to_collection(dw_cogs, project_folder, 'dynamic_world_metrics/s2_dw_percentages_56789_v20250414', 3, 4, 5)
# Out:
# s2_dw_pct_56789_AK050H01V31_v20250414
# ['s2', 'dw', 'pct', '56789', 'AK050H01V31', 'v20250414', 'tif']
# 56789
# AK050H01V31
# v20250414
# ('{"type": "IMAGE", "gcs_location": {"uris": '
#  '"gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H01V31_v20250414.tif"}, '
#  '"properties": {"months": "56789", "tile": "AK050H01V31", "version_counts": '
#  '"v20250414"}}')
# https://earthengine.googleapis.com/v1alpha/projects/{}/assets?assetId={}
# https://earthengine.googleapis.com/v1alpha/projects/akveg-map/assets?assetId=dynamic_world_metrics/s2_dw_percentages_56789_v20250414/s2_dw_pct_56789_AK050H01V31_v20250414
# s2_dw_pct_56789_AK050H01V32_v20250414
# ['s2', 'dw', 'pct', '56789', 'AK050H01V32', 'v20250414', 'tif']
# 56789
# AK050H01V32
# v20250414
# ('{"type": "IMAGE", "gcs_location": {"uris": '
#  '"gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H01V32_v20250414.tif"}, '
#  '"properties": {"months": "56789", "tile": "AK050H01V32", "version_counts": '
#  '"v20250414"}}')
# https://earthengine.googleapis.com/v1alpha/projects/{}/assets?assetId={}
# https://earthengine.googleapis.com/v1alpha/projects/akveg-map/assets?assetId=dynamic_world_metrics/s2_dw_percentages_56789_v20250414/s2_dw_pct_56789_AK050H01V32_v20250414
# s2_dw_pct_56789_AK050H01V33_v20250414
# ['s2', 'dw', 'pct', '56789', 'AK050H01V33', 'v20250414', 'tif']
# 56789
# AK050H01V33
# v20250414
# ('{"type": "IMAGE", "gcs_location": {"uris": '
#  '"gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H01V33_v20250414.tif"}, '
#  '"properties": {"months": "56789", "tile": "AK050H01V33", "version_counts": '
#  '"v20250414"}}')
# https://earthengine.googleapis.com/v1alpha/projects/{}/assets?assetId={}
# https://earthengine.googleapis.com/v1alpha/projects/akveg-map/assets?assetId=dynamic_world_metrics/s2_dw_percentages_56789_v20250414/s2_dw_pct_56789_AK050H01V33_v20250414
# s2_dw_pct_56789_AK050H02V31_v20250414
# ['s2', 'dw', 'pct', '56789', 'AK050H02V31', 'v20250414', 'tif']
# 56789
# AK050H02V31
# v20250414
# ('{"type": "IMAGE", "gcs_location": {"uris": '
#  '"gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H02V31_v20250414.tif"}, '
#  '"properties": {"months": "56789", "tile": "AK050H02V31", "version_counts": '
#  '"v20250414"}}')
# https://earthengine.googleapis.com/v1alpha/projects/{}/assets?assetId={}
# https://earthengine.googleapis.com/v1alpha/projects/akveg-map/assets?assetId=dynamic_world_metrics/s2_dw_percentages_56789_v20250414/s2_dw_pct_56789_AK050H02V31_v20250414
# s2_dw_pct_56789_AK050H02V32_v20250414
# ['s2', 'dw', 'pct', '56789', 'AK050H02V32', 'v20250414', 'tif']
# 56789
# AK050H02V32
# v20250414
# ('{"type": "IMAGE", "gcs_location": {"uris": '
#  '"gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H02V32_v20250414.tif"}, '
#  '"properties": {"months": "56789", "tile": "AK050H02V32", "version_counts": '
#  '"v20250414"}}')
# https://earthengine.googleapis.com/v1alpha/projects/{}/assets?assetId={}
# https://earthengine.googleapis.com/v1alpha/projects/akveg-map/assets?assetId=dynamic_world_metrics/s2_dw_percentages_56789_v20250414/s2_dw_pct_56789_AK050H02V32_v20250414
# s2_dw_pct_56789_AK050H02V33_v20250414
# ['s2', 'dw', 'pct', '56789', 'AK050H02V33', 'v20250414', 'tif']
# 56789
# AK050H02V33
# v20250414
# ('{"type": "IMAGE", "gcs_location": {"uris": '
#  '"gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H02V33_v20250414.tif"}, '
#  '"properties": {"months": "56789", "tile": "AK050H02V33", "version_counts": '
#  '"v20250414"}}')
# https://earthengine.googleapis.com/v1alpha/projects/{}/assets?assetId={}
# https://earthengine.googleapis.com/v1alpha/projects/akveg-map/assets?assetId=dynamic_world_metrics/s2_dw_percentages_56789_v20250414/s2_dw_pct_56789_AK050H02V33_v20250414
# s2_dw_pct_56789_AK050H03V32_v20250414
# ['s2', 'dw', 'pct', '56789', 'AK050H03V32', 'v20250414', 'tif']
# 56789
# AK050H03V32
# v20250414
# ('{"type": "IMAGE", "gcs_location": {"uris": '
#  '"gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H03V32_v20250414.tif"}, '
#  '"properties": {"months": "56789", "tile": "AK050H03V32", "version_counts": '
#  '"v20250414"}}')
# https://earthengine.googleapis.com/v1alpha/projects/{}/assets?assetId={}
# https://earthengine.googleapis.com/v1alpha/projects/akveg-map/assets?assetId=dynamic_world_metrics/s2_dw_percentages_56789_v20250414/s2_dw_pct_56789_AK050H03V32_v20250414
# s2_dw_pct_56789_AK050H03V33_v20250414
# ['s2', 'dw', 'pct', '56789', 'AK050H03V33', 'v20250414', 'tif']
# 56789
# AK050H03V33
# v20250414
# ('{"type": "IMAGE", "gcs_location": {"uris": '
#  '"gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H03V33_v20250414.tif"}, '
#  '"properties": {"months": "56789", "tile": "AK050H03V33", "version_counts": '
#  '"v20250414"}}')
# https://earthengine.googleapis.com/v1alpha/projects/{}/assets?assetId={}
# https://earthengine.googleapis.com/v1alpha/projects/akveg-map/assets?assetId=dynamic_world_metrics/s2_dw_percentages_56789_v20250414/s2_dw_pct_56789_AK050H03V33_v20250414
# s2_dw_pct_56789_AK050H04V34_v20250414
# ['s2', 'dw', 'pct', '56789', 'AK050H04V34', 'v20250414', 'tif']
# 56789
# AK050H04V34
# v20250414
# ('{"type": "IMAGE", "gcs_location": {"uris": '
#  '"gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H04V34_v20250414.tif"}, '
#  '"properties": {"months": "56789", "tile": "AK050H04V34", "version_counts": '
#  '"v20250414"}}')
# https://earthengine.googleapis.com/v1alpha/projects/{}/assets?assetId={}
# https://earthengine.googleapis.com/v1alpha/projects/akveg-map/assets?assetId=dynamic_world_metrics/s2_dw_percentages_56789_v20250414/s2_dw_pct_56789_AK050H04V34_v20250414
# s2_dw_pct_56789_AK050H05V34_v20250414
# ['s2', 'dw', 'pct', '56789', 'AK050H05V34', 'v20250414', 'tif']
# 56789
# AK050H05V34
# v20250414
# ('{"type": "IMAGE", "gcs_location": {"uris": '
#  '"gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H05V34_v20250414.tif"}, '
#  '"properties": {"months": "56789", "tile": "AK050H05V34", "version_counts": '
#  '"v20250414"}}')
# https://earthengine.googleapis.com/v1alpha/projects/{}/assets?assetId={}
# https://earthengine.googleapis.com/v1alpha/projects/akveg-map/assets?assetId=dynamic_world_metrics/s2_dw_percentages_56789_v20250414/s2_dw_pct_56789_AK050H05V34_v20250414
# s2_dw_pct_56789_AK050H06V35_v20250414
# ['s2', 'dw', 'pct', '56789', 'AK050H06V35', 'v20250414', 'tif']
# 56789
# AK050H06V35
# v20250414
# ('{"type": "IMAGE", "gcs_location": {"uris": '
#  '"gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H06V35_v20250414.tif"}, '
#  '"properties": {"months": "56789", "tile": "AK050H06V35", "version_counts": '
#  '"v20250414"}}')
# https://earthengine.googleapis.com/v1alpha/projects/{}/assets?assetId={}
# https://earthengine.googleapis.com/v1alpha/projects/akveg-map/assets?assetId=dynamic_world_metrics/s2_dw_percentages_56789_v20250414/s2_dw_pct_56789_AK050H06V35_v20250414
# s2_dw_pct_56789_AK050H06V36_v20250414
# ['s2', 'dw', 'pct', '56789', 'AK050H06V36', 'v20250414', 'tif']
# 56789
# AK050H06V36
# v20250414
# ('{"type": "IMAGE", "gcs_location": {"uris": '
#  '"gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H06V36_v20250414.tif"}, '
#  '"properties": {"months": "56789", "tile": "AK050H06V36", "version_counts": '
#  '"v20250414"}}')
# https://earthengine.googleapis.com/v1alpha/projects/{}/assets?assetId={}
# https://earthengine.googleapis.com/v1alpha/projects/akveg-map/assets?assetId=dynamic_world_metrics/s2_dw_percentages_56789_v20250414/s2_dw_pct_56789_AK050H06V36_v20250414
# s2_dw_pct_56789_AK050H07V35_v20250414
# ['s2', 'dw', 'pct', '56789', 'AK050H07V35', 'v20250414', 'tif']
# 56789
# AK050H07V35
# v20250414
# ('{"type": "IMAGE", "gcs_location": {"uris": '
#  '"gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H07V35_v20250414.tif"}, '
#  '"properties": {"months": "56789", "tile": "AK050H07V35", "version_counts": '
#  '"v20250414"}}')
# https://earthengine.googleapis.com/v1alpha/projects/{}/assets?assetId={}
# https://earthengine.googleapis.com/v1alpha/projects/akveg-map/assets?assetId=dynamic_world_metrics/s2_dw_percentages_56789_v20250414/s2_dw_pct_56789_AK050H07V35_v20250414
# s2_dw_pct_56789_AK050H07V36_v20250414
# ['s2', 'dw', 'pct', '56789', 'AK050H07V36', 'v20250414', 'tif']
# 56789
# AK050H07V36
# v20250414
# ('{"type": "IMAGE", "gcs_location": {"uris": '
#  '"gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H07V36_v20250414.tif"}, '
#  '"properties": {"months": "56789", "tile": "AK050H07V36", "version_counts": '
#  '"v20250414"}}')
# https://earthengine.googleapis.com/v1alpha/projects/{}/assets?assetId={}
# https://earthengine.googleapis.com/v1alpha/projects/akveg-map/assets?assetId=dynamic_world_metrics/s2_dw_percentages_56789_v20250414/s2_dw_pct_56789_AK050H07V36_v20250414
# s2_dw_pct_56789_AK050H07V37_v20250414
# ['s2', 'dw', 'pct', '56789', 'AK050H07V37', 'v20250414', 'tif']
# 56789
# AK050H07V37
# v20250414
# ('{"type": "IMAGE", "gcs_location": {"uris": '
#  '"gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H07V37_v20250414.tif"}, '
#  '"properties": {"months": "56789", "tile": "AK050H07V37", "version_counts": '
#  '"v20250414"}}')
# https://earthengine.googleapis.com/v1alpha/projects/{}/assets?assetId={}
# https://earthengine.googleapis.com/v1alpha/projects/akveg-map/assets?assetId=dynamic_world_metrics/s2_dw_percentages_56789_v20250414/s2_dw_pct_56789_AK050H07V37_v20250414
# s2_dw_pct_56789_AK050H07V38_v20250414
# ['s2', 'dw', 'pct', '56789', 'AK050H07V38', 'v20250414', 'tif']
# 56789
# AK050H07V38
# v20250414
# ('{"type": "IMAGE", "gcs_location": {"uris": '
#  '"gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H07V38_v20250414.tif"}, '
#  '"properties": {"months": "56789", "tile": "AK050H07V38", "version_counts": '
#  '"v20250414"}}')
# https://earthengine.googleapis.com/v1alpha/projects/{}/assets?assetId={}
# https://earthengine.googleapis.com/v1alpha/projects/akveg-map/assets?assetId=dynamic_world_metrics/s2_dw_percentages_56789_v20250414/s2_dw_pct_56789_AK050H07V38_v20250414
# s2_dw_pct_56789_AK050H08V36_v20250414
# ['s2', 'dw', 'pct', '56789', 'AK050H08V36', 'v20250414', 'tif']
# 56789
# AK050H08V36
# v20250414
# ('{"type": "IMAGE", "gcs_location": {"uris": '
#  '"gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H08V36_v20250414.tif"}, '
#  '"properties": {"months": "56789", "tile": "AK050H08V36", "version_counts": '
#  '"v20250414"}}')
# https://earthengine.googleapis.com/v1alpha/projects/{}/assets?assetId={}
# https://earthengine.googleapis.com/v1alpha/projects/akveg-map/assets?assetId=dynamic_world_metrics/s2_dw_percentages_56789_v20250414/s2_dw_pct_56789_AK050H08V36_v20250414
# s2_dw_pct_56789_AK050H08V37_v20250414
# ['s2', 'dw', 'pct', '56789', 'AK050H08V37', 'v20250414', 'tif']
# 56789
# AK050H08V37
# v20250414
# ('{"type": "IMAGE", "gcs_location": {"uris": '
#  '"gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H08V37_v20250414.tif"}, '
#  '"properties": {"months": "56789", "tile": "AK050H08V37", "version_counts": '
#  '"v20250414"}}')
# https://earthengine.googleapis.com/v1alpha/projects/{}/assets?assetId={}
# https://earthengine.googleapis.com/v1alpha/projects/akveg-map/assets?assetId=dynamic_world_metrics/s2_dw_percentages_56789_v20250414/s2_dw_pct_56789_AK050H08V37_v20250414
# s2_dw_pct_56789_AK050H08V38_v20250414
# ['s2', 'dw', 'pct', '56789', 'AK050H08V38', 'v20250414', 'tif']
# 56789
# AK050H08V38
# v20250414
# ('{"type": "IMAGE", "gcs_location": {"uris": '
#  '"gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H08V38_v20250414.tif"}, '
#  '"properties": {"months": "56789", "tile": "AK050H08V38", "version_counts": '
#  '"v20250414"}}')
# https://earthengine.googleapis.com/v1alpha/projects/{}/assets?assetId={}
# https://earthengine.googleapis.com/v1alpha/projects/akveg-map/assets?assetId=dynamic_world_metrics/s2_dw_percentages_56789_v20250414/s2_dw_pct_56789_AK050H08V38_v20250414
# s2_dw_pct_56789_AK050H09V37_v20250414
# ['s2', 'dw', 'pct', '56789', 'AK050H09V37', 'v20250414', 'tif']
# 56789
# AK050H09V37
# v20250414
# ('{"type": "IMAGE", "gcs_location": {"uris": '
#  '"gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H09V37_v20250414.tif"}, '
#  '"properties": {"months": "56789", "tile": "AK050H09V37", "version_counts": '
#  '"v20250414"}}')
# https://earthengine.googleapis.com/v1alpha/projects/{}/assets?assetId={}
# https://earthengine.googleapis.com/v1alpha/projects/akveg-map/assets?assetId=dynamic_world_metrics/s2_dw_percentages_56789_v20250414/s2_dw_pct_56789_AK050H09V37_v20250414
# s2_dw_pct_56789_AK050H09V38_v20250414
# ['s2', 'dw', 'pct', '56789', 'AK050H09V38', 'v20250414', 'tif']
# 56789
# AK050H09V38
# v20250414
# ('{"type": "IMAGE", "gcs_location": {"uris": '
#  '"gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H09V38_v20250414.tif"}, '
#  '"properties": {"months": "56789", "tile": "AK050H09V38", "version_counts": '
#  '"v20250414"}}')
# https://earthengine.googleapis.com/v1alpha/projects/{}/assets?assetId={}
# https://earthengine.googleapis.com/v1alpha/projects/akveg-map/assets?assetId=dynamic_world_metrics/s2_dw_percentages_56789_v20250414/s2_dw_pct_56789_AK050H09V38_v20250414
# s2_dw_pct_56789_AK050H10V38_v20250414
# ['s2', 'dw', 'pct', '56789', 'AK050H10V38', 'v20250414', 'tif']
# 56789
# AK050H10V38
# v20250414
# ('{"type": "IMAGE", "gcs_location": {"uris": '
#  '"gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H10V38_v20250414.tif"}, '
#  '"properties": {"months": "56789", "tile": "AK050H10V38", "version_counts": '
#  '"v20250414"}}')
# https://earthengine.googleapis.com/v1alpha/projects/{}/assets?assetId={}
# https://earthengine.googleapis.com/v1alpha/projects/akveg-map/assets?assetId=dynamic_world_metrics/s2_dw_percentages_56789_v20250414/s2_dw_pct_56789_AK050H10V38_v20250414
# s2_dw_pct_56789_AK050H10V39_v20250414
# ['s2', 'dw', 'pct', '56789', 'AK050H10V39', 'v20250414', 'tif']
# 56789
# AK050H10V39
# v20250414
# ('{"type": "IMAGE", "gcs_location": {"uris": '
#  '"gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H10V39_v20250414.tif"}, '
#  '"properties": {"months": "56789", "tile": "AK050H10V39", "version_counts": '
#  '"v20250414"}}')
# https://earthengine.googleapis.com/v1alpha/projects/{}/assets?assetId={}
# https://earthengine.googleapis.com/v1alpha/projects/akveg-map/assets?assetId=dynamic_world_metrics/s2_dw_percentages_56789_v20250414/s2_dw_pct_56789_AK050H10V39_v20250414
# s2_dw_pct_56789_AK050H11V38_v20250414
# ['s2', 'dw', 'pct', '56789', 'AK050H11V38', 'v20250414', 'tif']
# 56789
# AK050H11V38
# v20250414
# ('{"type": "IMAGE", "gcs_location": {"uris": '
#  '"gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H11V38_v20250414.tif"}, '
#  '"properties": {"months": "56789", "tile": "AK050H11V38", "version_counts": '
#  '"v20250414"}}')
# https://earthengine.googleapis.com/v1alpha/projects/{}/assets?assetId={}
# https://earthengine.googleapis.com/v1alpha/projects/akveg-map/assets?assetId=dynamic_world_metrics/s2_dw_percentages_56789_v20250414/s2_dw_pct_56789_AK050H11V38_v20250414
# s2_dw_pct_56789_AK050H11V39_v20250414
# ['s2', 'dw', 'pct', '56789', 'AK050H11V39', 'v20250414', 'tif']
# 56789
# AK050H11V39
# v20250414
# ('{"type": "IMAGE", "gcs_location": {"uris": '
#  '"gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H11V39_v20250414.tif"}, '
#  '"properties": {"months": "56789", "tile": "AK050H11V39", "version_counts": '
#  '"v20250414"}}')
# https://earthengine.googleapis.com/v1alpha/projects/{}/assets?assetId={}
# https://earthengine.googleapis.com/v1alpha/projects/akveg-map/assets?assetId=dynamic_world_metrics/s2_dw_percentages_56789_v20250414/s2_dw_pct_56789_AK050H11V39_v20250414
# s2_dw_pct_56789_AK050H12V38_v20250414
# ['s2', 'dw', 'pct', '56789', 'AK050H12V38', 'v20250414', 'tif']
# 56789
# AK050H12V38
# v20250414
# ('{"type": "IMAGE", "gcs_location": {"uris": '
#  '"gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H12V38_v20250414.tif"}, '
#  '"properties": {"months": "56789", "tile": "AK050H12V38", "version_counts": '
#  '"v20250414"}}')
# https://earthengine.googleapis.com/v1alpha/projects/{}/assets?assetId={}
# https://earthengine.googleapis.com/v1alpha/projects/akveg-map/assets?assetId=dynamic_world_metrics/s2_dw_percentages_56789_v20250414/s2_dw_pct_56789_AK050H12V38_v20250414
# s2_dw_pct_56789_AK050H12V39_v20250414
# ['s2', 'dw', 'pct', '56789', 'AK050H12V39', 'v20250414', 'tif']
# 56789
# AK050H12V39
# v20250414
# ('{"type": "IMAGE", "gcs_location": {"uris": '
#  '"gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H12V39_v20250414.tif"}, '
#  '"properties": {"months": "56789", "tile": "AK050H12V39", "version_counts": '
#  '"v20250414"}}')
# https://earthengine.googleapis.com/v1alpha/projects/{}/assets?assetId={}
# https://earthengine.googleapis.com/v1alpha/projects/akveg-map/assets?assetId=dynamic_world_metrics/s2_dw_percentages_56789_v20250414/s2_dw_pct_56789_AK050H12V39_v20250414
# s2_dw_pct_56789_AK050H13V38_v20250414
# ['s2', 'dw', 'pct', '56789', 'AK050H13V38', 'v20250414', 'tif']
# 56789
# AK050H13V38
# v20250414
# ('{"type": "IMAGE", "gcs_location": {"uris": '
#  '"gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H13V38_v20250414.tif"}, '
#  '"properties": {"months": "56789", "tile": "AK050H13V38", "version_counts": '
#  '"v20250414"}}')
# https://earthengine.googleapis.com/v1alpha/projects/{}/assets?assetId={}
# https://earthengine.googleapis.com/v1alpha/projects/akveg-map/assets?assetId=dynamic_world_metrics/s2_dw_percentages_56789_v20250414/s2_dw_pct_56789_AK050H13V38_v20250414
# s2_dw_pct_56789_AK050H13V39_v20250414
# ['s2', 'dw', 'pct', '56789', 'AK050H13V39', 'v20250414', 'tif']
# 56789
# AK050H13V39
# v20250414
# ('{"type": "IMAGE", "gcs_location": {"uris": '
#  '"gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H13V39_v20250414.tif"}, '
#  '"properties": {"months": "56789", "tile": "AK050H13V39", "version_counts": '
#  '"v20250414"}}')
# https://earthengine.googleapis.com/v1alpha/projects/{}/assets?assetId={}
# https://earthengine.googleapis.com/v1alpha/projects/akveg-map/assets?assetId=dynamic_world_metrics/s2_dw_percentages_56789_v20250414/s2_dw_pct_56789_AK050H13V39_v20250414
# s2_dw_pct_56789_AK050H13V40_v20250414
# ['s2', 'dw', 'pct', '56789', 'AK050H13V40', 'v20250414', 'tif']
# 56789
# AK050H13V40
# v20250414
# ('{"type": "IMAGE", "gcs_location": {"uris": '
#  '"gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H13V40_v20250414.tif"}, '
#  '"properties": {"months": "56789", "tile": "AK050H13V40", "version_counts": '
#  '"v20250414"}}')
# https://earthengine.googleapis.com/v1alpha/projects/{}/assets?assetId={}
# https://earthengine.googleapis.com/v1alpha/projects/akveg-map/assets?assetId=dynamic_world_metrics/s2_dw_percentages_56789_v20250414/s2_dw_pct_56789_AK050H13V40_v20250414
# s2_dw_pct_56789_AK050H14V39_v20250414
# ['s2', 'dw', 'pct', '56789', 'AK050H14V39', 'v20250414', 'tif']
# 56789
# AK050H14V39
# v20250414
# ('{"type": "IMAGE", "gcs_location": {"uris": '
#  '"gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H14V39_v20250414.tif"}, '
#  '"properties": {"months": "56789", "tile": "AK050H14V39", "version_counts": '
#  '"v20250414"}}')
# https://earthengine.googleapis.com/v1alpha/projects/{}/assets?assetId={}
# https://earthengine.googleapis.com/v1alpha/projects/akveg-map/assets?assetId=dynamic_world_metrics/s2_dw_percentages_56789_v20250414/s2_dw_pct_56789_AK050H14V39_v20250414
# s2_dw_pct_56789_AK050H14V40_v20250414
# ['s2', 'dw', 'pct', '56789', 'AK050H14V40', 'v20250414', 'tif']
# 56789
# AK050H14V40
# v20250414
# ('{"type": "IMAGE", "gcs_location": {"uris": '
#  '"gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H14V40_v20250414.tif"}, '
#  '"properties": {"months": "56789", "tile": "AK050H14V40", "version_counts": '
#  '"v20250414"}}')
# https://earthengine.googleapis.com/v1alpha/projects/{}/assets?assetId={}
# https://earthengine.googleapis.com/v1alpha/projects/akveg-map/assets?assetId=dynamic_world_metrics/s2_dw_percentages_56789_v20250414/s2_dw_pct_56789_AK050H14V40_v20250414
# s2_dw_pct_56789_AK050H15V39_v20250414
# ['s2', 'dw', 'pct', '56789', 'AK050H15V39', 'v20250414', 'tif']
# 56789
# AK050H15V39
# v20250414
# ('{"type": "IMAGE", "gcs_location": {"uris": '
#  '"gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H15V39_v20250414.tif"}, '
#  '"properties": {"months": "56789", "tile": "AK050H15V39", "version_counts": '
#  '"v20250414"}}')
# https://earthengine.googleapis.com/v1alpha/projects/{}/assets?assetId={}
# https://earthengine.googleapis.com/v1alpha/projects/akveg-map/assets?assetId=dynamic_world_metrics/s2_dw_percentages_56789_v20250414/s2_dw_pct_56789_AK050H15V39_v20250414
# s2_dw_pct_56789_AK050H15V40_v20250414
# ['s2', 'dw', 'pct', '56789', 'AK050H15V40', 'v20250414', 'tif']
# 56789
# AK050H15V40
# v20250414
# ('{"type": "IMAGE", "gcs_location": {"uris": '
#  '"gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H15V40_v20250414.tif"}, '
#  '"properties": {"months": "56789", "tile": "AK050H15V40", "version_counts": '
#  '"v20250414"}}')
# https://earthengine.googleapis.com/v1alpha/projects/{}/assets?assetId={}
# https://earthengine.googleapis.com/v1alpha/projects/akveg-map/assets?assetId=dynamic_world_metrics/s2_dw_percentages_56789_v20250414/s2_dw_pct_56789_AK050H15V40_v20250414
# s2_dw_pct_56789_AK050H16V39_v20250414
# ['s2', 'dw', 'pct', '56789', 'AK050H16V39', 'v20250414', 'tif']
# 56789
# AK050H16V39
# v20250414
# ('{"type": "IMAGE", "gcs_location": {"uris": '
#  '"gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H16V39_v20250414.tif"}, '
#  '"properties": {"months": "56789", "tile": "AK050H16V39", "version_counts": '
#  '"v20250414"}}')
# https://earthengine.googleapis.com/v1alpha/projects/{}/assets?assetId={}
# https://earthengine.googleapis.com/v1alpha/projects/akveg-map/assets?assetId=dynamic_world_metrics/s2_dw_percentages_56789_v20250414/s2_dw_pct_56789_AK050H16V39_v20250414
# s2_dw_pct_56789_AK050H16V40_v20250414
# ['s2', 'dw', 'pct', '56789', 'AK050H16V40', 'v20250414', 'tif']
# 56789
# AK050H16V40
# v20250414
# ('{"type": "IMAGE", "gcs_location": {"uris": '
#  '"gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H16V40_v20250414.tif"}, '
#  '"properties": {"months": "56789", "tile": "AK050H16V40", "version_counts": '
#  '"v20250414"}}')
# https://earthengine.googleapis.com/v1alpha/projects/{}/assets?assetId={}
# https://earthengine.googleapis.com/v1alpha/projects/akveg-map/assets?assetId=dynamic_world_metrics/s2_dw_percentages_56789_v20250414/s2_dw_pct_56789_AK050H16V40_v20250414
# s2_dw_pct_56789_AK050H17V39_v20250414
# ['s2', 'dw', 'pct', '56789', 'AK050H17V39', 'v20250414', 'tif']
# 56789
# AK050H17V39
# v20250414
# ('{"type": "IMAGE", "gcs_location": {"uris": '
#  '"gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H17V39_v20250414.tif"}, '
#  '"properties": {"months": "56789", "tile": "AK050H17V39", "version_counts": '
#  '"v20250414"}}')
# https://earthengine.googleapis.com/v1alpha/projects/{}/assets?assetId={}
# https://earthengine.googleapis.com/v1alpha/projects/akveg-map/assets?assetId=dynamic_world_metrics/s2_dw_percentages_56789_v20250414/s2_dw_pct_56789_AK050H17V39_v20250414
# s2_dw_pct_56789_AK050H17V40_v20250414
# ['s2', 'dw', 'pct', '56789', 'AK050H17V40', 'v20250414', 'tif']
# 56789
# AK050H17V40
# v20250414
# ('{"type": "IMAGE", "gcs_location": {"uris": '
#  '"gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H17V40_v20250414.tif"}, '
#  '"properties": {"months": "56789", "tile": "AK050H17V40", "version_counts": '
#  '"v20250414"}}')
# https://earthengine.googleapis.com/v1alpha/projects/{}/assets?assetId={}
# https://earthengine.googleapis.com/v1alpha/projects/akveg-map/assets?assetId=dynamic_world_metrics/s2_dw_percentages_56789_v20250414/s2_dw_pct_56789_AK050H17V40_v20250414
# s2_dw_pct_56789_AK050H18V39_v20250414
# ['s2', 'dw', 'pct', '56789', 'AK050H18V39', 'v20250414', 'tif']
# 56789
# AK050H18V39
# v20250414
# ('{"type": "IMAGE", "gcs_location": {"uris": '
#  '"gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H18V39_v20250414.tif"}, '
#  '"properties": {"months": "56789", "tile": "AK050H18V39", "version_counts": '
#  '"v20250414"}}')
# https://earthengine.googleapis.com/v1alpha/projects/{}/assets?assetId={}
# https://earthengine.googleapis.com/v1alpha/projects/akveg-map/assets?assetId=dynamic_world_metrics/s2_dw_percentages_56789_v20250414/s2_dw_pct_56789_AK050H18V39_v20250414
# s2_dw_pct_56789_AK050H18V40_v20250414
# ['s2', 'dw', 'pct', '56789', 'AK050H18V40', 'v20250414', 'tif']
# 56789
# AK050H18V40
# v20250414
# ('{"type": "IMAGE", "gcs_location": {"uris": '
#  '"gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H18V40_v20250414.tif"}, '
#  '"properties": {"months": "56789", "tile": "AK050H18V40", "version_counts": '
#  '"v20250414"}}')
# https://earthengine.googleapis.com/v1alpha/projects/{}/assets?assetId={}
# https://earthengine.googleapis.com/v1alpha/projects/akveg-map/assets?assetId=dynamic_world_metrics/s2_dw_percentages_56789_v20250414/s2_dw_pct_56789_AK050H18V40_v20250414
# s2_dw_pct_56789_AK050H18V41_v20250414
# ['s2', 'dw', 'pct', '56789', 'AK050H18V41', 'v20250414', 'tif']
# 56789
# AK050H18V41
# v20250414
# ('{"type": "IMAGE", "gcs_location": {"uris": '
#  '"gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H18V41_v20250414.tif"}, '
#  '"properties": {"months": "56789", "tile": "AK050H18V41", "version_counts": '
#  '"v20250414"}}')
# https://earthengine.googleapis.com/v1alpha/projects/{}/assets?assetId={}
# https://earthengine.googleapis.com/v1alpha/projects/akveg-map/assets?assetId=dynamic_world_metrics/s2_dw_percentages_56789_v20250414/s2_dw_pct_56789_AK050H18V41_v20250414
# s2_dw_pct_56789_AK050H19V40_v20250414
# ['s2', 'dw', 'pct', '56789', 'AK050H19V40', 'v20250414', 'tif']
# 56789
# AK050H19V40
# v20250414
# ('{"type": "IMAGE", "gcs_location": {"uris": '
#  '"gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H19V40_v20250414.tif"}, '
#  '"properties": {"months": "56789", "tile": "AK050H19V40", "version_counts": '
#  '"v20250414"}}')
# https://earthengine.googleapis.com/v1alpha/projects/{}/assets?assetId={}
# https://earthengine.googleapis.com/v1alpha/projects/akveg-map/assets?assetId=dynamic_world_metrics/s2_dw_percentages_56789_v20250414/s2_dw_pct_56789_AK050H19V40_v20250414
# s2_dw_pct_56789_AK050H20V40_v20250414
# ['s2', 'dw', 'pct', '56789', 'AK050H20V40', 'v20250414', 'tif']
# 56789
# AK050H20V40
# v20250414
# ('{"type": "IMAGE", "gcs_location": {"uris": '
#  '"gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H20V40_v20250414.tif"}, '
#  '"properties": {"months": "56789", "tile": "AK050H20V40", "version_counts": '
#  '"v20250414"}}')
# https://earthengine.googleapis.com/v1alpha/projects/{}/assets?assetId={}
# https://earthengine.googleapis.com/v1alpha/projects/akveg-map/assets?assetId=dynamic_world_metrics/s2_dw_percentages_56789_v20250414/s2_dw_pct_56789_AK050H20V40_v20250414
# s2_dw_pct_56789_AK050H21V40_v20250414
# ['s2', 'dw', 'pct', '56789', 'AK050H21V40', 'v20250414', 'tif']
# 56789
# AK050H21V40
# v20250414
# ('{"type": "IMAGE", "gcs_location": {"uris": '
#  '"gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H21V40_v20250414.tif"}, '
#  '"properties": {"months": "56789", "tile": "AK050H21V40", "version_counts": '
#  '"v20250414"}}')
# https://earthengine.googleapis.com/v1alpha/projects/{}/assets?assetId={}
# https://earthengine.googleapis.com/v1alpha/projects/akveg-map/assets?assetId=dynamic_world_metrics/s2_dw_percentages_56789_v20250414/s2_dw_pct_56789_AK050H21V40_v20250414
# s2_dw_pct_56789_AK050H22V39_v20250414
# ['s2', 'dw', 'pct', '56789', 'AK050H22V39', 'v20250414', 'tif']
# 56789
# AK050H22V39
# v20250414
# ('{"type": "IMAGE", "gcs_location": {"uris": '
#  '"gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H22V39_v20250414.tif"}, '
#  '"properties": {"months": "56789", "tile": "AK050H22V39", "version_counts": '
#  '"v20250414"}}')
# https://earthengine.googleapis.com/v1alpha/projects/{}/assets?assetId={}
# https://earthengine.googleapis.com/v1alpha/projects/akveg-map/assets?assetId=dynamic_world_metrics/s2_dw_percentages_56789_v20250414/s2_dw_pct_56789_AK050H22V39_v20250414
# s2_dw_pct_56789_AK050H22V40_v20250414
# ['s2', 'dw', 'pct', '56789', 'AK050H22V40', 'v20250414', 'tif']
# 56789
# AK050H22V40
# v20250414
# ('{"type": "IMAGE", "gcs_location": {"uris": '
#  '"gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H22V40_v20250414.tif"}, '
#  '"properties": {"months": "56789", "tile": "AK050H22V40", "version_counts": '
#  '"v20250414"}}')
# https://earthengine.googleapis.com/v1alpha/projects/{}/assets?assetId={}
# https://earthengine.googleapis.com/v1alpha/projects/akveg-map/assets?assetId=dynamic_world_metrics/s2_dw_percentages_56789_v20250414/s2_dw_pct_56789_AK050H22V40_v20250414
# s2_dw_pct_56789_AK050H23V39_v20250414
# ['s2', 'dw', 'pct', '56789', 'AK050H23V39', 'v20250414', 'tif']
# 56789
# AK050H23V39
# v20250414
# ('{"type": "IMAGE", "gcs_location": {"uris": '
#  '"gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H23V39_v20250414.tif"}, '
#  '"properties": {"months": "56789", "tile": "AK050H23V39", "version_counts": '
#  '"v20250414"}}')
# https://earthengine.googleapis.com/v1alpha/projects/{}/assets?assetId={}
# https://earthengine.googleapis.com/v1alpha/projects/akveg-map/assets?assetId=dynamic_world_metrics/s2_dw_percentages_56789_v20250414/s2_dw_pct_56789_AK050H23V39_v20250414
# s2_dw_pct_56789_AK050H23V40_v20250414
# ['s2', 'dw', 'pct', '56789', 'AK050H23V40', 'v20250414', 'tif']
# 56789
# AK050H23V40
# v20250414
# ('{"type": "IMAGE", "gcs_location": {"uris": '
#  '"gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H23V40_v20250414.tif"}, '
#  '"properties": {"months": "56789", "tile": "AK050H23V40", "version_counts": '
#  '"v20250414"}}')
# https://earthengine.googleapis.com/v1alpha/projects/{}/assets?assetId={}
# https://earthengine.googleapis.com/v1alpha/projects/akveg-map/assets?assetId=dynamic_world_metrics/s2_dw_percentages_56789_v20250414/s2_dw_pct_56789_AK050H23V40_v20250414
# s2_dw_pct_56789_AK050H24V22_v20250414
# ['s2', 'dw', 'pct', '56789', 'AK050H24V22', 'v20250414', 'tif']
# 56789
# AK050H24V22
# v20250414
# ('{"type": "IMAGE", "gcs_location": {"uris": '
#  '"gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H24V22_v20250414.tif"}, '
#  '"properties": {"months": "56789", "tile": "AK050H24V22", "version_counts": '
#  '"v20250414"}}')
# https://earthengine.googleapis.com/v1alpha/projects/{}/assets?assetId={}
# https://earthengine.googleapis.com/v1alpha/projects/akveg-map/assets?assetId=dynamic_world_metrics/s2_dw_percentages_56789_v20250414/s2_dw_pct_56789_AK050H24V22_v20250414
# s2_dw_pct_56789_AK050H24V23_v20250414
# ['s2', 'dw', 'pct', '56789', 'AK050H24V23', 'v20250414', 'tif']
# 56789
# AK050H24V23
# v20250414
# ('{"type": "IMAGE", "gcs_location": {"uris": '
#  '"gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H24V23_v20250414.tif"}, '
#  '"properties": {"months": "56789", "tile": "AK050H24V23", "version_counts": '
#  '"v20250414"}}')
# https://earthengine.googleapis.com/v1alpha/projects/{}/assets?assetId={}
# https://earthengine.googleapis.com/v1alpha/projects/akveg-map/assets?assetId=dynamic_world_metrics/s2_dw_percentages_56789_v20250414/s2_dw_pct_56789_AK050H24V23_v20250414
# s2_dw_pct_56789_AK050H24V39_v20250414
# ['s2', 'dw', 'pct', '56789', 'AK050H24V39', 'v20250414', 'tif']
# 56789
# AK050H24V39
# v20250414
# ('{"type": "IMAGE", "gcs_location": {"uris": '
#  '"gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H24V39_v20250414.tif"}, '
#  '"properties": {"months": "56789", "tile": "AK050H24V39", "version_counts": '
#  '"v20250414"}}')
# https://earthengine.googleapis.com/v1alpha/projects/{}/assets?assetId={}
# https://earthengine.googleapis.com/v1alpha/projects/akveg-map/assets?assetId=dynamic_world_metrics/s2_dw_percentages_56789_v20250414/s2_dw_pct_56789_AK050H24V39_v20250414
# s2_dw_pct_56789_AK050H24V40_v20250414
# ['s2', 'dw', 'pct', '56789', 'AK050H24V40', 'v20250414', 'tif']
# 56789
# AK050H24V40
# v20250414
# ('{"type": "IMAGE", "gcs_location": {"uris": '
#  '"gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H24V40_v20250414.tif"}, '
#  '"properties": {"months": "56789", "tile": "AK050H24V40", "version_counts": '
#  '"v20250414"}}')
# https://earthengine.googleapis.com/v1alpha/projects/{}/assets?assetId={}
# https://earthengine.googleapis.com/v1alpha/projects/akveg-map/assets?assetId=dynamic_world_metrics/s2_dw_percentages_56789_v20250414/s2_dw_pct_56789_AK050H24V40_v20250414
# s2_dw_pct_56789_AK050H25V22_v20250414
# ['s2', 'dw', 'pct', '56789', 'AK050H25V22', 'v20250414', 'tif']
# 56789
# AK050H25V22
# v20250414
# ('{"type": "IMAGE", "gcs_location": {"uris": '
#  '"gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H25V22_v20250414.tif"}, '
#  '"properties": {"months": "56789", "tile": "AK050H25V22", "version_counts": '
#  '"v20250414"}}')
# https://earthengine.googleapis.com/v1alpha/projects/{}/assets?assetId={}
# https://earthengine.googleapis.com/v1alpha/projects/akveg-map/assets?assetId=dynamic_world_metrics/s2_dw_percentages_56789_v20250414/s2_dw_pct_56789_AK050H25V22_v20250414
# s2_dw_pct_56789_AK050H25V23_v20250414
# ['s2', 'dw', 'pct', '56789', 'AK050H25V23', 'v20250414', 'tif']
# 56789
# AK050H25V23
# v20250414
# ('{"type": "IMAGE", "gcs_location": {"uris": '
#  '"gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H25V23_v20250414.tif"}, '
#  '"properties": {"months": "56789", "tile": "AK050H25V23", "version_counts": '
#  '"v20250414"}}')
# https://earthengine.googleapis.com/v1alpha/projects/{}/assets?assetId={}
# https://earthengine.googleapis.com/v1alpha/projects/akveg-map/assets?assetId=dynamic_world_metrics/s2_dw_percentages_56789_v20250414/s2_dw_pct_56789_AK050H25V23_v20250414
# s2_dw_pct_56789_AK050H25V30_v20250414
# ['s2', 'dw', 'pct', '56789', 'AK050H25V30', 'v20250414', 'tif']
# 56789
# AK050H25V30
# v20250414
# ('{"type": "IMAGE", "gcs_location": {"uris": '
#  '"gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H25V30_v20250414.tif"}, '
#  '"properties": {"months": "56789", "tile": "AK050H25V30", "version_counts": '
#  '"v20250414"}}')
# https://earthengine.googleapis.com/v1alpha/projects/{}/assets?assetId={}
# https://earthengine.googleapis.com/v1alpha/projects/akveg-map/assets?assetId=dynamic_world_metrics/s2_dw_percentages_56789_v20250414/s2_dw_pct_56789_AK050H25V30_v20250414
# s2_dw_pct_56789_AK050H25V31_v20250414
# ['s2', 'dw', 'pct', '56789', 'AK050H25V31', 'v20250414', 'tif']
# 56789
# AK050H25V31
# v20250414
# ('{"type": "IMAGE", "gcs_location": {"uris": '
#  '"gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H25V31_v20250414.tif"}, '
#  '"properties": {"months": "56789", "tile": "AK050H25V31", "version_counts": '
#  '"v20250414"}}')
# https://earthengine.googleapis.com/v1alpha/projects/{}/assets?assetId={}
# https://earthengine.googleapis.com/v1alpha/projects/akveg-map/assets?assetId=dynamic_world_metrics/s2_dw_percentages_56789_v20250414/s2_dw_pct_56789_AK050H25V31_v20250414
# s2_dw_pct_56789_AK050H25V32_v20250414
# ['s2', 'dw', 'pct', '56789', 'AK050H25V32', 'v20250414', 'tif']
# 56789
# AK050H25V32
# v20250414
# ('{"type": "IMAGE", "gcs_location": {"uris": '
#  '"gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H25V32_v20250414.tif"}, '
#  '"properties": {"months": "56789", "tile": "AK050H25V32", "version_counts": '
#  '"v20250414"}}')
# https://earthengine.googleapis.com/v1alpha/projects/{}/assets?assetId={}
# https://earthengine.googleapis.com/v1alpha/projects/akveg-map/assets?assetId=dynamic_world_metrics/s2_dw_percentages_56789_v20250414/s2_dw_pct_56789_AK050H25V32_v20250414
# s2_dw_pct_56789_AK050H25V39_v20250414
# ['s2', 'dw', 'pct', '56789', 'AK050H25V39', 'v20250414', 'tif']
# 56789
# AK050H25V39
# v20250414
# ('{"type": "IMAGE", "gcs_location": {"uris": '
#  '"gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H25V39_v20250414.tif"}, '
#  '"properties": {"months": "56789", "tile": "AK050H25V39", "version_counts": '
#  '"v20250414"}}')
# https://earthengine.googleapis.com/v1alpha/projects/{}/assets?assetId={}
# https://earthengine.googleapis.com/v1alpha/projects/akveg-map/assets?assetId=dynamic_world_metrics/s2_dw_percentages_56789_v20250414/s2_dw_pct_56789_AK050H25V39_v20250414
# s2_dw_pct_56789_AK050H25V40_v20250414
# ['s2', 'dw', 'pct', '56789', 'AK050H25V40', 'v20250414', 'tif']
# 56789
# AK050H25V40
# v20250414
# ('{"type": "IMAGE", "gcs_location": {"uris": '
#  '"gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H25V40_v20250414.tif"}, '
#  '"properties": {"months": "56789", "tile": "AK050H25V40", "version_counts": '
#  '"v20250414"}}')
# https://earthengine.googleapis.com/v1alpha/projects/{}/assets?assetId={}
# https://earthengine.googleapis.com/v1alpha/projects/akveg-map/assets?assetId=dynamic_world_metrics/s2_dw_percentages_56789_v20250414/s2_dw_pct_56789_AK050H25V40_v20250414
# s2_dw_pct_56789_AK050H26V30_v20250414
# ['s2', 'dw', 'pct', '56789', 'AK050H26V30', 'v20250414', 'tif']
# 56789
# AK050H26V30
# v20250414
# ('{"type": "IMAGE", "gcs_location": {"uris": '
#  '"gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H26V30_v20250414.tif"}, '
#  '"properties": {"months": "56789", "tile": "AK050H26V30", "version_counts": '
#  '"v20250414"}}')
# https://earthengine.googleapis.com/v1alpha/projects/{}/assets?assetId={}
# https://earthengine.googleapis.com/v1alpha/projects/akveg-map/assets?assetId=dynamic_world_metrics/s2_dw_percentages_56789_v20250414/s2_dw_pct_56789_AK050H26V30_v20250414
# s2_dw_pct_56789_AK050H26V31_v20250414
# ['s2', 'dw', 'pct', '56789', 'AK050H26V31', 'v20250414', 'tif']
# 56789
# AK050H26V31
# v20250414
# ('{"type": "IMAGE", "gcs_location": {"uris": '
#  '"gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H26V31_v20250414.tif"}, '
#  '"properties": {"months": "56789", "tile": "AK050H26V31", "version_counts": '
#  '"v20250414"}}')
# https://earthengine.googleapis.com/v1alpha/projects/{}/assets?assetId={}
# https://earthengine.googleapis.com/v1alpha/projects/akveg-map/assets?assetId=dynamic_world_metrics/s2_dw_percentages_56789_v20250414/s2_dw_pct_56789_AK050H26V31_v20250414
# s2_dw_pct_56789_AK050H26V32_v20250414
# ['s2', 'dw', 'pct', '56789', 'AK050H26V32', 'v20250414', 'tif']
# 56789
# AK050H26V32
# v20250414
# ('{"type": "IMAGE", "gcs_location": {"uris": '
#  '"gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H26V32_v20250414.tif"}, '
#  '"properties": {"months": "56789", "tile": "AK050H26V32", "version_counts": '
#  '"v20250414"}}')
# https://earthengine.googleapis.com/v1alpha/projects/{}/assets?assetId={}
# https://earthengine.googleapis.com/v1alpha/projects/akveg-map/assets?assetId=dynamic_world_metrics/s2_dw_percentages_56789_v20250414/s2_dw_pct_56789_AK050H26V32_v20250414
# s2_dw_pct_56789_AK050H26V38_v20250414
# ['s2', 'dw', 'pct', '56789', 'AK050H26V38', 'v20250414', 'tif']
# 56789
# AK050H26V38
# v20250414
# ('{"type": "IMAGE", "gcs_location": {"uris": '
#  '"gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H26V38_v20250414.tif"}, '
#  '"properties": {"months": "56789", "tile": "AK050H26V38", "version_counts": '
#  '"v20250414"}}')
# https://earthengine.googleapis.com/v1alpha/projects/{}/assets?assetId={}
# https://earthengine.googleapis.com/v1alpha/projects/akveg-map/assets?assetId=dynamic_world_metrics/s2_dw_percentages_56789_v20250414/s2_dw_pct_56789_AK050H26V38_v20250414
# s2_dw_pct_56789_AK050H26V39_v20250414
# ['s2', 'dw', 'pct', '56789', 'AK050H26V39', 'v20250414', 'tif']
# 56789
# AK050H26V39
# v20250414
# ('{"type": "IMAGE", "gcs_location": {"uris": '
#  '"gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H26V39_v20250414.tif"}, '
#  '"properties": {"months": "56789", "tile": "AK050H26V39", "version_counts": '
#  '"v20250414"}}')
# https://earthengine.googleapis.com/v1alpha/projects/{}/assets?assetId={}
# https://earthengine.googleapis.com/v1alpha/projects/akveg-map/assets?assetId=dynamic_world_metrics/s2_dw_percentages_56789_v20250414/s2_dw_pct_56789_AK050H26V39_v20250414
# s2_dw_pct_56789_AK050H26V40_v20250414
# ['s2', 'dw', 'pct', '56789', 'AK050H26V40', 'v20250414', 'tif']
# 56789
# AK050H26V40
# v20250414
# ('{"type": "IMAGE", "gcs_location": {"uris": '
#  '"gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H26V40_v20250414.tif"}, '
#  '"properties": {"months": "56789", "tile": "AK050H26V40", "version_counts": '
#  '"v20250414"}}')
# https://earthengine.googleapis.com/v1alpha/projects/{}/assets?assetId={}
# https://earthengine.googleapis.com/v1alpha/projects/akveg-map/assets?assetId=dynamic_world_metrics/s2_dw_percentages_56789_v20250414/s2_dw_pct_56789_AK050H26V40_v20250414
# s2_dw_pct_56789_AK050H27V15_v20250414
# ['s2', 'dw', 'pct', '56789', 'AK050H27V15', 'v20250414', 'tif']
# 56789
# AK050H27V15
# v20250414
# ('{"type": "IMAGE", "gcs_location": {"uris": '
#  '"gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H27V15_v20250414.tif"}, '
#  '"properties": {"months": "56789", "tile": "AK050H27V15", "version_counts": '
#  '"v20250414"}}')
# https://earthengine.googleapis.com/v1alpha/projects/{}/assets?assetId={}
# https://earthengine.googleapis.com/v1alpha/projects/akveg-map/assets?assetId=dynamic_world_metrics/s2_dw_percentages_56789_v20250414/s2_dw_pct_56789_AK050H27V15_v20250414
# s2_dw_pct_56789_AK050H27V16_v20250414
# ['s2', 'dw', 'pct', '56789', 'AK050H27V16', 'v20250414', 'tif']
# 56789
# AK050H27V16
# v20250414
# ('{"type": "IMAGE", "gcs_location": {"uris": '
#  '"gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H27V16_v20250414.tif"}, '
#  '"properties": {"months": "56789", "tile": "AK050H27V16", "version_counts": '
#  '"v20250414"}}')
# https://earthengine.googleapis.com/v1alpha/projects/{}/assets?assetId={}
# https://earthengine.googleapis.com/v1alpha/projects/akveg-map/assets?assetId=dynamic_world_metrics/s2_dw_percentages_56789_v20250414/s2_dw_pct_56789_AK050H27V16_v20250414
# s2_dw_pct_56789_AK050H27V17_v20250414
# ['s2', 'dw', 'pct', '56789', 'AK050H27V17', 'v20250414', 'tif']
# 56789
# AK050H27V17
# v20250414
# ('{"type": "IMAGE", "gcs_location": {"uris": '
#  '"gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H27V17_v20250414.tif"}, '
#  '"properties": {"months": "56789", "tile": "AK050H27V17", "version_counts": '
#  '"v20250414"}}')
# https://earthengine.googleapis.com/v1alpha/projects/{}/assets?assetId={}
# https://earthengine.googleapis.com/v1alpha/projects/akveg-map/assets?assetId=dynamic_world_metrics/s2_dw_percentages_56789_v20250414/s2_dw_pct_56789_AK050H27V17_v20250414
# s2_dw_pct_56789_AK050H27V38_v20250414
# ['s2', 'dw', 'pct', '56789', 'AK050H27V38', 'v20250414', 'tif']
# 56789
# AK050H27V38
# v20250414
# ('{"type": "IMAGE", "gcs_location": {"uris": '
#  '"gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H27V38_v20250414.tif"}, '
#  '"properties": {"months": "56789", "tile": "AK050H27V38", "version_counts": '
#  '"v20250414"}}')
# https://earthengine.googleapis.com/v1alpha/projects/{}/assets?assetId={}
# https://earthengine.googleapis.com/v1alpha/projects/akveg-map/assets?assetId=dynamic_world_metrics/s2_dw_percentages_56789_v20250414/s2_dw_pct_56789_AK050H27V38_v20250414
# s2_dw_pct_56789_AK050H27V39_v20250414
# ['s2', 'dw', 'pct', '56789', 'AK050H27V39', 'v20250414', 'tif']
# 56789
# AK050H27V39
# v20250414
# ('{"type": "IMAGE", "gcs_location": {"uris": '
#  '"gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H27V39_v20250414.tif"}, '
#  '"properties": {"months": "56789", "tile": "AK050H27V39", "version_counts": '
#  '"v20250414"}}')
# https://earthengine.googleapis.com/v1alpha/projects/{}/assets?assetId={}
# https://earthengine.googleapis.com/v1alpha/projects/akveg-map/assets?assetId=dynamic_world_metrics/s2_dw_percentages_56789_v20250414/s2_dw_pct_56789_AK050H27V39_v20250414
# s2_dw_pct_56789_AK050H27V40_v20250414
# ['s2', 'dw', 'pct', '56789', 'AK050H27V40', 'v20250414', 'tif']
# 56789
# AK050H27V40
# v20250414
# ('{"type": "IMAGE", "gcs_location": {"uris": '
#  '"gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H27V40_v20250414.tif"}, '
#  '"properties": {"months": "56789", "tile": "AK050H27V40", "version_counts": '
#  '"v20250414"}}')
# https://earthengine.googleapis.com/v1alpha/projects/{}/assets?assetId={}
# https://earthengine.googleapis.com/v1alpha/projects/akveg-map/assets?assetId=dynamic_world_metrics/s2_dw_percentages_56789_v20250414/s2_dw_pct_56789_AK050H27V40_v20250414
# s2_dw_pct_56789_AK050H28V15_v20250414
# ['s2', 'dw', 'pct', '56789', 'AK050H28V15', 'v20250414', 'tif']
# 56789
# AK050H28V15
# v20250414
# ('{"type": "IMAGE", "gcs_location": {"uris": '
#  '"gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H28V15_v20250414.tif"}, '
#  '"properties": {"months": "56789", "tile": "AK050H28V15", "version_counts": '
#  '"v20250414"}}')
# https://earthengine.googleapis.com/v1alpha/projects/{}/assets?assetId={}
# https://earthengine.googleapis.com/v1alpha/projects/akveg-map/assets?assetId=dynamic_world_metrics/s2_dw_percentages_56789_v20250414/s2_dw_pct_56789_AK050H28V15_v20250414
# s2_dw_pct_56789_AK050H28V16_v20250414
# ['s2', 'dw', 'pct', '56789', 'AK050H28V16', 'v20250414', 'tif']
# 56789
# AK050H28V16
# v20250414
# ('{"type": "IMAGE", "gcs_location": {"uris": '
#  '"gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H28V16_v20250414.tif"}, '
#  '"properties": {"months": "56789", "tile": "AK050H28V16", "version_counts": '
#  '"v20250414"}}')
# https://earthengine.googleapis.com/v1alpha/projects/{}/assets?assetId={}
# https://earthengine.googleapis.com/v1alpha/projects/akveg-map/assets?assetId=dynamic_world_metrics/s2_dw_percentages_56789_v20250414/s2_dw_pct_56789_AK050H28V16_v20250414
# s2_dw_pct_56789_AK050H28V17_v20250414
# ['s2', 'dw', 'pct', '56789', 'AK050H28V17', 'v20250414', 'tif']
# 56789
# AK050H28V17
# v20250414
# ('{"type": "IMAGE", "gcs_location": {"uris": '
#  '"gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H28V17_v20250414.tif"}, '
#  '"properties": {"months": "56789", "tile": "AK050H28V17", "version_counts": '
#  '"v20250414"}}')
# https://earthengine.googleapis.com/v1alpha/projects/{}/assets?assetId={}
# https://earthengine.googleapis.com/v1alpha/projects/akveg-map/assets?assetId=dynamic_world_metrics/s2_dw_percentages_56789_v20250414/s2_dw_pct_56789_AK050H28V17_v20250414
# s2_dw_pct_56789_AK050H28V18_v20250414
# ['s2', 'dw', 'pct', '56789', 'AK050H28V18', 'v20250414', 'tif']
# 56789
# AK050H28V18
# v20250414
# ('{"type": "IMAGE", "gcs_location": {"uris": '
#  '"gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H28V18_v20250414.tif"}, '
#  '"properties": {"months": "56789", "tile": "AK050H28V18", "version_counts": '
#  '"v20250414"}}')
# https://earthengine.googleapis.com/v1alpha/projects/{}/assets?assetId={}
# https://earthengine.googleapis.com/v1alpha/projects/akveg-map/assets?assetId=dynamic_world_metrics/s2_dw_percentages_56789_v20250414/s2_dw_pct_56789_AK050H28V18_v20250414
# s2_dw_pct_56789_AK050H28V38_v20250414
# ['s2', 'dw', 'pct', '56789', 'AK050H28V38', 'v20250414', 'tif']
# 56789
# AK050H28V38
# v20250414
# ('{"type": "IMAGE", "gcs_location": {"uris": '
#  '"gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H28V38_v20250414.tif"}, '
#  '"properties": {"months": "56789", "tile": "AK050H28V38", "version_counts": '
#  '"v20250414"}}')
# https://earthengine.googleapis.com/v1alpha/projects/{}/assets?assetId={}
# https://earthengine.googleapis.com/v1alpha/projects/akveg-map/assets?assetId=dynamic_world_metrics/s2_dw_percentages_56789_v20250414/s2_dw_pct_56789_AK050H28V38_v20250414
# s2_dw_pct_56789_AK050H28V39_v20250414
# ...
# https://earthengine.googleapis.com/v1alpha/projects/akveg-map/assets?assetId=dynamic_world_metrics/s2_dw_percentages_56789_v20250414/s2_dw_pct_56789_AK050H38V11_v20250414
# s2_dw_pct_56789_AK050H38V12_v20250414
# ['s2', 'dw', 'pct', '56789', 'AK050H38V12', 'v20250414', 'tif']
# 56789
# AK050H38V12
# v20250414
# ('{"type": "IMAGE", "gcs_location": {"uris": '
#  '"gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H38V12_v20250414.tif"}, '
#  '"properties": {"months": "56789", "tile": "AK050H38V12", "version_counts": '
#  '"v20250414"}}')
# https://earthengine.googleapis.com/v1alpha/projects/{}/assets?assetId={}
# https://earthengine.googleapis.com/v1alpha/projects/akveg-map/assets?assetId=dynamic_world_metrics/s2_dw_percentages_56789_v20250414/s2_dw_pct_56789_AK050H38V12_v20250414
# s2_dw_pct_56789_AK050H38V13_v20250414
# ['s2', 'dw', 'pct', '56789', 'AK050H38V13', 'v20250414', 'tif']
# 56789
# AK050H38V13
# v20250414
# ('{"type": "IMAGE", "gcs_location": {"uris": '
#  '"gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H38V13_v20250414.tif"}, '
#  '"properties": {"months": "56789", "tile": "AK050H38V13", "version_counts": '
#  '"v20250414"}}')
# https://earthengine.googleapis.com/v1alpha/projects/{}/assets?assetId={}
# https://earthengine.googleapis.com/v1alpha/projects/akveg-map/assets?assetId=dynamic_world_metrics/s2_dw_percentages_56789_v20250414/s2_dw_pct_56789_AK050H38V13_v20250414
# s2_dw_pct_56789_AK050H38V14_v20250414
# ['s2', 'dw', 'pct', '56789', 'AK050H38V14', 'v20250414', 'tif']
# 56789
# AK050H38V14
# v20250414
# ('{"type": "IMAGE", "gcs_location": {"uris": '
#  '"gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H38V14_v20250414.tif"}, '
#  '"properties": {"months": "56789", "tile": "AK050H38V14", "version_counts": '
#  '"v20250414"}}')
# https://earthengine.googleapis.com/v1alpha/projects/{}/assets?assetId={}
# https://earthengine.googleapis.com/v1alpha/projects/akveg-map/assets?assetId=dynamic_world_metrics/s2_dw_percentages_56789_v20250414/s2_dw_pct_56789_AK050H38V14_v20250414
# s2_dw_pct_56789_AK050H38V15_v20250414
# ['s2', 'dw', 'pct', '56789', 'AK050H38V15', 'v20250414', 'tif']
# 56789
# AK050H38V15
# v20250414
# ('{"type": "IMAGE", "gcs_location": {"uris": '
#  '"gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H38V15_v20250414.tif"}, '
#  '"properties": {"months": "56789", "tile": "AK050H38V15", "version_counts": '
#  '"v20250414"}}')
# https://earthengine.googleapis.com/v1alpha/projects/{}/assets?assetId={}
# https://earthengine.googleapis.com/v1alpha/projects/akveg-map/assets?assetId=dynamic_world_metrics/s2_dw_percentages_56789_v20250414/s2_dw_pct_56789_AK050H38V15_v20250414
# s2_dw_pct_56789_AK050H38V16_v20250414
# ['s2', 'dw', 'pct', '56789', 'AK050H38V16', 'v20250414', 'tif']
# 56789
# AK050H38V16
# v20250414
# ('{"type": "IMAGE", "gcs_location": {"uris": '
#  '"gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H38V16_v20250414.tif"}, '
#  '"properties": {"months": "56789", "tile": "AK050H38V16", "version_counts": '
#  '"v20250414"}}')
# https://earthengine.googleapis.com/v1alpha/projects/{}/assets?assetId={}
# https://earthengine.googleapis.com/v1alpha/projects/akveg-map/assets?assetId=dynamic_world_metrics/s2_dw_percentages_56789_v20250414/s2_dw_pct_56789_AK050H38V16_v20250414
# s2_dw_pct_56789_AK050H38V17_v20250414
# ['s2', 'dw', 'pct', '56789', 'AK050H38V17', 'v20250414', 'tif']
# 56789
# AK050H38V17
# v20250414
# ('{"type": "IMAGE", "gcs_location": {"uris": '
#  '"gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H38V17_v20250414.tif"}, '
#  '"properties": {"months": "56789", "tile": "AK050H38V17", "version_counts": '
#  '"v20250414"}}')
# https://earthengine.googleapis.com/v1alpha/projects/{}/assets?assetId={}
# https://earthengine.googleapis.com/v1alpha/projects/akveg-map/assets?assetId=dynamic_world_metrics/s2_dw_percentages_56789_v20250414/s2_dw_pct_56789_AK050H38V17_v20250414
# s2_dw_pct_56789_AK050H38V18_v20250414
# ['s2', 'dw', 'pct', '56789', 'AK050H38V18', 'v20250414', 'tif']
# 56789
# AK050H38V18
# v20250414
# ('{"type": "IMAGE", "gcs_location": {"uris": '
#  '"gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H38V18_v20250414.tif"}, '
#  '"properties": {"months": "56789", "tile": "AK050H38V18", "version_counts": '
#  '"v20250414"}}')
# https://earthengine.googleapis.com/v1alpha/projects/{}/assets?assetId={}
# https://earthengine.googleapis.com/v1alpha/projects/akveg-map/assets?assetId=dynamic_world_metrics/s2_dw_percentages_56789_v20250414/s2_dw_pct_56789_AK050H38V18_v20250414
# s2_dw_pct_56789_AK050H38V19_v20250414
# ['s2', 'dw', 'pct', '56789', 'AK050H38V19', 'v20250414', 'tif']
# 56789
# AK050H38V19
# v20250414
# ('{"type": "IMAGE", "gcs_location": {"uris": '
#  '"gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H38V19_v20250414.tif"}, '
#  '"properties": {"months": "56789", "tile": "AK050H38V19", "version_counts": '
#  '"v20250414"}}')
# https://earthengine.googleapis.com/v1alpha/projects/{}/assets?assetId={}
# https://earthengine.googleapis.com/v1alpha/projects/akveg-map/assets?assetId=dynamic_world_metrics/s2_dw_percentages_56789_v20250414/s2_dw_pct_56789_AK050H38V19_v20250414
# s2_dw_pct_56789_AK050H38V20_v20250414
# ['s2', 'dw', 'pct', '56789', 'AK050H38V20', 'v20250414', 'tif']
# 56789
# AK050H38V20
# v20250414
# ('{"type": "IMAGE", "gcs_location": {"uris": '
#  '"gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H38V20_v20250414.tif"}, '
#  '"properties": {"months": "56789", "tile": "AK050H38V20", "version_counts": '
#  '"v20250414"}}')
# https://earthengine.googleapis.com/v1alpha/projects/{}/assets?assetId={}
# https://earthengine.googleapis.com/v1alpha/projects/akveg-map/assets?assetId=dynamic_world_metrics/s2_dw_percentages_56789_v20250414/s2_dw_pct_56789_AK050H38V20_v20250414
# s2_dw_pct_56789_AK050H38V21_v20250414
# ['s2', 'dw', 'pct', '56789', 'AK050H38V21', 'v20250414', 'tif']
# 56789
# AK050H38V21
# v20250414
# ('{"type": "IMAGE", "gcs_location": {"uris": '
#  '"gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H38V21_v20250414.tif"}, '
#  '"properties": {"months": "56789", "tile": "AK050H38V21", "version_counts": '
#  '"v20250414"}}')
# https://earthengine.googleapis.com/v1alpha/projects/{}/assets?assetId={}
# https://earthengine.googleapis.com/v1alpha/projects/akveg-map/assets?assetId=dynamic_world_metrics/s2_dw_percentages_56789_v20250414/s2_dw_pct_56789_AK050H38V21_v20250414
# s2_dw_pct_56789_AK050H38V22_v20250414
# ['s2', 'dw', 'pct', '56789', 'AK050H38V22', 'v20250414', 'tif']
# 56789
# AK050H38V22
# v20250414
# ('{"type": "IMAGE", "gcs_location": {"uris": '
#  '"gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H38V22_v20250414.tif"}, '
#  '"properties": {"months": "56789", "tile": "AK050H38V22", "version_counts": '
#  '"v20250414"}}')
# https://earthengine.googleapis.com/v1alpha/projects/{}/assets?assetId={}
# https://earthengine.googleapis.com/v1alpha/projects/akveg-map/assets?assetId=dynamic_world_metrics/s2_dw_percentages_56789_v20250414/s2_dw_pct_56789_AK050H38V22_v20250414
# s2_dw_pct_56789_AK050H38V23_v20250414
# ['s2', 'dw', 'pct', '56789', 'AK050H38V23', 'v20250414', 'tif']
# 56789
# AK050H38V23
# v20250414
# ('{"type": "IMAGE", "gcs_location": {"uris": '
#  '"gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H38V23_v20250414.tif"}, '
#  '"properties": {"months": "56789", "tile": "AK050H38V23", "version_counts": '
#  '"v20250414"}}')
# https://earthengine.googleapis.com/v1alpha/projects/{}/assets?assetId={}
# https://earthengine.googleapis.com/v1alpha/projects/akveg-map/assets?assetId=dynamic_world_metrics/s2_dw_percentages_56789_v20250414/s2_dw_pct_56789_AK050H38V23_v20250414
# s2_dw_pct_56789_AK050H38V24_v20250414
# ['s2', 'dw', 'pct', '56789', 'AK050H38V24', 'v20250414', 'tif']
# 56789
# AK050H38V24
# v20250414
# ('{"type": "IMAGE", "gcs_location": {"uris": '
#  '"gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H38V24_v20250414.tif"}, '
#  '"properties": {"months": "56789", "tile": "AK050H38V24", "version_counts": '
#  '"v20250414"}}')
# https://earthengine.googleapis.com/v1alpha/projects/{}/assets?assetId={}
# https://earthengine.googleapis.com/v1alpha/projects/akveg-map/assets?assetId=dynamic_world_metrics/s2_dw_percentages_56789_v20250414/s2_dw_pct_56789_AK050H38V24_v20250414
# s2_dw_pct_56789_AK050H38V25_v20250414
# ['s2', 'dw', 'pct', '56789', 'AK050H38V25', 'v20250414', 'tif']
# 56789
# AK050H38V25
# v20250414
# ('{"type": "IMAGE", "gcs_location": {"uris": '
#  '"gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H38V25_v20250414.tif"}, '
#  '"properties": {"months": "56789", "tile": "AK050H38V25", "version_counts": '
#  '"v20250414"}}')
# https://earthengine.googleapis.com/v1alpha/projects/{}/assets?assetId={}
# https://earthengine.googleapis.com/v1alpha/projects/akveg-map/assets?assetId=dynamic_world_metrics/s2_dw_percentages_56789_v20250414/s2_dw_pct_56789_AK050H38V25_v20250414
# s2_dw_pct_56789_AK050H38V26_v20250414
# ['s2', 'dw', 'pct', '56789', 'AK050H38V26', 'v20250414', 'tif']
# 56789
# AK050H38V26
# v20250414
# ('{"type": "IMAGE", "gcs_location": {"uris": '
#  '"gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H38V26_v20250414.tif"}, '
#  '"properties": {"months": "56789", "tile": "AK050H38V26", "version_counts": '
#  '"v20250414"}}')
# https://earthengine.googleapis.com/v1alpha/projects/{}/assets?assetId={}
# https://earthengine.googleapis.com/v1alpha/projects/akveg-map/assets?assetId=dynamic_world_metrics/s2_dw_percentages_56789_v20250414/s2_dw_pct_56789_AK050H38V26_v20250414
# s2_dw_pct_56789_AK050H38V27_v20250414
# ['s2', 'dw', 'pct', '56789', 'AK050H38V27', 'v20250414', 'tif']
# 56789
# AK050H38V27
# v20250414
# ('{"type": "IMAGE", "gcs_location": {"uris": '
#  '"gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H38V27_v20250414.tif"}, '
#  '"properties": {"months": "56789", "tile": "AK050H38V27", "version_counts": '
#  '"v20250414"}}')
# https://earthengine.googleapis.com/v1alpha/projects/{}/assets?assetId={}
# https://earthengine.googleapis.com/v1alpha/projects/akveg-map/assets?assetId=dynamic_world_metrics/s2_dw_percentages_56789_v20250414/s2_dw_pct_56789_AK050H38V27_v20250414
# s2_dw_pct_56789_AK050H38V28_v20250414
# ['s2', 'dw', 'pct', '56789', 'AK050H38V28', 'v20250414', 'tif']
# 56789
# AK050H38V28
# v20250414
# ('{"type": "IMAGE", "gcs_location": {"uris": '
#  '"gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H38V28_v20250414.tif"}, '
#  '"properties": {"months": "56789", "tile": "AK050H38V28", "version_counts": '
#  '"v20250414"}}')
# https://earthengine.googleapis.com/v1alpha/projects/{}/assets?assetId={}
# https://earthengine.googleapis.com/v1alpha/projects/akveg-map/assets?assetId=dynamic_world_metrics/s2_dw_percentages_56789_v20250414/s2_dw_pct_56789_AK050H38V28_v20250414
# s2_dw_pct_56789_AK050H38V29_v20250414
# ['s2', 'dw', 'pct', '56789', 'AK050H38V29', 'v20250414', 'tif']
# 56789
# AK050H38V29
# v20250414
# ('{"type": "IMAGE", "gcs_location": {"uris": '
#  '"gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H38V29_v20250414.tif"}, '
#  '"properties": {"months": "56789", "tile": "AK050H38V29", "version_counts": '
#  '"v20250414"}}')
# https://earthengine.googleapis.com/v1alpha/projects/{}/assets?assetId={}
# https://earthengine.googleapis.com/v1alpha/projects/akveg-map/assets?assetId=dynamic_world_metrics/s2_dw_percentages_56789_v20250414/s2_dw_pct_56789_AK050H38V29_v20250414
# s2_dw_pct_56789_AK050H38V30_v20250414
# ['s2', 'dw', 'pct', '56789', 'AK050H38V30', 'v20250414', 'tif']
# 56789
# AK050H38V30
# v20250414
# ('{"type": "IMAGE", "gcs_location": {"uris": '
#  '"gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H38V30_v20250414.tif"}, '
#  '"properties": {"months": "56789", "tile": "AK050H38V30", "version_counts": '
#  '"v20250414"}}')
# https://earthengine.googleapis.com/v1alpha/projects/{}/assets?assetId={}
# https://earthengine.googleapis.com/v1alpha/projects/akveg-map/assets?assetId=dynamic_world_metrics/s2_dw_percentages_56789_v20250414/s2_dw_pct_56789_AK050H38V30_v20250414
# s2_dw_pct_56789_AK050H38V33_v20250414
# ['s2', 'dw', 'pct', '56789', 'AK050H38V33', 'v20250414', 'tif']
# 56789
# AK050H38V33
# v20250414
# ('{"type": "IMAGE", "gcs_location": {"uris": '
#  '"gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H38V33_v20250414.tif"}, '
#  '"properties": {"months": "56789", "tile": "AK050H38V33", "version_counts": '
#  '"v20250414"}}')
# https://earthengine.googleapis.com/v1alpha/projects/{}/assets?assetId={}
# https://earthengine.googleapis.com/v1alpha/projects/akveg-map/assets?assetId=dynamic_world_metrics/s2_dw_percentages_56789_v20250414/s2_dw_pct_56789_AK050H38V33_v20250414
# s2_dw_pct_56789_AK050H38V34_v20250414
# ['s2', 'dw', 'pct', '56789', 'AK050H38V34', 'v20250414', 'tif']
# 56789
# AK050H38V34
# v20250414
# ('{"type": "IMAGE", "gcs_location": {"uris": '
#  '"gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H38V34_v20250414.tif"}, '
#  '"properties": {"months": "56789", "tile": "AK050H38V34", "version_counts": '
#  '"v20250414"}}')
# https://earthengine.googleapis.com/v1alpha/projects/{}/assets?assetId={}
# https://earthengine.googleapis.com/v1alpha/projects/akveg-map/assets?assetId=dynamic_world_metrics/s2_dw_percentages_56789_v20250414/s2_dw_pct_56789_AK050H38V34_v20250414
# s2_dw_pct_56789_AK050H38V35_v20250414
# ['s2', 'dw', 'pct', '56789', 'AK050H38V35', 'v20250414', 'tif']
# 56789
# AK050H38V35
# v20250414
# ('{"type": "IMAGE", "gcs_location": {"uris": '
#  '"gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H38V35_v20250414.tif"}, '
#  '"properties": {"months": "56789", "tile": "AK050H38V35", "version_counts": '
#  '"v20250414"}}')
# https://earthengine.googleapis.com/v1alpha/projects/{}/assets?assetId={}
# https://earthengine.googleapis.com/v1alpha/projects/akveg-map/assets?assetId=dynamic_world_metrics/s2_dw_percentages_56789_v20250414/s2_dw_pct_56789_AK050H38V35_v20250414
# s2_dw_pct_56789_AK050H38V36_v20250414
# ['s2', 'dw', 'pct', '56789', 'AK050H38V36', 'v20250414', 'tif']
# 56789
# AK050H38V36
# v20250414
# ('{"type": "IMAGE", "gcs_location": {"uris": '
#  '"gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H38V36_v20250414.tif"}, '
#  '"properties": {"months": "56789", "tile": "AK050H38V36", "version_counts": '
#  '"v20250414"}}')
# https://earthengine.googleapis.com/v1alpha/projects/{}/assets?assetId={}
# https://earthengine.googleapis.com/v1alpha/projects/akveg-map/assets?assetId=dynamic_world_metrics/s2_dw_percentages_56789_v20250414/s2_dw_pct_56789_AK050H38V36_v20250414
# s2_dw_pct_56789_AK050H38V37_v20250414
# ['s2', 'dw', 'pct', '56789', 'AK050H38V37', 'v20250414', 'tif']
# 56789
# AK050H38V37
# v20250414
# ('{"type": "IMAGE", "gcs_location": {"uris": '
#  '"gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H38V37_v20250414.tif"}, '
#  '"properties": {"months": "56789", "tile": "AK050H38V37", "version_counts": '
#  '"v20250414"}}')
# https://earthengine.googleapis.com/v1alpha/projects/{}/assets?assetId={}
# https://earthengine.googleapis.com/v1alpha/projects/akveg-map/assets?assetId=dynamic_world_metrics/s2_dw_percentages_56789_v20250414/s2_dw_pct_56789_AK050H38V37_v20250414
# s2_dw_pct_56789_AK050H38V38_v20250414
# ['s2', 'dw', 'pct', '56789', 'AK050H38V38', 'v20250414', 'tif']
# 56789
# AK050H38V38
# v20250414
# ('{"type": "IMAGE", "gcs_location": {"uris": '
#  '"gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/s2_dw_pct_56789_AK050H38V38_v20250414.tif"}, '
#  '"properties": {"months": "56789", "tile": "AK050H38V38", "version_counts": '
#  '"v20250414"}}')
# https://earthengine.googleapis.com/v1alpha/projects/{}/assets?assetId={}
# https://earthengine.googleapis.com/v1alpha/projects/akveg-map/assets?assetId=dynamic_world_metrics/s2_dw_percentages_56789_v20250414/s2_dw_pct_56789_AK050H38V38_v20250414
# done

# %% [raw]
# Get summary of compute effort (EECUs) and GCS storage
# ~10.8 million EECU seconds for 5 months x 351 AKVeg MGRS tiles
# 30,770 EECU seconds per MGRS tile
# ~$1200 or $3.41 per MGRS tile
#
# To get size and count of exports:
#
# (ee) mmacander@mason:/data/gis/raster_base/Alaska/AKVegMap/dynamic_world$ gsutil du -sh gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414
#
# 55.19 GiB
#
# (ee) mmacander@mason:/data/gis/raster_base/Alaska/AKVegMap/dynamic_world$ gsutil ls gs://akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/*.tif | wc -l
#
# 428 images

# %%
import ee
import pandas as pd
from datetime import datetime, timezone

# Initialize Earth Engine
ee.Initialize()

# Parse Alaska time in format: 'YYYY-MM-DD HH:MM:SS -0800'
def parse_alaska_offset(s):
    return datetime.strptime(s, '%Y-%m-%d %H:%M:%S %z').astimezone(timezone.utc)

# Input times (Alaska time with UTC offset)
start_str = '2026-02-03 21:20:00 -0800'
end_str   = '2026-02-05 12:00:00 -0800'

start_dt = parse_alaska_offset(start_str)
end_dt   = parse_alaska_offset(end_str)

# List tasks
ops = ee.data.listOperations()
print(ops)

# Filter and collect metadata
all_keys = set()
filtered_ops = []
for op in ops:
    meta = op.get('metadata', {})
    create_time = meta.get('createTime')
    if create_time:
        create_dt = datetime.fromisoformat(create_time.replace('Z', '+00:00'))
        if start_dt <= create_dt <= end_dt:
            filtered_ops.append(op)
            all_keys.update(meta.keys())

# Build rows
all_keys = sorted(all_keys)
rows = []
for op in filtered_ops:
    meta = op.get('metadata', {})
    row = {key: meta.get(key, None) for key in all_keys}
    row['task_id'] = op.get('name', '').split('/')[-1]
    row['state'] = 'DONE' if op.get('done') else 'RUNNING'
    rows.append(row)

# Save to CSV
df = pd.DataFrame(rows)
# df.to_csv('/data/gis/raster_base/Alaska/AKVegMap/dynamic_world/gee_tasks_all_metadata_20250424.csv', index=False)
# df.to_csv('./gee_tasks_all_metadata_20250424.csv', index=False)

total = df['batchEecuUsageSeconds'].sum()
cost = f"${total/3600*0.4:,.2f}"
print('EECUs:', total, cost)
# Out:
# [{'name': 'projects/akveg-map/operations/6NF4743ZSBQ56U2XUESMVIDI', 'metadata': {'@type': 'type.googleapis.com/google.earthengine.v1alpha.OperationMetadata', 'state': 'SUCCEEDED', 'description': 's2_dw_counts_56789_AK050H38V38_v20250414', 'priority': 100, 'createTime': '2026-02-04T18:36:55.215521Z', 'updateTime': '2026-02-05T07:46:41.729332Z', 'startTime': '2026-02-05T07:37:19.270752Z', 'endTime': '2026-02-05T07:46:41.729332Z', 'type': 'EXPORT_IMAGE', 'scriptUri': 'https://code.earthengine.google.com/9f48dff8029e67ce326b7a74ef84b451?noload=1', 'destinationUris': ['https://console.developers.google.com/storage/browser/akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/'], 'attempt': 1, 'progress': 1, 'stages': [{'displayName': 'Create Local Files', 'completeWorkUnits': 1, 'totalWorkUnits': '1', 'description': 'Computation and writing of temporary files.'}, {'displayName': 'Write Files to Destination', 'completeWorkUnits': 1, 'totalWorkUnits': '1', 'description': 'Uploading of files to the export destination.'}], 'batchEecuUsageSeconds': 452.880126953125}, 'done': True, 'response': {'@type': 'type.googleapis.com/google.protobuf.Empty'}}, {'name': 'projects/akveg-map/operations/PLJV3LSSQW3WDFPJ2GULJLTV', 'metadata': {'@type': 'type.googleapis.com/google.earthengine.v1alpha.OperationMetadata', 'state': 'SUCCEEDED', 'description': 's2_dw_counts_56789_AK050H38V37_v20250414', 'priority': 100, 'createTime': '2026-02-04T18:34:55.172424Z', 'updateTime': '2026-02-05T07:50:48.693474Z', 'startTime': '2026-02-05T07:33:18.879168Z', 'endTime': '2026-02-05T07:50:48.693474Z', 'type': 'EXPORT_IMAGE', 'scriptUri': 'https://code.earthengine.google.com/9f48dff8029e67ce326b7a74ef84b451?noload=1', 'destinationUris': ['https://console.developers.google.com/storage/browser/akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/'], 'attempt': 1, 'progress': 1, 'stages': [{'displayName': 'Create Local Files', 'completeWorkUnits': 1, 'totalWorkUnits': '1', 'description': 'Computation and writing of temporary files.'}, {'displayName': 'Write Files to Destination', 'completeWorkUnits': 1, 'totalWorkUnits': '1', 'description': 'Uploading of files to the export destination.'}], 'batchEecuUsageSeconds': 731.5562744140625}, 'done': True, 'response': {'@type': 'type.googleapis.com/google.protobuf.Empty'}}, {'name': 'projects/akveg-map/operations/4FII22BWGK4HHHEDHA45T44C', 'metadata': {'@type': 'type.googleapis.com/google.earthengine.v1alpha.OperationMetadata', 'state': 'SUCCEEDED', 'description': 's2_dw_counts_56789_AK050H38V36_v20250414', 'priority': 100, 'createTime': '2026-02-04T18:32:55.243340Z', 'updateTime': '2026-02-05T07:37:12.573227Z', 'startTime': '2026-02-05T07:33:07.476782Z', 'endTime': '2026-02-05T07:37:12.573227Z', 'type': 'EXPORT_IMAGE', 'scriptUri': 'https://code.earthengine.google.com/9f48dff8029e67ce326b7a74ef84b451?noload=1', 'destinationUris': ['https://console.developers.google.com/storage/browser/akveg-data/s2_dw_v1_metrics/s2_dw_pct_akalb_050_v20250414/'], 'attempt': 1, 'progress': 1, 'stages': [{'displayName': 'Create Local Files', 'completeWorkUnits': 1, 'totalWorkUnits': '1', 'description': 'Computation and writing of temporary files.'}, {'displayName': 'Write Files to Destination', 'completeWorkUnits': 1, 'totalWorkUnits': '1', 'description': 'Uploading of files to the export destination.'}], 'batchEecuUsageSeconds': 522.41357421875}, 'done': True, 'response': {'@type': 'type.googleapis.com/google.protobuf.Empty'}}, {'name': 'projects/akveg-map/operations/SVBX5CHRAWN4TNKIXV6SA4XC', 'metadata': {'@type': 'type.googleapis.com/google.earthengine.v1alpha.OperationMetadata', 'state': 'SUCCEEDED', 'description': 's2_dw_counts_56789_AK050H38V35_v20250414', 'priority': 100, 'createTime': '2026-02-04T18:30:57.124324Z', 'updateTime': '2026-02-05T07:33:04.285419Z', 'startTime': '2026-02-05T07:26:53.811702Z', 'endTime': '2026-02-05T07:33:04.285419Z', 'type': 'EXPORT_IMAGE', 'scriptUri': 'https://code.earthengine.google.com/9f48dff8029e67 ...
# ---------------------------------------------------------------------------
#
# KeyError                                  Traceback (most recent call last)
#
# Cell In[16], line 50
#
#      46 df = pd.DataFrame(rows)
#
#      47 # df.to_csv('/data/gis/raster_base/Alaska/AKVegMap/dynamic_world/gee_tasks_all_metadata_20250424.csv', index=False)
#
#      48 # df.to_csv('./gee_tasks_all_metadata_20250424.csv', index=False)
#
# ---> 50 total = df['batchEecuUsageSeconds'].sum()
#
#      51 cost = f"${total/3600*0.4:,.2f}"
#
#      52 print('EECUs:', total, cost)
#
#
#
# File ~/miniforge3/envs/ee_env/lib/python3.11/site-packages/pandas/core/frame.py:4378, in DataFrame.__getitem__(self, key)
#
#    4376 if self.columns.nlevels > 1:
#
#    4377     return self._getitem_multilevel(key)
#
# -> 4378 indexer = self.columns.get_loc(key)
#
#    4379 if is_integer(indexer):
#
#    4380     indexer = [indexer]
#
#
#
# File ~/miniforge3/envs/ee_env/lib/python3.11/site-packages/pandas/core/indexes/range.py:525, in RangeIndex.get_loc(self, key)
#
#     523         raise KeyError(key) from err
#
#     524 if isinstance(key, Hashable):
#
# --> 525     raise KeyError(key)
#
#     526 self._check_indexing_error(key)
#
#     527 raise KeyError(key)
#
#
#
# KeyError: 'batchEecuUsageSeconds'

# %%
import ee
ee.Initialize()

operations = ee.data.listOperations()

# Filter for failed or cancelled tasks
failed_ops = [
    op for op in operations
    if op.get('metadata', {}).get('state') in ['FAILED', 'CANCELLED']
]

# Print summary
for op in failed_ops:
    meta = op['metadata']
    print(f"Task ID: {op['name'].split('/')[-1]}")
    print(f"Description: {meta.get('description', 'N/A')}")
    print(f"State: {meta.get('state')}")
    print(f"Error: {meta.get('errorMessage', 'None')}")
    print('-' * 40)

# Need to redo two (maybe no granules for that month?)
# s2_dw_counts_month05_03UUV_v20250414
# s2_dw_counts_month06_01UCS_v20250414
# Out:
# Task ID: YYMPO3EHHR2GGDIAT7IR37JQ
# Description: alaska_floodplain_training_data_30000
# State: FAILED
# Error: None
# ----------------------------------------
# Task ID: LDUT7G55XQTZA7ICZN7PNA6Q
# Description: alaska_floodplain_training_data_40000
# State: FAILED
# Error: None
# ----------------------------------------
# Task ID: 7VNZY3N3DMC55LLDLLIVJ3O5
# Description: alaska_floodplain_training_data_25000
# State: FAILED
# Error: None
# ----------------------------------------
# Task ID: KGY5OUYEUEPPYJP3GG6S23H3
# Description: alaska_floodplain_training_data_v5
# State: FAILED
# Error: None
# ----------------------------------------
# Task ID: BCM4WG5TEI2I4I647NHJ7KLC
# Description: alaska_floodplain_training_data_v3
# State: FAILED
# Error: None
# ----------------------------------------
# Task ID: JZY4R347K6F4A2FAMP3E7AIG
# Description: Alaska_Floodplain_Step1_Export_to_Asset_v4-dsw
# State: CANCELLED
# Error: None
# ----------------------------------------
